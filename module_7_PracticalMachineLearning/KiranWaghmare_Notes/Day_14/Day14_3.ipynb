# %% [markdown]
# # DBSCAN Example

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.DataFrame(np.load('D:\Test\D14data2.npy'),columns=['x', 'y'])
dataset
# Out:
#              x         y
# 0    -0.121535 -0.228763
# 1    -0.220937 -0.252511
# 2     0.125904 -0.273143
# 3    -0.164537 -0.222244
# 4    -0.180824 -0.211075
# ...        ...       ...
# 2304 -0.063610  0.013804
# 2305  0.284742  0.301998
# 2306  0.502431 -0.300296
# 2307  0.538223  0.194122
# 2308 -0.086889 -0.209272
#
# [2309 rows x 2 columns]

# %%
dataset.plot(kind='scatter', x='x', y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.033,
               min_samples=22,
               algorithm='brute',
               p=0.9)

# %%
db = dbscan.fit_predict(dataset)

# %%
la = dbscan.labels_
la
# Out:
# array([ 0,  0,  0, ..., -1, -1,  0], dtype=int64)

# %%
len(dbscan.core_sample_indices_)
# Out:
# 1364

# %%
dataset.plot(kind='scatter', x='x', y='y', c=db,cmap='Accent_r', figsize=(16,10))
plt.show()
