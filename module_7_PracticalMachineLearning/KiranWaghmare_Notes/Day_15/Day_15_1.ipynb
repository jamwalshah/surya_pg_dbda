# %% [markdown]
# # Time Series data Application

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("D:\D15data1.csv")
dataset
# Out:
#             Date  Temp
# 0     01-01-1981  20.7
# 1     02-01-1981  17.9
# 2     03-01-1981  18.8
# 3     04-01-1981  14.6
# 4     05-01-1981  15.8
# ...          ...   ...
# 3645  27-12-1990  14.0
# 3646  28-12-1990  13.6
# 3647  29-12-1990  13.5
# 3648  30-12-1990  15.7
# 3649  31-12-1990  13.0
#
# [3650 rows x 2 columns]

# %%
type(dataset['Temp'])
# Out:
# pandas.core.series.Series

# %%
dataset['Date'] = pd.to_datetime(dataset['Date'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25028\1580598953.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   dataset['Date'] = pd.to_datetime(dataset['Date'])

# %%
dataset.head(10)
# Out:
#         Date  Temp
# 0 1981-01-01  20.7
# 1 1981-02-01  17.9
# 2 1981-03-01  18.8
# 3 1981-04-01  14.6
# 4 1981-05-01  15.8
# 5 1981-06-01  15.8
# 6 1981-07-01  15.8
# 7 1981-08-01  17.4
# 8 1981-09-01  21.8
# 9 1981-10-01  20.0

# %%
plt.plot(dataset['Date'],dataset['Temp'])

# %%
dataset['M12']=dataset['Temp'].rolling(12).mean()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25028\2084587910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['M12']=dataset['Temp'].rolling(12).mean()

# %%
dataset['Month'] = [i.month for i in dataset['Date']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File D:\Anaconda\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Anaconda\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 dataset['Month'] = [i.month for i in dataset['Date']]
#
# File D:\Anaconda\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Date'

# %%
#dataset

# %%
dataset['Year'] = [i.year for i in dataset['Date']]

# %%
#dataset

# %%
dataset['Series'] = np.arange(1,len(dataset)+1)

# %%
#dataset

# %%
dataset.drop(['Date','M12'], axis=1, inplace=True)

# %%
#dataset

# %%
dataset = dataset[['Series','Year','Month','Temp']]

# %%
#dataset

# %%
X=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test =train_test_split(X,y,test_size=1/3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(X_test)

# %%
plt.plot(X_train,y_train,color='red')
plt.plot(X_train, reg.predict(X_train), color='blue')
# Out:
# [<matplotlib.lines.Line2D at 0x25cbf3f8820>,
#  <matplotlib.lines.Line2D at 0x25cbf3f8850>,
#  <matplotlib.lines.Line2D at 0x25cbf3f8880>]

# %%
plt.plot(X_test,y_test,color='red')
plt.plot(X_train, reg.predict(X_train), color='blue')
# Out:
# [<matplotlib.lines.Line2D at 0x25cbf457a60>,
#  <matplotlib.lines.Line2D at 0x25cbf457a90>,
#  <matplotlib.lines.Line2D at 0x25cbf457ac0>]
