# %%
passing_marks = 2
if passing_marks > 16:
  print("Pass")
else:
  print("fail")
# Out:
# fail

# %% [markdown]
# WAP to check if entered string is in upper case or not

# %%
str = "CDAC"
if str.isupper() == True:
  print("upper case")
else:
  print("Not in upper case")
# Out:
# upper case

# %%
str = "hello"
if str in str.upper():
  print("upper case")
else:
  print("Not in upper case")
# Out:
# Not in upper case

# %%
str.upper()
# Out:
# 'HELLO'

# %% [markdown]
# WAP to check given no is greater than zero or not

# %%
n = int(input("Enter a number"))
if n > 0:
  print("greater than zero")
else:
  print("Not greater than zero")
# Out:
# Enter a number5
# greater than zero

# %% [markdown]
# WAP to check if a number is odd/even

# %%
n = int(input("Enter a number : "))
if n % 2 == 0:
  print("Number is even")
else:
  print("number is odd")
# Out:
# Enter a number : 2
# Number is even
