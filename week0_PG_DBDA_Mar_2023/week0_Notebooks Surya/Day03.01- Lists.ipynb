# %% [markdown]
# **List**
# 1. sequence of items
# 2. can contain combination of multiple data types, like int, float etc.
# 3. enclosed in square brackets []
# 4. allows to hold duplicate elements
# 5. it is mutable, can make changes like add, update, remove any element
# 6. follows an ordered format, new elements are added at the end
# 7. allowed to create an empty list e.g. list1=[]

# %%
list1 = []

# %%
type(list1)
# Out:
# list

# %%
list1 = [1,2,3]
list1
# Out:
# [1, 2, 3]

# %%
list1 = [23.4, 56.8, 67.9]
list1
# Out:
# [23.4, 56.8, 67.9]

# %%
list1 = ["hello", "world", "cdac"]
list1
# Out:
# ['hello', 'world', 'cdac']

# %%
list2 = ["hello", 12, 34.56]
list2
# Out:
# ['hello', 12, 34.56]

# %%
list3 = [12,  34, 45, ["hello"], [2, 4, 4.6, "xyz"]]
list3
# Out:
# [12, 34, 45, ['hello'], [2, 4, 4.6, 'xyz']]

# %%
list4 = [12,  34, 45, ["hello"], [2, 4, 4.6, "xyz"], {1, 2, 3}, (45, 34)]
list4
#allows collection of different data types
# Out:
# [12, 34, 45, ['hello'], [2, 4, 4.6, 'xyz'], {1, 2, 3}, (45, 34)]

# %%
len(list4)
# Out:
# 7

# %%
list4.index(34)
# Out:
# 1

# %%
list4[1]
# Out:
# 34

# %%
list[4][2]
# Out:
# 4.6

# %%
list4[6][1]
# Out:
# 34

# %%
list4[-1][1]
# Out:
# 34

# %%
list1 = ["one", "two", "three", "four", 1, 2, 3, 4, 5, 6]
list1[0:5]
# Out:
# ['one', 'two', 'three', 'four', 1]

# %% [markdown]
# WAP to slice and find the first three & last three elements

# %%
list = [1, 2, 3, 4, 5]
list[0:3]
# Out:
# [1, 2, 3]

# %%
list[-3:]
# Out:
# [3, 4, 5]

# %%
list
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# list() : it is a built-in method to create a new list

# %%
new_li = list()
print(new_li)
# Out:
# []

# %%
a = "hello", 1, 3, 7.9
new_li = list(a)
new_li
# Out:
# ['hello', 1, 3, 7.9]

# %% [markdown]
# append() : adds only single element to end of list

# %%
new_li.append("world")
new_li
# Out:
# ['hello', 1, 3, 7.9, 'world']

# %% [markdown]
# extend() : adds multiple emelents at end of list

# %%
ex = ["cdac", "mumbai"]
new_li.extend(ex)
new_li
# Out:
# ['hello', 1, 3, 7.9, 'world', 'cdac', 'mumbai']

# %%
new_li.insert(3, "three")
new_li
# Out:
# ['hello', 1, 3, 'three', 7.9, 'world', 'cdac', 'mumbai']

# %% [markdown]
# ##append() Vs. extend() Vs. insert()
# 1. append() adds single element at end
# 2. extend() adds multiple elements at end
# 3. insert() adds element at defined location without removing existing elements

# %%
new_li[0:2] = ["march", "three"]
new_li
# Out:
# ['march', 'three', 3, 'three', 7.9, 'world', 'cdac', 'mumbai']

# %%
new_li.remove("three")
new_li
# Out:
# ['march', 3, 'three', 7.9, 'world', 'cdac', 'mumbai']

# %% [markdown]
# WAP to listname.pop(2)

# %%
new_li = ["one", "two", "three", 1.2, 3, 4, 45]
new_li.pop(2) # removes elment at index specified to pop()
#new_li
# Out:
# 'three'

# %%
new_li = ["one", "two", "three", 1.2, 3, 4, 45]
new_li.pop() # removes last element if no index is specified to pop()
# Out:
# 45

# %%
new_li
# Out:
# ['one', 'two', 'three', 1.2, 3, 4]

# %%
del new_li[3]

# %%
new_li
# Out:
# ['one', 'two', 'three', 3, 4]

# %%
del new_li

# %%
new_li = ['one', 'two', 'three', 1.2, 3, 4]

# %%
new_li.pop()
# Out:
# 4

# %%
new_li.pop()
# Out:
# 3

# %%
new_li.pop()
# Out:
# 1.2

# %%
new_li.pop()
# Out:
# 'three'

# %%
new_li.pop()
# Out:
# 'two'

# %%
new_li.pop()
# Out:
# 'one'

# %%
new_li
# Out:
# []

# %% [markdown]
# ##list.pop(n) Vs. del < list[n] > Vs. list.clear() Vs. list.remove(< element >)
# 1. pop method removes & returns only last element form list, if you provide an index as an argument, it removes removes and returns the element at that index
# 2. del removes the element by index or by slicing or entire list
# 3. clear() only removes all the  elements from the list
# 4. remove(< element >) removes the first occurence of the specified element from the list

# %%
new_li = ['one', 'two', 'three', 1.2, 3, 4, 45]

# %%
new_li.clear()

# %%
new_li
# Out:
# []

# %%
new_li = ['one', 'two', 'three', 1.2, 3, 4, 45]

# %%
copy_list = new_li

# %%
id(new_li)
# Out:
# 139953015525568

# %%
id(copy_list)
# Out:
# 139953015525568

# %% [markdown]
# Address of both lists will be same when an existing list is assigned to a new one

# %%
copy_meth = new_li.copy()

# %%
copy_meth
# Out:
# ['one', 'two', 'three', 1.2, 3, 4, 45]

# %%
id(copy_meth)
# Out:
# 139953015370432

# %% [markdown]
# while copying using list.copy() method, a new list is created, existing address of previous list is not used, so address of new list is different

# %%
cc_list = list()

# %%
id(cc_list)
# Out:
# 139952683460992

# %%
cc_list = new_li
cc_list
# Out:
# ['one', 'two', 'three', 1.2, 3, 4, 45]

# %%
print(new_li)
print(copy_list)
print(copy_meth)
print(cc_list)
# Out:
# ['one', 'two', 'three', 1.2, 3, 4, 45]
# ['one', 'two', 'three', 1.2, 3, 4, 45]
# ['one', 'two', 'three', 1.2, 3, 4, 45]
# ['one', 'two', 'three', 1.2, 3, 4, 45]

# %%
id(new_li)
# Out:
# 139953015525568

# %%
id(copy_list)
# Out:
# 139953015525568

# %%
id(copy_meth)
# Out:
# 139953015370432

# %%
id(cc_list)
# Out:
# 139953015525568

# %% [markdown]
# while copying data will be same for any way you copy data
#
# address is same only when existing list is  assigned to new list while initializing
#
# but address will be different while using copy() method or if you assign list after initializing the list using list() method

# %%
new_li.extend(copy_list)
new_li
# Out:
# ['one', 'two', 'three', 1.2, 3, 4, 45, 'one', 'two', 'three', 1.2, 3, 4, 45]

# %%
new_li + copy_meth
# Out:
# ['one',
#  'two',
#  'three',
#  1.2,
#  3,
#  4,
#  45,
#  'one',
#  'two',
#  'three',
#  1.2,
#  3,
#  4,
#  45,
#  'one',
#  'two',
#  'three',
#  1.2,
#  3,
#  4,
#  45]

# %%
#reverese
new_li = ['one', 'two', 'three', 1.2, 3, 4, 45]

# %%
new_li.reverse()

# %%
print(new_li)
# Out:
# [45, 4, 3, 1.2, 'three', 'two', 'one']

# %%
new_li[::-1]
# Out:
# ['one', 'two', 'three', 1.2, 3, 4, 45]

# %%
or1= [45 , 67, 1, 2, 34, 6, 78]
or1.sort()
or1
# Out:
# [1, 2, 6, 34, 45, 67, 78]

# %%
or1= [45 , 67, 1, 2, 34, 6, 78]
or1.sort(reverse=True)
or1
# Out:
# [78, 67, 45, 34, 6, 2, 1]

# %% [markdown]
# list.sort() will sort in ascending order, but to sort in descending order you've to use extar argument reverse=True
