# %%
Sure, here are some of the methods of BeautifulSoup in web scraping and their explanations:

soup.find(): This method is used to find the first occurrence of a specified HTML tag in the BeautifulSoup object. You can search for tags based on their name, attributes, and text content.

soup.find_all(): This method is used to find all occurrences of a specified HTML tag in the BeautifulSoup object. You can search for tags based on their name, attributes, and text content.

soup.select(): This method is used to select HTML elements based on CSS selectors. You can use CSS selectors to select tags based on their attributes, class names, and parent-child relationships.

soup.get_text(): This method is used to extract the text content of an HTML document. It returns all the text in the document, including the text inside tags.

soup.prettify(): This method is used to format the HTML document in a human-readable way. It adds line breaks and indentation to the document to make it easier to read.

soup.contents: This method returns a list of all the direct child elements of an HTML tag. It can be used to iterate over the child elements of a tag and extract their contents.

soup.parent: This method returns the parent element of an HTML tag. It can be used to navigate up the HTML document and extract information from parent elements.

soup.next_sibling: This method returns the next sibling element of an HTML tag. It can be used to navigate to the next sibling element and extract information from it.

soup.previous_sibling: This method returns the previous sibling element of an HTML tag. It can be used to navigate to the previous sibling element and extract information from it.

These are just some of the many methods available in BeautifulSoup. Using these methods, you can extract information from HTML documents and scrape data from websites.

# %%
#find() method: This method returns the first matching tag, given the tag name and attributes.
from bs4 import BeautifulSoup

html_doc = """
<html>
<head>
<title>My Website</title>
</head>
<body>
<div id="content">
<h1>Welcome to my website!</h1>
<p>This is a paragraph of text.</p>
<a href="http://www.google.com">Google</a>
</div>
</body>
</html>
"""
soup = BeautifulSoup(html_doc, 'html.parser')
# Find the first <div> tag with id="content"
div_tag = soup.find('div', {'id': 'content'})
print(div_tag)
# Out:
# <div id="content">
# <h1>Welcome to my website!</h1>
# <p>This is a paragraph of text.</p>
# <a href="http://www.google.com">Google</a>
# </div>

# %%
#find_all() method: This method returns a list of all matching tags, given the tag name and attributes.
from bs4 import BeautifulSoup

html_doc = """
<html>
<head>
<title>My Website</title>
</head>
<body>
<div class="article">
<h2>Article Title</h2>
<p>This is the first paragraph.</p>
<p>This is the second paragraph.</p>
</div>
<div class="article">
<h2>Another Article Title</h2>
<p>This is another paragraph.</p>
</div>
</body>
</html>
"""

soup = BeautifulSoup(html_doc, 'html.parser')

# Find all <div> tags with class="article"
#div_tags = soup.find_all('div', {'class': 'article'})
div_tags = soup.find_all('h2')
for div_tag in div_tags:
    print(div_tag)
# Out:
# <h2>Article Title</h2>
# <h2>Another Article Title</h2>

# %%
#select() method: This method allows you to use CSS selectors to find matching tags.
from bs4 import BeautifulSoup

html_doc = """
<html>
<head>
<title>My Website</title>
</head>
<body>
<div class="article">
<h2>Article Title</h2>
<p>This is the first paragraph.</p>
<p>This is the second paragraph.</p>
</div>
<div class="article">
<h2>Another Article Title</h2>
<p>This is another paragraph.</p>
</div>
</body>
</html>
"""

soup = BeautifulSoup(html_doc, 'html.parser')

# Find all <div> tags with class="article"
#div_tags = soup.select('div.article')
div_tags = soup.select('h2')
for div_tag in div_tags:
    print(div_tag)
# Out:
# <h2>Article Title</h2>
# <h2>Another Article Title</h2>

# %%
#Accessing tag attributes: You can use the dictionary-like syntax to access the attributes of a tag.from bs4 import BeautifulSoup

html_doc = """
<html>
<head>
<title>My Website</title>
</head>
<body>
<a href="http://www.google.com">Google</a>
</body>
</html>
"""

soup = BeautifulSoup(html_doc, 'html.parser')

# Find the <a> tag and print its href attribute
a_tag = soup.find('a')
print(a_tag['href'])
# Out:
# http://www.google.com

# %%
#Accessing tag text: You can use the .text property to access the text content of a tag.
from bs4 import BeautifulSoup

html_doc = """
<html>
<head>
<title>My Website</title>
</head>
<body>
<div id="content">
<h1>Welcome to my website!</h1>
<p>This is a paragraph of text.</p>
<a href="http://www.google.com">Google</a>
</div>
</body>
</html>
"""

soup = BeautifulSoup(html_doc, 'html.parser')

# Find the <h1> tag and print its text content
h1_tag = soup.find('h1')
print(h1_tag.text)
# Out:
# Welcome to my website!

# %%
from bs4 import BeautifulSoup
import requests
#get data from html page toa file text
f=requests.get("https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=Python&txtLocation=Mumbai&cboWorkExp1=0").text

soup=BeautifulSoup(f,'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html><head>
# <link href="https://fonts.googleapis.com/css?family=Poppins:400,500,600,700" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/jquery.tokeninput.js" type="text/javascript"></script>
# <!-- <script type="text/javascript" src="https://code.angularjs.org/1.7.0/angular.min.js"></script> -->
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/angular1.7.0.min.js" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/materialize.min.js" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/groupJs/dwrGroup.js?v=7.1.7" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/mustache.js" type="text/javascript"></script>
# <link href="https://www.timesjobs.com/candidate/job-search.html" rel="canonical"/>
# <link href="https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&amp;from=submit&amp;txtKeywords=Python&amp;txtLocation=Mumbai&amp;cboWorkExp1=0/&amp;sequence=2&amp;startPage=1" rel="next"/>
# <title>Python Jobs in Mumbai  with Entry Level experience - TimesJobs</title>
# <meta content="Jobs in Python in Mumbai  with Entry Level experience. Search and apply jobs online at Timesjobs.com" name="description"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-59SJDG4');</script>
# <!-- End Google Tag Manager -->
# <script src="https://www.gstatic.com/charts/loader.js" type="text/javascript"></script>
# <script>
#           //google.charts.load('current', {'packages':['bar']});
#           google.charts.load('current', {packages: ['corechart', 'bar']});
#         </script>
# <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="C4P83-FLD8C-N9VTA-RP2SP-ZADRK",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"C4P83-FLD8C-N9VTA-RP2SP-ZADRK";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="eprtnfaxbsiyuzby67hq-f-258d733a0-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"34","ak.cp":"1277284","ak.ai":parseInt("765140",10),"ak.ol":"0","ak.cr":26,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"18bdc7c1","ak.r":36638,"ak.a2":n,"ak.m":"j","ak.n":"essl","ak.bpcip":"35.227.54.0","ak.cport":39314,"ak.gh":"23.32.17.138","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1681455055","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"9","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head>
# <body>
# <div id="site">
# <!-- Header Starts -->
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-59SJDG4" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script src="https://wchat.freshchat.com/js/widget.js" type="text/javascript"></script>
# <script>
# window.fcWidget.init({
# token: "d7130618-a917-400b-804c-bdf44d8d178b",
# host: "https://wchat.freshchat.com",
# config: {
# headerProperty: {
# hideChatButton: true
# }
#         }
# });
#
# </script>
# <!--[if IE]>
# <script src="scripts/html5shiv.js"></script>
# <![endif]-->
# <script src="https://static.timesjobs.com/newtj_js/scripts/ajax-upload.js" type="text/javascript"></script>
# <div class="msg notify" id="fb_connect_suggest" style="display: none;">
# 		Dear Jobseeker, Find millions of jobs on single click.
# 		<span id="fb_auto_connect"><a href="javascript:fconnect_auto();"><img alt="fconnect" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/top-facebook-notify.png"/></a></span>
# <span class="big-cls cls-icn" onclick="javascript:ack_fbconnect_cancel();" title="Click to Hide"><i class="material-icons">close</i></span>
# <span id="fb_connect_status"></span>
# </div>
# <div class="msg success" id="fb_connect_success" style="display: none;">
# 			Congratulations! You have been logged in via Facebook
# 		</div>
# <header class="main-header">
# <div class="top-header">
# <div class="ubility-wrap clearfix">
# <ul class="top-link">
# <li><a class="link-active" href="https://www.timesjobs.com">TimesJobs</a></li>
# <li><a href="http://jobbuzz.timesjobs.com" target="_blank">JobBuzz</a></li>
# <!--<li><a href="http://stepahead.timesjobs.com" target="_blank">Career Services</a></li>
#      <li><a href="http://www.techgig.com" target="_blank">TechGig</a></li> -->
# <li><a href="https://ae.timesjobs.com" target="_blank">Gulf Jobs</a></li>
# <li><a href="http://content.timesjobs.com/recruitex?fromsite=tjcand" target="_blank">Career Insight</a></li>
# </ul>
# <ul class="top-contact">
# <li><i class="material-icons">call</i>0120 6358222</li>
# <li>
# <span class="live-chat" id="chat-widget" onclick="window.fcWidget.open();window.fcWidget.show();">Live Chat (10am to 6pm IST)</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="ubility-wrap logo-section clearfix">
# <a class="top-tj-logo" href="https://www.timesjobs.com" itemprop="url" title="TIMESJOBS">
# <img alt="TimesJobs" height="23" itemprop="logo" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/tj-logo-new.png" title="TimesJobs" width="140"/>
# </a>
# <script type="text/javascript">
# 				jQuery(document).ready(function() {
# 					jQuery("#career-affection").show();
# 					jQuery("#career-affection-rhs").show();
# 				})
# 			</script>
# <ul class="main-tj-nav clearfix">
# <script type="text/javascript">
# var notification_timeout = 10000;
# var notification_cache = true;
# if (!window.console) console = {log: function() {}};
#
# if(typeof String.prototype.trim !== 'function') {
#   String.prototype.trim = function() {
#     return this.replace(/^\s+|\s+$/g, '');
#   }
# }
#
#
# /* This function is used to set cookies */
# function setCookie(name,value,expires,path,domain,secure) {
#   document.cookie = name + "=" + escape (value) +
#     ((expires) ? "; expires=" + expires.toGMTString() : "") +
#     ((path) ? "; path=" + path : "") +
#     ((domain) ? "; domain=" + domain : "") + ((secure) ? "; secure" : "");
# }
#
# /* This function is used to get cookies */
# function getCookie(name) {
# 	var prefix = name + "=" ;
# 	var start = document.cookie.indexOf(prefix);
#
# 	if (start==-1) {
# 		return null;
# 	}
#
# 	var end = document.cookie.indexOf(";", start+prefix.length);
# 	if (end==-1) {
# 		end=document.cookie.length;
# 	}
#
# 	var value=document.cookie.substring(start+prefix.length, end) ;
# 	return unescape(value);
# }
#
#
# function deleteCookie(name,path,domain) {
#   if (getCookie(name)) {
#     document.cookie = name + "=" +
#       ((path) ? "; path=" + path : "") +
#       ((domain) ? "; domain=" + domain : "") +
#       "; expires=Thu, 01-Jan-70 00:00:01 GMT";
#   }
# }
#
# var authenticated = 'false';
#
# jQuery(document).ready(function(){
# var alreadyCalled = false;
#
# //alert("logged-in:"+authenticated);
# //alert("comparison to true, for"+authenticated +", "+ ('true' == authenticated));
#
# if('true' == authenticated){
# 	//jQuery(".viewnoteTab").mouseout(function(){
# //	  jQuery(".showdiv").hide();
# //	});
# //	jQuery(".viewnoteTab").mouseenter(function(){
# //	  jQuery(".showdiv").show();
# //	});
# 	//alert("logged in ");
# }else{
# 	//alert("not logged in ");
# 	jQuery(".notif-cls").on("click",function(){
# 		//alert('hi');
# 	  jQuery("#inline_login").hide();
# 	  //jQuery(".notification .nav-drop").hide();
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# 	updateNonLoggedInUsersTime();
# }
# function updateNonLoggedInUsersTime(){
# 	//alert("non_loggedin_time:"+getCookie('non_loggedin_time'));
# 	var setCookieForTime = getCookie('non_loggedin_time');
# 	if(null!=setCookieForTime){
# 		//alert("cookie found to be set to : "+setCookieForTime+" where time since is:"+timeSince(setCookieForTime));
# 		jQuery("#non_loggedin_time").html(timeSince(setCookieForTime));
# 	}else{
# 		var currentTime = new Date().getTime();
# 		setCookie('non_loggedin_time',currentTime);
# 	}
# }
#
# jQuery(".viewnote").on("click",function(){
# 	var loggedInClicked = getCookie('loggedin_click');
# 	if(null!=loggedInClicked){
# 		jQuery("#notification_count").css("background-color","#075DC1");
# 	}else{
# 		if('true' == authenticated){
# 			setCookie('loggedin_click',1);
# 			//alert("setting loggedInClicked");
# 		}
# 	}
# });
#
# });
#
# </script>
# <!--- view notification section begin --->
# <li class="notification viewnote">
# <a class="dropdown-button" data-activates="notifyDropdown" href="#">
# <i class="material-icons left">notifications_none</i>
# <span class="notif-count-new" id="notification_count">1</span>
# 	</a>
# <div class="nav-drop viewnoteTab dropdown-content" id="notifyDropdown">
# <div class="showdiv">
# <div class="notif-not-logedin" id="non_loggedin" style="display:none;">
# <div class="notif-welcm-msg clearfix">To see all recommended jobs, profile views, recruiter's contacted information, updates and more...</div>
# <div class="notif-act clearfix">
# <button class="waves-effect waves-light btn red-bdr-btn" onclick="javascript:openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');" type="button">Login</button>
# <strong class="or">or</strong>
# <a class="waves-effect waves-light btn red-bdr-btn" href="/candidate/register.html">Register</a>
# </div>
# </div>
# <!-- INLINE LOGIN PAGE -->
# <div class="notif-login-frm" id="inline_login" style="display:none;">
# <span class="notif-cls" title="Click to Hide"></span>
# <strong>Login to View Notifications!</strong>
# <form action="/candidate/times_login?BeforeLoginUrl=notification&amp;tab=1" method="post" name="loginFormNotification">
# <input class="txt2 defaultValue inpt-typ" id="txtUseNameNotification" name="j_username" onblur="javascript:settextNotification('txtUseNameNotification');" onclick="filltxtNotification(txtUseNameNotification)" size="42" type="text" value="Enter Email id / Login id"/>
# <input class="password_input_notification" name="j_password" size="42" style="display:none" type="password" value=""/>
# <input class="clearNotification" size="42" type="text" value="Enter Password"/>
# <div class="frgt-pass"><a class="fp" href="javascript:forgotPasswordNotification();">Forgot Password?</a></div>
# <input class="" onclick="javascript:return validateLoginFormNotification();" type="submit" value="Login"/>
# <div class="error-msg dflt-msg" id="loginErrNotification" style="display:none;">
# <!--<img class="errTip" title="Error" alt="Error" src="https://static.timesjobs.com/images_cand/tj_images/home/errTipL.gif">-->
# <!--<a class="errCls" href="#"><img border="0" title="Close" alt="Close" src="/images_cand/tj_images/home/logginErrClse.gif"></a>-->
#        	      Login-ID/Password cannot be left blank. Enter the full email ID (like: ram@gmail.com), if you are using registered email-id for login.
# 	      </div>
# <input name="notlogin" type="hidden" value="mytj"/>
# <input name="_acegi_security_remember_me" type="hidden" value="yes"/>
# </form>
# </div>
# <!-- INLINE LOGIN PAGE -->
# <div class="notif-main" id="base" style="display: none;">
# <ul>
# <li class="heading clearfix" id="heading">
# <a href="#" id="heading-link"><span>Job Alerts(10)</span></a>
# </li>
# <li id="base-li" style="display: none;"><a href="#" id="base-li-anchor">5 Matching Jobs <span id="base-li-time">3 hrs ago</span></a>
# </li>
# <span class="base_li" id="base-li-data" style="display: none;"></span>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <!--- view notification section ends here --->
# <script type="text/javascript">
#
# function forgotPasswordNotification(){
# 		GB_showCenter('Forgot Password','/candidate/ForgetPassword.html',180,420);
# 	}
# var race = 0;
# function showNotificationLoginThickBox(){
#
# race = 1;
#
# 			//jQuery("#inline_login").addClass('notifyshow');
# 			//jQuery('.viewnoteTab').addClass('notifyshow');
# 			//jQuery('.showdiv').addClass('notifyshow');
# 			//jQuery(".notif-not-logedin").hide();
# 			//jQuery(".notification .nav-drop").css('display','block');
# 			//jQuery(".notification").addClass("notifi");
# 			jQuery('.clearNotification').css({color:"#b3b3b3"});
# 					jQuery('.clearNotification').focus(function(){
# 						//alert('check');
# 						jQuery(this).hide();
# 						jQuery(' .password_input_notification').show();
# 						jQuery('.password_input_notification').focus();
# 					});
# 					jQuery('.password_input_notification').blur(function(){
# 						if(this.value==''){
# 						jQuery(this).hide();
# 							jQuery('.clearNotification').show();
# 						}
# 					});
#
#
#
# }
# jQuery(".notif-cls").on("click",function(){
# 	  //jQuery("#inline_login").removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.viewnoteTab').removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.showdiv').removeClass('notifyshow');
#
# 	 // jQuery(".notif-not-logedin").show();
# 	 jQuery(".notif-not-logedin").css('display','');
# 	  //jQuery(".notification .nav-drop").css('display','none');
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# jQuery(".viewnote").mouseenter(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").show();
#   //jQuery(".notification .nav-drop").show();
#
#   if('false' == authenticated){
#     var hideCountCookie = getCookie('hide_nologgedin_count');
#     if(null == hideCountCookie){
#   		setCookie('hide_nologgedin_count',1);
#   		//alert("setting hide_nologgedin_count");
#   	}else{
#   		jQuery("#notification_count").hide();
#   	}
#   }else{
#    jQuery("#inline_login").hide();
#    jQuery("#non_loggedin").hide();
#
#    	updateNotificationComponentWithIECheck();
#   }
#
# });
# jQuery(".viewnote").mouseleave(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").hide();
#   //jQuery(".notification .nav-drop").hide();
# });
# jQuery(".notif-login-frm").mouseleave(function(){
# //alert("mouseenter called..");
#   event.stopPropagation()
# });
# function settextNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value !=''){
# 			document.getElementById(id).checked=true;
# 		}else{
# 			document.getElementById(id).checked=false;
# 			document.getElementById('txtUseNameNotification').value='Enter Email id / Login id';
# 			document.getElementById('txtUseNameNotification').style.color='#999'
# 		}
# 	}
# function filltxtNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id')
# 			document.getElementById('txtUseNameNotification').value=''
# 		document.getElementById('txtUseNameNotification').style.color='#333'
# 	}
# function validateLoginFormNotification(){
# var status = true;
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id'){
# 			document.getElementById('txtUseNameNotification').value='';
# 			status =  false;
# 		}
#
# 		if(checkBlankNotification(document.loginFormNotification.j_username,"Login ID")){
# 			status =  false;
# 		}
# 		if(checkBlankNotification(document.loginFormNotification.j_password,"Password")){
# 			status =  false;
# 		}
# 		//update_notification_cookie
# 		if(status){
# 			deleteCookie('update_notification_cookie');
# 		}
# 		return status;
# 	}
# function checkBlankNotification(field,name){
# 		if(field.value.trim() == ""){
# 			field.value = "";
# 			field.focus();
# 			document.getElementById("loginErrNotification").style.display="";
# 			return true;
# 		}
# 		return false;
# 	}
#
# var diff = 1681455055-((new Date().getTime())/1000);
#
#
# function ellipsize(str, len) {
# 	if(str.length > len) {
#  		return str.substr(0,len) + "...";
# 	} else {
# 		return str;
# 	}
# }
#
# function timeSince(previous){
#
# 	current =  new Date().getTime()+diff;
# 	var milleSecondsPerMinute = 60 * 1000;
#     var milleSecondsPerHour = milleSecondsPerMinute * 60;
#     var milleSecondsPerDay = milleSecondsPerHour * 24;
#     var milleSecondsPerMonth = milleSecondsPerDay * 30;
#     var milleSecondsPerYear = milleSecondsPerDay * 365;
#
#     var elapsed = current - previous;
#
#     if (elapsed < milleSecondsPerMinute) {
#          value = Math.round(elapsed/1000) + ' seconds ago';
#     }
#
#     else if (elapsed < milleSecondsPerHour) {
#     	value = Math.round(elapsed/milleSecondsPerMinute) + ' minutes ago';
#     }
#
#     else if (elapsed < milleSecondsPerDay ) {
#     	value = Math.round(elapsed/milleSecondsPerHour ) + ' hours ago';
#     }
#
#     else if (elapsed < milleSecondsPerMonth) {
#     	value =  Math.round(elapsed/milleSecondsPerDay) + ' days ago';
#     }
#
#     else if (elapsed < milleSecondsPerYear) {
#     	value = Math.round(elapsed/milleSecondsPerMonth) + ' months ago';
#     }
#
#     else {
#     	value = Math.round(elapsed/milleSecondsPerYear ) + ' years ago';
#     }
#     //return (value);
#     return (value);
# }
#
#
# function updateNotificationComponent(){
#  alreadyCalled  =true;
# 	var context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  context="/candidate/";
# 		  //alert("bingo");
# 	}
#
#
# 	ajaxController.getLoginId(function(response){
# 	//alert("updateNotificationComponent,response:"+response)
# 		if (response != null && response.trim().length > 0) {
# 			jQuery.ajax({
# 							cache:notification_cache,
# 							timeout:notification_timeout,
# 							url:context+"inbox-notifications.html?from=submit",
# 							success:function(data){
# 							var trimLength = 30;
# 									jQuery("#base_ja").remove();
# 									jQuery("#base_j").remove();
# 									jQuery("#base_rv").remove();
# 									//alert(data);
# 									var parsedData = JSON.parse(data);
# 									var theCount = parsedData["count"];
#
# 									var jaCount = parsedData["jaCount"];
# 									var jCount = parsedData["jCount"];
# 									var rvCount = parsedData["rvCount"];
#
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
# 									//theCount = theCount - jCount;
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
#
# 									if(theCount >= 0){
# 										if(theCount >= 0){
# 											if(theCount <99){
# 												jQuery("#notification_count").html(theCount);
# 												setCookie('notification_cookie_count',theCount);
# 											}else{
# 												jQuery("#notification_count").html("99+");
# 												setCookie('notification_cookie_count',"99+");
# 											}
# 										}
#
# 										var isNew = parsedData["new"];
# 										//alert("new:"+(isNew == true));
# 										if(isNew == true){
# 											jQuery("#notification_count").css("background-color","red");
# 											setCookie('notification_cookie_color','red');
# 											deleteCookie('loggedin_click');
# 										}else{
# 											var loggedInClicked = getCookie('loggedin_click');
# 											//alert("loggedInClicked:"+loggedInClicked);
# 											if(null!=loggedInClicked){
# 												jQuery("#notification_count").css("background-color","#075DC1");
# 												setCookie('notification_cookie_color','#075DC1');
# 											}else{
# 												jQuery("#notification_count").css("background-color","red");
# 												setCookie('notification_cookie_color','red');
# 											}
#
# 										}
# 									}
# 									jQuery("#notification_count").show();
#
# 									/* alert("count:"+parsedData["count"]);
# 									alert("jaCount:"+parsedData["jaCount"]);
# 									alert("jCount:"+parsedData["jCount"]);
# 									alert("rvCount:"+parsedData["rvCount"]); */
#
# 									/**
# 									start-JA
# 									*/
# 									if(jaCount){
# 										if(jaCount <25){
# 											jQuery("#base .heading span").html("Job alerts ("+jaCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Job alerts (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Job alerts");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jaData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jaData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jaData"])[i].subject;
# 										var since = timeSince(JSON.parse(parsedData["jaData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=1&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_ja_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_ja");
# 									//alert("jaData[0]:"+ (JSON.parse(parsedData["jaData"]).length));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-JA
# 									*/
#
# 									/**
# 									start-J
# 									*/
# 								   if(jCount){
# 									 	if(jCount <25){
# 											jQuery("#base .heading span").html("Mails from recruiters ("+jCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Mails from recruiters (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Mails from recruiters");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jData"])[i].EmployerName + " contacted you.";
# 										var since = timeSince(JSON.parse(parsedData["jData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=2&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_j_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_j");
# 									//alert("jData[0]:"+timeSince(JSON.parse(parsedData["jData"])[0].creationTime));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-J
# 									*/
#
# 									/**
# 									start-RV
# 									*/
# 									if(rvCount > 0){
# 										if(rvCount <25){
# 											jQuery("#base .heading span").html("Who's viewed your profile ("+rvCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Who's viewed your profile (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Who's viewed your profile");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["rvData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["rvData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["rvData"])[i].subject;
# 										var employerName = JSON.parse(parsedData["rvData"])[i].EmployerName + " viewed your resume.";
# 										var since = timeSince(JSON.parse(parsedData["rvData"])[i].creationTime);
# 										if(null!=employerName && employerName.length > 0){
# 											jQuery("#base-li-anchor").html(ellipsize(employerName,trimLength));
# 											jQuery("#base-li-anchor").attr("title",employerName);
# 										}else{
# 											jQuery("#base-li-anchor").html("Resume Viewed");
# 										}
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=5&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_rv_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_rv");
# 									//alert("rvData[0]:"+timeSince(JSON.parse(parsedData["rvData"])[0].employerName));
# 									jQuery("#base > ul span.base_li").html("");
# 									/**
# 									end-RV
# 									*/
#
# 									jQuery("#base").hide();
# 									jQuery("li#base-li").hide();
# 								},
# 							complete:function(){
# 								console.log("complete... inbox-notifications");
# 								jQuery("#inline_login").hide();
#    								jQuery("#non_loggedin").hide();
#    								alreadyCalled  = false;
# 							},
# 							error: function(x, t, m) {
# 								console.log("Error message"+m);
# 								 var randomnumber=Math.floor(Math.random()*100000001);
# 								 var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+context+"inbox-notifications.html?from=submit"+'&op=respTracking#'+randomnumber;
# 								 ping(nlpurl);
# 						        jQuery("#error").show();
# 							}
# 						});
#
# 		}else{
# 					jQuery("#base_ja").remove();
# 					jQuery("#base_j").remove();
# 					jQuery("#base_rv").remove();
# 					if(0 == race){
# 						jQuery("#non_loggedin").show();
# 					}
#
#
# 					var hideCountCookie = getCookie('hide_nologgedin_count');
# 					if(null != hideCountCookie){
# 						/*This is commented because for non logged in user default count 1 is being hidden.*/
# 						//jQuery("#notification_count").hide();
# 					}else{
# 						jQuery("#notification_count").css("background-color","red");
# 						jQuery("#notification_count").show();
# 					}
# 					alreadyCalled  = false;
# 		}
# 	});
# }
#
# var updateNotificationCookie = getCookie('update_notification_cookie');
# //alert("updateNotificationCookie: "+updateNotificationCookie);
# if(null == updateNotificationCookie || updateNotificationCookie==''){
# 	updateNotificationComponentWithIECheck();
# 	setCookie('update_notification_cookie',1);
# 	//alert("cookie set");
# 	scheduleNotificationCookieToDie();
# }else{
# 	if('true' == authenticated){
# 		//alert("updating from cookie!!!");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		if(null==notificationCookieCount){
# 			updateNotificationComponent();
# 		}
# 		updateNotificationFromCookie();
# 	}else{
# 		//alert("not updating from cookie!!!");
# 		updateNotificationComponentWithIECheck();
# 	}
# }
#
# function scheduleNotificationCookieToDie(){
# 	setTimeout(function() {
# 	      deleteCookie('update_notification_cookie');
# 	      deleteCookie('notification_cookie_count');
# 	      deleteCookie('notification_cookie_color');
# 	},5*60*1000);
# }
#
# function updateNotificationFromCookie(){
# console.log("cookie set for updateNotificationCookie, not making server call.");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		//alert("not setting cookie"+updateNotificationCookie);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").html(""+notificationCookieCount);
# 		}else{
# 			jQuery("#notification_count").html("1");
# 		}
# 		var notificationCookieColor = getCookie('notification_cookie_color');
# 		//alert("cookie color"+notificationCookieColor);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").css("background-color",notificationCookieColor);
# 		}else{
# 			jQuery("#notification_count").css("background-color","red");
# 		}
# 		jQuery("#notification_count").show();
# }
#
# function updateNotificationComponentWithIECheck(){
# <!--[if gte IE 9]>
# 		updateNotificationComponent();
# 	<!--<![endif]-->
# 	<!--[if lt IE 9]>
#    		jQuery(document).ready(function() {
# 			updateNotificationComponent();
# 		});
# 	<!--<![endif]-->
# }
#
# </script>
# <li class="login-reg">
# <a href="javascript:void(0);" onclick="openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');">Login</a>
# </li>
# <li class="login-reg">
# <a href="/candidate/register.html?pageFlow=TJ_SEARCH">Register</a>
# </li>
# </ul>
# </div>
# </header>
# <!--bottom banner starts-->
# <!--bottom banner ends-->
# <div class="open-search">
# <div class="usability-srch clearfix">
# <div class="main-srch-form clearfix">
# <div class="msg error" id="errorMsgDiv" style="display:none">Please provide inputs for at least one field</div>
# <form action="https://www.timesjobs.com/candidate/job-search.html" id="quickSearchBean" method="get" name="quickSearchBean" onsubmit="return searchEngine.validateSearchForm(this);">
# <input name="searchType" type="hidden" value="personalizedSearch"/>
# <input name="from" type="hidden" value="submit"/>
# <div class="auto-suggest-blk">
# <input class="browser-default" id="txtKeywords" name="txtKeywords" type="text" value="Python"/>
# <div id="autoSuggestList" style="display:none;"><ul></ul></div><iframe frameborder="0" id="FrameautoSuggestList" style="display:none;"></iframe>
# <div class="suggestionList srch-suggest" id="autoSuggestList2ndKeywordsListSFB" style="display:none;">
# <h5>Suggested Keywords</h5>
# <ul></ul></div>
# </div>
# <div class="auto-suggest-blk location-srch">
# <input class="location-srch browser-default" id="txtLocation" name="txtLocation" type="text" value="Mumbai"/><div id="autoSuggestLocation" style="display:none;"><ul></ul></div><iframe frameborder="0" id="FrameautoSuggestLocation" style="display:none"></iframe></div>
# <div class="srch-select">
# <select class="browser-default" id="cboWorkExp1" name="cboWorkExp1">
# <option value="-1">Experience</option>
# <option selected="selected" value="0">Entry Level</option>
# <option value="1">1 year</option>
# <option value="2">2 years</option>
# <option value="3">3 years</option>
# <option value="4">4 years</option>
# <option value="5">5 years</option>
# <option value="6">6 years</option>
# <option value="7">7 years</option>
# <option value="8">8 years</option>
# <option value="9">9 years</option>
# <option value="10">10 years</option>
# <option value="11">11 years</option>
# <option value="12">12 years</option>
# <option value="13">13 years</option>
# <option value="14">14 years</option>
# <option value="15">15 years</option>
# <option value="16">16 years</option>
# <option value="17">17 years</option>
# <option value="18">18 years</option>
# <option value="19">19 years</option>
# <option value="20">20 years</option>
# <option value="21">20+ years</option>
# </select>
# </div>
# <button class="waves-effect waves-light btn" onclick="javascript:setAClickOnSearch();" value="Search">Find Jobs</button>
# </form>
# </div>
# <div class="recent-srchs home-srchptext srch-top-right" id="recentSearchId" style="display: none;"></div>
# <div class="upload-res-uni srch-top-right clearfix" id="resNewUpload" style="display:none;">
# <div class="upload-res-txt clearfix">
# <span class="upload-icon"></span>
# <div class="upload-res-input">
# <h5>New to Timesjobs?</h5>
# <label class="upload-res-btn" id="uploadResume_basic">
#           upload your resume
#           <input id="resumeFile_basic" name="resumeFile_basic" size="25" type="file"/>
# </label>
# <span id="uploadingResume_basic" style="display:none"><img alt="Uploading Resume" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/loader.gif"/></span>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#   var ssCounterSFB=0;
# 	function openSecondSuggestionSFB(theSelectedSuggestionText){
# 		if(ssCounterSFB < 5){
# 			ajaxController.getSuggestedSkillList(theSelectedSuggestionText,"","SKILL",8,true,cb_openSecondSuggestionSFB);
# 		}else{
# 			console.log("CAND-131 Not showing 2nd suggestion.");
# 		}
# 	}
#
# 	function cb_openSecondSuggestionSFB(result){
# 		//alert("cb_openSecondSuggestion:"+result);
# 		var splitData = (""+result).split(",");
# 		var li_data = "";
# 		var dataLength = splitData.length;
# 	    var text = jQuery("#txtKeywords").val();
# 	    text =text.toLowerCase();
# 	    if(dataLength >1){
# 			for(i=0;i<dataLength;i++){
# 	            if(text.indexOf(splitData[i].toLowerCase()) < 0){
# 	                var hyperlink =  "javascript:secondSelectionClickedSFB('"+encodeURI(splitData[i])+"');";
# 					li_data+="<li><a href="+hyperlink+">"+splitData[i]+"</a></li>";
# 				}
# 			}
# 			jQuery("#autoSuggestList2ndKeywordsListSFB ul").html(li_data);
# 			jQuery("#autoSuggestList2ndKeywordsListSFB").slideDown(300);
# 			//ssCounterSFB = ssCounterSFB  + 1;
# 		}
# 	}
#
# 	function secondSelectionClickedSFB(that){
# 		//alert("that:"+that);
# 		_gaq.push(['_trackEvent','Click2Ad','tj_skillsuggestion']);
# 		jQuery("#autoSuggestList2ndKeywordsListSFB").hide();
# 		var text = jQuery("#txtKeywords").val();
# 		var text2 = text.toLowerCase() + ",";
# 		var that2 = that.toLowerCase();
# 		var res = text2.split(",");
# 		var exists = false;
# 		for(i in res){
# 			if(null!=res[i] && res[i].length > 0 && res[i]+"".trim() === that2){
# 				exists = true;
# 				break;
# 			}
# 		}
# 		//var index = text2.search(new RegExp(that2, "i"));
# 		//console.log("exists:"+exists);
# 		if(!exists){
# 			jQuery("#txtKeywords").val(text +","+ that);
# 			jQuery("#txtKeywords").focus();
# 		}
# 		openSecondSuggestionSFB(that);
# 	}
# jQuery(document).ready(function(){
# 	jQuery('#quickSearchBean input[type="text"]').DefaultInputValue();
# })
#
# function BasicResFileUpload(){
# 		//alert('uploaded re loaded');
# 		new AjaxUpload('resumeFile_basic', {
# 			action:'/candidate/servlet/FileUploadServlet',
# 			//responseType: 'json',
# 			responseType: 'true',
# 			name: 'resumeFile_basic',
# 			onSubmit : function() {
# 				//alert('11');
# 				document.getElementById("uploadResume_basic").style.display="none";
# 				document.getElementById("uploadingResume_basic").style.display="block";
# 			},
# 			onComplete : function(file,response){
# 				var displayFilename=file;
# 				if(file.length >18){
# 					displayFilename=file.substring(0,18)+"..";
# 				}
# 				response = response.replace(/'/g , '"');
# 				var jsonObj = jQuery.parseJSON(response);
# 				jsonObj["filename"] = displayFilename;
# 				ajaxController.setSessionAttribute('tjindexResumeUploadMsg', jsonObj["MESSAGE"]);
# 				response = JSON.stringify(jsonObj);
# 				ajaxController.setSessionAttribute('tjindexResumeUpload', response);
# 				//window.open('/candidate/register.html', '_blank');
# 				window.location ='/candidate/register.html';
# 			}
# 		});
# 	}
# 	BasicResFileUpload();
#   </script>
# </div>
# <script>
# var name='null';
# var phone='null';
# var email='null';
# //alert("name"+name);
# //alert("phone Num"+phone);
# if((phone!=null && $.trim(phone).length>0)&& phone.indexOf("+91-")!=-1){
#    phone = phone.replace("+91-",'');
# }
#
# FRESHCHAT_VISITORINFO={"name":name,"email":email,"phone":phone};
# </script>
# <script type="text/javascript">
#
# //	alert("Hello");
# 	    var fc_CSS = document.createElement('link');
# 	    fc_CSS.setAttribute('rel', 'stylesheet');
# 	    var fc_isSecured = (window.location && window.location.protocol == 'https:');
# 	    var fc_lang = document.getElementsByTagName('html')[0].getAttribute('lang');
# 	    var fc_rtlLanguages = ['ar', 'he'];
# 	    var fc_rtlSuffix = (fc_rtlLanguages.indexOf(fc_lang) >= 0) ? '-rtl' : '';
# 	    fc_CSS.setAttribute('type', 'text/css');
# 	    fc_CSS.setAttribute('href', ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets1.chat.freshdesk.com') + '/css/visitor' + fc_rtlSuffix + '.css');
# 	    document.getElementsByTagName('head')[0].appendChild(fc_CSS);
# 	    var fc_JS = document.createElement('script');
# 	    fc_JS.type = 'text/javascript';
# 	    fc_JS.defer = true;
# 	    fc_JS.src = ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets.chat.freshdesk.com') + '/js/visitor.js';
# 	    (document.body ? document.body : document.getElementsByTagName('head')[0]).appendChild(fc_JS);
# 	    window.freshchat_setting = '...';
#
# </script>
# <script type="text/javascript">
#
# if(document.getElementById("chat-widget") != undefined){
# document.getElementById("chat-widget").addEventListener("click", function(event){
#     event.preventDefault()
# });
# }
# </script>
# <script type="text/javascript">
# 		$(function(){
# 			$('.nav-search').click(function(e){
# 				$('.common-search').slideToggle();
# 			});
# 			 $('.dropdown-button').dropdown({
# 				  inDuration: 300,
# 				  outDuration: 225,
# 				  constrainWidth: false,
# 				  hover: true,
# 				  gutter: 0,
# 				  belowOrigin: false,
# 				  alignment: 'left',
# 				  stopPropagation: false
# 			}
# 		  );
# 		});
# 	</script>
# <script>
# 	jQuery(function() {
# 		//bottom banner starts
# 		jQuery('.bot-bnr').append('<span class="up-dwn-arrow"></span><span class="bot-bnr-cls"></span>');
# 		jQuery('.bot-bnr').addClass('bot-bnr-expnd',1000);
# 		setTimeout(function(){
# 		jQuery('.bot-bnr').removeClass('bot-bnr-expnd',1000);}, 5000);
# 		jQuery('.bot-bnr-cls').on("click", function() {
# 		  jQuery(this).parent("div").addClass('bot-bnr-csl',1000);
# 		});
# 		jQuery('.up-dwn-arrow').on("click", function() {
# 		  jQuery(this).parent("div").toggleClass('bot-bnr-expnd',1000);
# 		});
# 		//bottom banner ends
# 	});
# </script>
# <!-- Header Ends -->
# <!-- Content Starts   -->
# <div class="ubility-wrap clearfix">
# <!--Cluster related page inclusion start here-->
# <!--Cluster related page inclusion end here-->
# <section class="ubility-lhs clearfix">
# <div class="inside-lhs" id="search-result-cluster">
# <div class="wht-bdr-bx tj-cluster">
# <h4><i class="material-icons">sort</i>Refined By</h4>
# <!--  <div id="clusterRefineHistoryId"></div>-->
# <!--
#   <ul class="tab-filter clearfix">
#
#       <li class="tab-tc" id="tab-tc"><a href="#tabtc">Top Companies</a></li>
#
#
#     <li class="tab-jf" id="tab-jf"><a href="#tabjf">Job Function</a></li>
#
#       <li class="tab-loc" id="tab-loc"><a href="#tabloc">Location</a></li>
#
#
#
#
#       <li class="tab-ind" id="tab-ind"><a href="#tabind">Industry</a></li>
#
#
#
#
#       <li class="tab-sal" id="tab-sal"><a href="#tabsal">Salary</a></li>
#
#   </ul>
# -->
# <div id="tj-tab-container-clusterId">
# <div id="clusterDataInitial">
# <ul class="collapsible" data-collapsible="expandable">
# <li id="tabtc">
# <div class="collapsible-header active"><h6>Companies</h6></div>
# <div class="cluster-scroll collapsible-body">
# <ul>
# <div id="comp_show">
# <li>
# <input id="com_0" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=Mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=Python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=morgan+stanley+pvt+ltd&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=Mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=Python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=morgan+stanley+pvt+ltd&amp;gadLink=View Jobs By This Company','Morgan Stanley Pvt Ltd');" type="checkbox"/>
# <label for="com_0">
# <span title="Morgan Stanley Pvt Ltd">
#                 Morgan Stanley Pvt Ltd
#                 </span> <span class="grey-text">(12)</span></label>
# </li>
# <li>
# <input id="com_1" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=Mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=Python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=crimson+interactive+pvt+ltd&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=Mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=Python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=crimson+interactive+pvt+ltd&amp;gadLink=View Jobs By This Company','Crimson Interactive Pvt Ltd');" type="checkbox"/>
# <label for="com_1">
# <span title="Crimson Interactive Pvt Ltd">
#                 Crimson Interactive Pvt Ltd
#                 </span> <span class="grey-text">(3)</span></label>
# </li>
# <li>
# <input id="com_2" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=Mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=Python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=hiotron+india+pvt+ltd&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=Mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=Python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=hiotron+india+pvt+ltd&amp;gadLink=View Jobs By This Company','Hiotron India Pvt Ltd');" type="checkbox"/>
# <label for="com_2">
# <span title="Hiotron India Pvt Ltd">
#                 Hiotron India Pvt Ltd
#                 </span> <span class="grey-text">(3)</span></label>
# </li>
# <li>
# <input id="com_3" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=Mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=Python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=verisk+analytics+india+private+limited&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=Mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=Python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=verisk+analytics+india+private+limited&amp;gadLink=View Jobs By This Company','Verisk Analytics India Private Limited');" type="checkbox"/>
# <label for="com_3">
# <span title="Verisk Analytics India Private Limited">
#                 Verisk Analytics India Private..
#                 </span> <span class="grey-text">(3)</span></label>
# </li>
# <li>
# <input id="com_4" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=Mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=Python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=boyen+haddin+consultants+llp&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=Python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=Mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=Python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=boyen+haddin+consultants+llp&amp;gadLink=View Jobs By This Company','Boyen Haddin Consultants Llp');" type="checkbox"/>
# <label for="com_4">
# <span title="Boyen Haddin Consultants Llp">
#                 Boyen Haddin Consultants Llp
#                 </span> <span class="grey-text">(2)</span></label>
# </li>
# <li>
# ...
# 	z-index: 9999999;
# 	overflow: hidden;
# 	background-position: center;
# 	background-repeat: no-repeat;
# 	width: 510px;
# 	height: 310px;
# 	border-radius: 8px;
# 	margin: auto;
# 	font-size: 14px;
# 	padding: 20px;
# 	display: none;
# }
#
# .registration-message p {
# 	margin: 0px;
# 	padding: 0 30px 0px 30px;
# 	text-align: center;
# 	line-height: 21px;
# 	font-size: 14px;
# }
#
# .registration-message .registration-close {
# 	color: #ccc;
# 	font-size: 16px;
# 	font-weight: bold;
# 	top: 10px;
# 	right: 15px;
# 	position: absolute;
# 	cursor: pointer;
# }
#
# .registration-message .registration-btn-close {
# 	text-decoration: none;
# 	color: #fff;
# 	font-size: 12px;
# 	background-color: #EE2525;
# 	text-align: center;
# 	-webkit-transition: .2s ease-out;
# 	transition: .2s ease-out;
# 	cursor: pointer;
# 	padding: 10px 20px;
# 	font-weight: bold;
# 	border:none;
# }
#
# .registration-message .heading {
# 	color: #01439F;
# 	font-size: 18px;
# 	font-weight: bold;
# 	text-align: center;
# 	padding: 24px 0;
# 	margin: 0px;
# }
# </style>
# <div class="registration-overlay"></div>
# <div class="registration-message">
# <span class="registration-close" oncli="">X</span>
# <h2 class="heading">We care for you!</h2>
# <p>
# <strong>Please note:</strong> TimesJobs or its recruiting partners do
# 		not charge money or fee from candidates for recruitment or anything
# 		else. If anyone calls you asking for money or payment for
# 		registration, application process, resume service, etc, then please
# 		report it immediately to <a href="mailto:corporatecare@timesinternet.in">corporatecare@timesinternet.in</a>
# <br/>
# <br/>
# <button class="registration-btn-close">OK</button>
# </p>
# </div>
# <script>
# 	let isFDivClosed = false;
#
# 	$(document).ready(function(){
# 		getFraudBannerShowStatus();
# 	})
#
# 	function registerFraudBannerEvents(){
# 		$(".registration-overlay, .registration-message").css("display", "block");
# 		/* $(".registration-close, .registration-btn-close").on(
# 			"click",
# 			function() {
# 				$(".registration-overlay, .registration-message").css("display", "none");
# 				updateStatus();
# 			}); */
# 	}
# 	/*
# 	$(window).on(
# 			'load',
# 			function() {
# 				$(".registration-overlay, .registration-message").css("display", "block");
# 			});
# 	*/
# 	$(".registration-close, .registration-btn-close").on("click", function() {
# 				$(".registration-overlay, .registration-message").css("display", "none");
# 				updateStatus();
# 			});
#
#
#  	function updateStatus(){
# 		if(isFDivClosed === false){
# 			updateFraudBannerStatus();
# 		}
# 	}
#
# 	setTimeout(autoFDivClose, 30000);
#
# 	function autoFDivClose(){
# 		if(isFDivClosed === false){
# 			//updateFraudBannerStatus();
# 			isFDivClosed = true;
# 			$(".registration-overlay, .registration-message").css("display", "none");
# 		}
# 	}
#
# 	function updateFraudBannerStatus(){
# 		var context="/candidate/";
# 		jQuery.ajax({
#  					url:context + 'updateFraudBannerStatus.json?&source=TJWEB',
#  					beforeSend:function(){
# 						console.log("beforeSend... updateFraudBannerStatus");
# 						},
# 					success:function(jsonResp){
#    	 					 console.log('updateFraudBannerStatus loaded successfully : ',jsonResp)
# 						},
# 					complete:function(){
# 						console.log("complete... updateFraudBannerStatus");
# 						isFDivClosed = true;
# 						$(".registration-overlay, .registration-message").css("display", "none");
# 					}
#  				});
# 	}
#
# 	function getFraudBannerShowStatus(){
# 		var context="/candidate/";
# 		jQuery.ajax({
#  					url:context + 'getFraudBannerShowStatus.json?&source=TJWEB',
#  					beforeSend:function(){
# 						console.log("beforeSend... updateFraudBannerStatus");
# 						},
# 					success:function(jsonResp){
#    	 					 console.log('updateFraudBannerStatus loaded successfully : ',jsonResp)
#    	 					 console.log('jsonResp : ',jsonResp)
#    	 					 if(jsonResp != null && jsonResp['showfraudbanner'] != null && jsonResp['showfraudbanner'] === true){
#    	 					 	isFDivClosed = false;
#    	 					 	registerFraudBannerEvents();
#    	 					 }
# 						},
# 					complete:function(){
#
# 					}
#  				});
# 	}
#
#
#
# </script>
# <!-- Footer Ends   -->
# <script type="text/javascript">
#         var GB_ROOT_DIR = "/candidate/greybox/";
#     </script>
# <link href="https://static.timesjobs.com/newtj_css/css/tj_css/personlisation/gb_styles.css" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://static.timesjobs.com/newtj_js/scripts/groupJs/searchResultTempGroup.js?v=7.1.7" type="text/javascript"></script>
# <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
# <!--[if IE]><script src="https://static.timesjobs.com/newtj_js/scripts/html5.js"></script><![endif]-->
# <script type="text/javascript">
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6036484" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#
#   function trackAjaxSRPresult(url, type) {
# 		var title = document.getElementsByTagName("title")[0].innerHTML;
# 		title = title.replace("TimesJobs.com", type + " Jobs");
# 		title = title.concat(" | TimesJobs.com");
#
# 		var t = "2", n = "6036484", r = "", i = encodeURIComponent(url), s = "", o = "", u = encodeURIComponent(title), a = "", f = "2.0", l = "1";
# 		var c = document.createElement("img");
# 		c.src = "https://sb.scorecardresearch.com/p?c1=" + t + "&c2=" + n +"&c3=" + r + "&c4=" + i + "&c5=" + s + "&c6=" + o + "&c8=" + u + "&c15=" + a + "&cv=" + f + "&cj=" + l + "&ns__t=" + (new Date).getTime();
# 		document.body.appendChild(c);
# 	}
#
#
# </script>
# <noscript>
# <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6036484&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <script type="text/javascript">
# /*!
# * jQuery Cookie Plugin v1.3.1
# * https://github.com/carhartl/jquery-cookie
# *
# * Copyright 2013 Klaus Hartl
# * Released under the MIT license
# */
# (function (factory) {
# if (typeof define === 'function' && define.amd && define.amd.jQuery) {
# // AMD. Register as anonymous module.
# define(['jquery'], factory);
# } else {
# // Browser globals.
# factory(jQuery);
# }
# }(function ($) {
#
# var pluses = /\+/g;
#
# function raw(s) {
# return s;
# }
#
# function decoded(s) {
# return decodeURIComponent(s.replace(pluses, ' '));
# }
#
# function converted(s) {
# if (s.indexOf('"') === 0) {
# // This is a quoted cookie as according to RFC2068, unescape
# s = s.slice(1, -1).replace(/\\"/g, '"').replace(/\\\\/g, '\\');
# }
# try {
# return config.json ? JSON.parse(s) : s;
# } catch(er) {}
# }
#
# var config = $.cookie = function (key, value, options) {
#
# // write
# if (value !== undefined) {
# options = $.extend({}, config.defaults, options);
#
# if (typeof options.expires === 'number') {
# var days = options.expires, t = options.expires = new Date();
# t.setDate(t.getDate() + days);
# }
#
# value = config.json ? JSON.stringify(value) : String(value);
#
# return (document.cookie = [
# encodeURIComponent(key), '=', config.raw ? value : encodeURIComponent(value),
# options.expires ? '; expires=' + options.expires.toUTCString() : '', // use expires attribute, max-age is not supported by IE
# options.path ? '; path=' + options.path : '',
# options.domain ? '; domain=' + options.domain : '',
# options.secure ? '; secure' : ''
# ].join(''));
# }
#
# // read
# var decode = config.raw ? raw : decoded;
# var cookies = document.cookie.split('; ');
# var result = key ? undefined : {};
# for (var i = 0, l = cookies.length; i < l; i++) {
# var parts = cookies[i].split('=');
# var name = decode(parts.shift());
# var cookie = decode(parts.join('='));
#
# if (key && key === name) {
# result = converted(cookie);
# break;
# }
#
# if (!key) {
# result[name] = converted(cookie);
# }
# }
#
# return result;
# };
#
# config.defaults = {};
#
# $.removeCookie = function (key, options) {
# if ($.cookie(key) !== undefined) {
# $.cookie(key, '', $.extend(options, { expires: -1 }));
# return true;
# }
# return false;
# };
#
# }));
# </script>
# <script type="text/javascript">
# 	jQuery.cookie('previous_browser_url', $.cookie('current_browser_url'));
# 	jQuery.cookie('current_browser_url', window.location.href);
# 	//setCookie('previous_browser_url',getCookie('current_browser_url'));
# 	//setCookie('current_browser_url', window.location.href);
# </script>
# <script type="text/javascript">
# 	function getPredefinedActionName(url){
# 		var returnActionName = "";
# 		var from = url.lastIndexOf("/");
# 		var to = url.indexOf("?",from);
# 		if(-1!=to){
# 			returnActionName = url.substring(from,to);
# 		}else{
# 			returnActionName = url.substring(from);
# 		}
# 		return returnActionName;
# 	}
# 	</script>
# <script type="text/javascript">
#
# var notification_timeout = 10000;
# var notification_cache = true;
# function ping(url){
#  var ImageObject = new Image();
#  ImageObject.src = url; //e.g. logo
# }
# var cand_context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  cand_context="/candidate/";
# 		  //alert("bingo");
# 	}
#
# 		function getMailInBoxUnreadCount(){
# 			var rurl=cand_context+"inbox-message-get-unread-count.html";
# 			jQuery.ajax({
# 				cache:notification_cache,
# 				url:rurl,
# 				success:function(data){
# 					console.log("success... inbox-message-get-unread-count.html"+'');
# 				},
# 				error: function(x, textStatus, m) {
# 					console.log("Failed"+m);
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            //do something. Try again perhaps?
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    	}
# 			});
# 		}
#
# 		function getDistinctEmployerCounts(){
# 		 var rurl=cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_RE";
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:rurl,
# 			success:function(data){
# 				//alert("RE-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_re").html(data);
# 				jQuery("#mytj_header_re").html(data);
# 				jQuery("#homeindex_inbox_re").html(data);
# 				jQuery("#headerhome_inbox_re").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			            console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			            //do something. Try again perhaps?
# 			        }
# 		    }
#
# 		});
# 	//alert("call in progress...");
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV",
# 			success:function(data){
# 				//alert("PV-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_pv").html(data);
# 				jQuery("#mytj_header_pv").html(data);
# 				jQuery("#homeindex_inbox_pv").html(data);
# 				jQuery("#headerhome_inbox_pv").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV"+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    }
# 		});
# 	 }
# 	function displayLoading(div){
# 	if(1 == tab || 2 == tab || 4 == tab || 5 == tab  ){
# 			jQuery(div).append("<div class='loading'>&nbsp;</div>");
# 	}
# }
# </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "location": {
#     "@type": "Place",
#     "address": "TimesJobs.com, Times Business Solutions (A Division of Times Internet Ltd.), Times Center (Digital Content Production Facility), FC - 6, (Ground Floor), Sector 16 A, Film City, NOIDA - 201 301, Uttar Pradesh, India"
#   },
#   "name": "TimesJobs.com",
#   "description": "TimesJobs: India's Leading Job Portal",
#   "logo": "https://static.timesjobs.com/images_cand/tj_images/logos/tj_logo_300x300.jpg",
#   "url": "https://www.timesjobs.com",
#   "email": "timesjobs@timesgroup.com"
# }
# </script>
# <script type="application/ld+json">
# {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "https://www.timesjobs.com",
#     "potentialAction": {
#       "@type": "SearchAction",
#       "target": "https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords={search_term_string}",
#       "query-input": "required name=search_term_string"
#     }
# }
# </script>
# <!--Common Template Included in all files end here  -->
# <!--google analytics start-->
# <script type="text/javascript">
# 	var _gaq = _gaq || [];
#
#
#
#
#
#
#
#
# 			_gaq.push(['_setAccount', 'UA-1688637-1']);
#
#
#   _gaq.push(['_trackPageview']);
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
#   function trackClickEvent(category,action){
# 		_gaq.push(['_trackEvent',category,action]);
# 	}
# </script>
# <!--google analytics ends-->
# <img alt="" border="0" height="1" src="https://tracking.sokrati.com/site?client_id=60&amp;product_category=Site_Search" width="1"/>
# <script type="text/javascript">
#
# 	function removeSpecificRefineNew(urltoHit){
#  	getSRPResultByDwrNew(urltoHit);
#  	return false;
#  }
#
#  function getSRPResultByDwrNew(urlToHit) {
# 		jQuery( "#refine-opt-search-datewise a" ).removeClass( "refinejobsopt" );
# 		jQuery("#defualtSelectedDate").addClass( "refinejobsopt" );
# 		jQuery("#searchResultData").remove();
# 		jQuery("#searchResultContents").html(dataImageLoader);
# 		var matchStr=urlToHit.match("&undo=(.*)&undoValue");//For Selecting tab on Cluster
#
# 		ajaxController.getDWRBasedWebResponse(urlToHit,function(data) {
# 							if (data != null && data != 'undefined') {
# 								jQuery("#searchResultContents").html(data);
#
# 								console.info("matchStr=="+matchStr);
# 								if(chkNull(matchStr)){
# 									console.info("matched text at posotion 1="+matchStr[1]);
# 									showSelectedTabData(matchStr[1]);
# 								}
# 								if(matchStr==null && urlToHit.indexOf("undo=")!=-1){
# 									//jQuery( ".refined-bx" ).tabs("refresh");
#
# 								}
# 								//For making initial tab selected
# 								if(urlToHit.indexOf("&reset")!=-1){
# 									console.info("inside reset all tab");
# 									//jQuery( ".refined-bx" ).tabs("refresh");
# 								}
# 							} else {
# 								jQuery("#searchResultContents").html("Oops! There seems to be a technical problem. Please try again");
# 							}
# 						});
# 						return false;
# 	}
#
#
#
# 	if (top != self){
# 		window.open(self.location.href,"_top");
# 	}
# 	var siteId='1040';
# 	var stype = 'timesjobs.com';
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://ceoconnect.in/feedback/scripts/feedbackInc.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
# </div>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/lightBox.js" type="text/javascript"></script>
# <div class="modal" id="light-box-popup">
# <span class="material-icons close-modal modal-action modal-close">close</span>
# <div class="modal-content" id="light-box-popup-content"></div>
# </div>
# <!-- <script type="text/javascript">
#   $(document).ready(function(){
# 	    // the "href" attribute of the modal trigger must specify the modal ID that wants to be triggered
# 	    $('.modal').modal();
# 	  });
#
#   </script> -->
# <!--  ##########################  JobBuzz Ads  ################## -->
# </body>
# </html>

# %%
from bs4 import BeautifulSoup
import requests
#get data from html page toa file text
f=requests.get("https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=mumbai&cboWorkExp1=0").text

soup=BeautifulSoup(f,'lxml')
tags=soup.find_all('span')
for i in tags:
    print(i.text)
#print(soup)
# Out:
# close
#
# Live Chat (10am to 6pm IST)
# 1
#
# Job Alerts(10)
# 3 hrs ago
#
#
#
#
#                 Morgan Stanley Pvt Ltd
#
# (12)
#
#                 Crimson Interactive Pvt Ltd
#
# (3)
#
#                 Hiotron India Pvt Ltd
#
# (3)
#
#                 Verisk Analytics India Private..
#
# (3)
#
#                 Boyen Haddin Consultants Llp
#
# (2)
#
#                 Dg7
#
# (2)
#
#                 Interactive Brokers
#
# (2)
#
#                 Larsen & Toubro Infotech L..
#
# (2)
#
#                 Pagalguy
#
# (2)
#
#                 Publicis Groupe
#
# (2)
#
#                 Rangam Infotech Pvt. Ltd.
#
# (2)
#
#                 Tac Security
#
# (2)
#
#                 World Resources Institute
#
# (2)
#
#                 Abc Consultants Pvt Ltd
#
# (1)
#
#                 Axionconnect Infosolutions Pvt..
#
# (1)
#
#                 Feedspot
#
# (1)
#
#                 Headhuntersinc Consultancy Pri..
#
# (1)
#
#                 Ingram Micro Inc.
#
# (1)
#
#                 L&t Technology Services Li..
#
# (1)
#
#                 Nec Software Solutions (india)..
#
# (1)
#
#                 Procter & Gamble (p&g)
#
# (1)
#
#                 Propellum Infotech Private Lim..
#
# (1)
#
#                 Qs Quacquarelli Symonds India ..
#
# (1)
#
#                 Quacquarelli Symonds Pvt Ltd
#
# (1)
#
#                 Sitel
#
# (1)
#
#                 Walt Disney
#
# (1)
#
#                 Wri India
#
# (1)
#  IT Software : Software Product..
#
# (62
#                       )
#  HR/PM/IR/Training
#
# (3
#                       )
#  IT Hardware : Hardware Product..
#
# (3
#                       )
#  Banks/Insurance/Financial Serv..
#
# (3
#                       )
#  Marketing/MR/Media Planning
#
# (2
#                       )
# (10)
# (9)
# (8)
#
#                     IT-Software
#
# (
#                     19
#                     )
#
#                     Financial Services/Stockbrokin..
#
# (
#                     14
#                     )
#
#                     IT-Hardware/Networking
#
# (
#                     11
#                     )
#
#                     Telecom
#
# (
#                     10
#                     )
#
#                     Software Services
#
# (
#                     6
#                     )
#
#                     Consulting Services
#
# (
#                     5
#                     )
#
#                     Advertising/PR/Event Managemen..
#
# (
#                     4
#                     )
#
#                     CRM/CallCentres/BPO/ITES/Med.T..
#
# (
#                     4
#                     )
#
#                     Educational/Training
#
# (
#                     4
#                     )
#
#                     Manufacturing/Industrial
#
# (
#                     4
#                     )
#
#                     Research/Surveyor/MR
#
# (
#                     4
#                     )
#
#                     Entertainment/Media
#
# (
#                     3
#                     )
#
#                     Banking
#
# (
#                     2
#                     )
#
#                     Recruitment/Placement Agencies
#
# (
#                     1
#                     )
#
#                     Consumer Durables/FMCG
#
# (
#                     1
#                     )
#
#                     NGO/Social Services
#
# (
#                     1
#                     )
#
#                     Internet/Dot com/ISP
#
# (
#                     1
#                     )
#
#                     Others
#
# (
#                     3
#                     )
# (9)
# (61)
# (1)
# (1)
# (71)
# (1)
# 72 Job Found
# 72
# 72
# Job Found
# 72
#
#
#                 Morgan Stanley Pvt Ltd
#
# (12)
#
#                 Crimson Interactive Pvt Ltd
#
# (3)
#
#                 Hiotron India Pvt Ltd
#
# (3)
#
#                 Verisk Analytics India Private..
#
# (3)
#
#                 Boyen Haddin Consultants Llp
#
# (2)
#
#                 Dg7
#
# (2)
#
#                 Interactive Brokers
#
# (2)
#
#                 Larsen & Toubro Infotech L..
#
# (2)
#
#                 Pagalguy
#
# (2)
#
#                 Publicis Groupe
#
# (2)
#
#                 Rangam Infotech Pvt. Ltd.
#
# (2)
#
#                 Tac Security
#
# (2)
#
#                 World Resources Institute
#
# (2)
#
#                 Abc Consultants Pvt Ltd
#
# (1)
#
#                 Axionconnect Infosolutions Pvt..
#
# (1)
#
#                 Feedspot
#
# (1)
#
#                 Headhuntersinc Consultancy Pri..
#
# (1)
#
#                 Ingram Micro Inc.
#
# (1)
#
#                 L&t Technology Services Li..
#
# (1)
#
#                 Nec Software Solutions (india)..
#
# (1)
#
#                 Procter & Gamble (p&g)
#
# (1)
#
#                 Propellum Infotech Private Lim..
#
# (1)
#
#                 Qs Quacquarelli Symonds India ..
#
# (1)
#
#                 Quacquarelli Symonds Pvt Ltd
#
# (1)
#
#                 Sitel
#
# (1)
#
#                 Walt Disney
#
# (1)
#
#                 Wri India
#
# (1)
#  IT Software : Software Product..
#
# (62
#                       )
#  HR/PM/IR/Training
#
# (3
#                       )
#  IT Hardware : Hardware Product..
#
# (3
#                       )
#  Banks/Insurance/Financial Serv..
#
# (3
#                       )
#  Marketing/MR/Media Planning
#
# (2
#                       )
# (10)
# (9)
# (8)
#
#                     IT-Software
#
# (
#                     19
#                     )
#
#                     Financial Services/Stockbrokin..
#
# (
#                     14
#                     )
#
#                     IT-Hardware/Networking
#
# (
#                     11
#                     )
#
#                     Telecom
#
# (
#                     10
#                     )
#
#                     Software Services
#
# (
#                     6
#                     )
#
#                     Consulting Services
#
# (
#                     5
#                     )
#
#                     Advertising/PR/Event Managemen..
#
# (
#                     4
#                     )
#
#                     CRM/CallCentres/BPO/ITES/Med.T..
#
# (
#                     4
#                     )
#
#                     Educational/Training
#
# (
#                     4
#                     )
#
#                     Manufacturing/Industrial
#
# (
#                     4
#                     )
#
#                     Research/Surveyor/MR
#
# (
#                     4
#                     )
#
#                     Entertainment/Media
#
# (
#                     3
#                     )
#
#                     Banking
#
# (
#                     2
#                     )
#
#                     Recruitment/Placement Agencies
#
# (
#                     1
#                     )
#
#                     Consumer Durables/FMCG
#
# (
#                     1
#                     )
#
#                     NGO/Social Services
#
# (
#                     1
#                     )
#
#                     Internet/Dot com/ISP
#
# (
#                     1
#                     )
#
#                     Others
#
# (
#                     3
#                     )
# (9)
# (61)
# (1)
# (1)
# (71)
# (1)
# (More Jobs)
# Mumbai,  Dombivali,  Kalyan,  Navi Mumbai,  Thane
#
# python  ,  Css
#
#
# directions_walk
# Walk-in Details 10-Apr-2023 - 08-Jun-2023  09:00 AM - 04:00 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
#
#
#
#
# Posted 4 days ago
#
# Posted 4 days ago
# (More Jobs)
# Mumbai,  Dombivali,  Kalyan,  Navi Mumbai,  Thane
#
# python  ,  new
#
#
# directions_walk
# Walk-in Details 13-Mar-2023 - 12-May-2023  09:30 AM - 05:00 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
#
#
#
#
# Posted a month ago
#
# Posted a month ago
# (More Jobs)
# Mumbai,  Dombivali,  Kalyan,  Navi Mumbai,  Thane
#
# python  ,  hire
#
#
# directions_walk
# Walk-in Details 29-Mar-2023 - 27-May-2023  10:30 AM - 04:30 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
#
#
#
#
# Posted few days ago
#
# Posted few days ago
# (More Jobs)
# Mumbai,  Dombivali,  Kalyan,  Navi Mumbai,  Thane
#
#
#           core python  ,  django
#
#
# directions_walk
# Walk-in Details 10-Mar-2023 - 08-May-2023  09:00 AM - 05:00 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
#
#
#
#
# Posted a month ago
#
# Posted a month ago
# (More Jobs)
# Mumbai,  Dombivali,  Kalyan,  Navi Mumbai,  Thane
#
#
#           internship  ,  python  ,  pune  ,  maharashtra
#
#
# directions_walk
# Walk-in Details 26-Feb-2023 - 24-Apr-2023  10:00 AM - 06:30 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
#
#
#
#
# Posted a month ago
#
# Posted a month ago
# (More Jobs)
# Mumbai,  Dombivali,  Kalyan,  Navi Mumbai,  Thane
#
#
#           django  ,  internship
#
#
# directions_walk
# Walk-in Details 25-Mar-2023 - 24-May-2023  10:30 AM - 04:00 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
#
#
#
#
# Posted few days ago
#
# Posted few days ago
# Mumbai
#
#
#           design  ,  engineering  ,  designing  ,  building
#
#
#
#
#
#
# Posted 4 days ago
#
# Posted 4 days ago
# Mumbai,  Bengaluru / Bangalore
#
#
#           c    ,  information technology  ,  java  ,  software engineering  ,  c#  ,  python  ,  perl scripting  ,  sybase  ,  unix  ,  storage  ,  database  ,  linux  ,  debugging  ,  technical skills  ,  business applications  ,  c  ,  mobile  ,  team player  ,  windows  ,  infrastructure
#
#
#
#
#
#
# Posted a month ago
#
# Posted a month ago
# (More Jobs)
# Bengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Mumbai,  Pune
#
# python  ,  Django  ,  perl  ,  Shell  ,  Web Technologies  ,  Http  ,  html
#
#
#
#
#
#
# Posted a month ago
#
# Posted a month ago
# (More Jobs)
# Bengaluru / Bangalore,  Chennai,  Delhi/NCR,  Hyderabad/Secunderabad,  Mumbai
#
# Python
#
#
#
#
#
#
# Work from Home
#
# Posted 6 days ago
#
#
# Work from Home
#
# Posted 6 days ago
# Mumbai
#
#
#           sql  ,  database  ,  java  ,  python
#
#
#
#
#
# Posted few days ago
#
# Posted few days ago
# Mumbai
#
#
#           c    ,  fx  ,  java  ,  python
#
#
#
#
#
# Posted a month ago
#
# Posted a month ago
# Mumbai
#
#
#           c    ,  scala  ,  fx  ,  python
#
#
#
#
#
# Posted a month ago
#
# Posted a month ago
# Mumbai
#
# python  ,  scala  ,  fx  ,  java
#
#
#
#
#
#
# Posted a month ago
#
# Posted a month ago
# Mumbai
#
# python  ,  web development  ,   keep learning
#
#
#
#
#
#
# Posted 4 days ago
#
# Posted 4 days ago
# Mumbai
#
# python  ,  problem solving  ,  mining  ,  sql
#
#
#
#
#
#
# Posted few days ago
#
# Posted few days ago
# Mumbai
#
#
#           orchestration  ,  python  ,  mining  ,  leadership skills
#
#
#
#
#
#
# Posted few days ago
#
# Posted few days ago
# Mumbai
#
#
#           sql  ,  linux  ,  python  ,  nosql  ,  php
#
#
#
#
#
#
# Posted few days ago
#
# Posted few days ago
# Mumbai
#
#
#           algorithms  ,  linux  ,  python  ,  machine learning
#
#
#
#
#
#
# Posted a month ago
#
# Posted a month ago
# Mumbai
#
# python  ,  github  ,  git  ,  html5  ,  mvc  ,  javascript
#
#
#
#
#
#
# Posted 1 day ago
#
# Posted 1 day ago
# Gurgaon,  Mumbai,  Pune,  Bengaluru / Bangalore
#
#
#           sql  ,  cloud computing  ,  python  ,  machine learning
#
#
#
#
#
#
# Posted 2 days ago
#
# Posted 2 days ago
# Mumbai
#
#
#           database  ,  security  ,  python  ,  problem solving  ,  mining  ,  nosql
#
#
#
#
#
#
# Posted few days ago
#
# Posted few days ago
# Mumbai
#
#
#           bi  ,  sql  ,  linux  ,  python  ,  nosql  ,  php
#
#
#
#
#
#
# Posted few days ago
#
# Posted few days ago
# Mumbai
#
#
#           c    ,  scala  ,  fx  ,  linux  ,  python  ,  windows
#
#
#
#
#
#
# Posted a month ago
#
# Posted a month ago
# Mumbai
#
#
#           c    ,  scala  ,  fx  ,  linux  ,  python  ,  windows
#
#
#
#
#
#
# Posted a month ago
#
# Posted a month ago
#
#
#
# Careers with
# Times Business Solutions
# Click Here
#
#
#
# Careers with
# Times Business Solutions
# Click Here
#
# Careers with
# Times Business Solutions
# Click Here
#
# powered by
# Get relevant jobs in your inbox
#
#
#
#
#
#
#
#
#
# View Institutes
#
# X
# close

# %%
tag=soup.find_all('ul')
for i in tag:
    print(i.text)
# Out:
# TimesJobs
# JobBuzz
#
# Gulf Jobs
# Career Insight
#
#
# call0120 6358222
#
# Live Chat (10am to 6pm IST)
#
#
#
#
#
#
#
# notifications_none
# 1
#
#
#
#
# To see all recommended jobs, profile views, recruiter's contacted information, updates and more...
#
# Login
# or
# Register
#
#
#
#
#
# Login to View Notifications!
#
#
#
#
# Forgot Password?
#
#
#
#
#        	      Login-ID/Password cannot be left blank. Enter the full email ID (like: ram@gmail.com), if you are using registered email-id for login.
#
#
#
#
#
#
#
#
#
# Job Alerts(10)
#
# 5 Matching Jobs 3 hrs ago
#
#
#
#
#
#
#
#
#
#
# Login
#
#
# Register
#
#
#
#
# Job Alerts(10)
#
# 5 Matching Jobs 3 hrs ago
#
#
#
#
#
#
#
#
# Companies
#
#
#
#
#
#
#
#                 Morgan Stanley Pvt Ltd
#                  (12)
#
#
#
#
#
#                 Verisk Analytics India Private..
#                  (4)
#
#
#
#
#
#                 Crimson Interactive Pvt Ltd
#                  (3)
#
#
#
#
#
#                 Hiotron India Pvt Ltd
#                  (3)
#
#
#
#
#
#                 Boyen Haddin Consultants Llp
#                  (2)
#
#
#
#
#
#                 Dg7
#                  (2)
#
#
#
#
#
#                 Interactive Brokers
#                  (2)
#
#
#
#
#
#                 Larsen & Toubro Infotech L..
#                  (2)
#
#
#
#
#
#                 Pagalguy
#                  (2)
#
#
#
#
#
#                 Publicis Groupe
#                  (2)
#
#
#
#
#
#                 Rangam Infotech Pvt. Ltd.
#                  (2)
#
#
#
#
#
#                 Tac Security
#                  (2)
#
#
#
#
#
#                 World Resources Institute
#                  (2)
#
#
#
#
#
#                 Abc Consultants Pvt Ltd
#                  (1)
#
#
#
#
#
#                 Axionconnect Infosolutions Pvt..
#                  (1)
#
#
#
#
#
#                 Feedspot
#                  (1)
#
#
#
#
#
#                 Headhuntersinc Consultancy Pri..
#                  (1)
#
#
#
#
#
#                 Ingram Micro Inc.
#                  (1)
#
#
#
#
#
#                 Jai Kisan
#                  (1)
#
#
#
#
#
#                 L&t Technology Services Li..
#                  (1)
#
#
#
#
#
#                 Nec Software Solutions (india)..
#                  (1)
#
#
#
#
#
#                 Paytm
#                  (1)
#
#
#
#
#
#                 Procter & Gamble (p&g)
#                  (1)
#
#
#
#
#
#                 Propellum Infotech Private Lim..
#                  (1)
#
#
#
#
#
#                 Qs Quacquarelli Symonds India ..
#                  (1)
#
#
#
#
#
#                 Quacquarelli Symonds Pvt Ltd
#                  (1)
#
#
#
#
#
#                 Sitel
#                  (1)
#
#
#
#
#
#                 Wri India
#                  (1)
#
#
#
#
#
#
# Job Function
#
#
#
#
#
#  IT Software : Software Product..
#                        (63
#                       )
#
#
#
#  IT Hardware : Hardware Product..
#                        (3
#                       )
#
#
#
#  Banks/Insurance/Financial Serv..
#                        (3
#                       )
#
#
#
#  HR/PM/IR/Training
#                        (2
#                       )
#
#
#
#  Marketing/MR/Media Planning
#                        (2
#                       )
#
#
#
#
#
#
# Location
#
#
#
#
#
# Pune
#                       (8)
#
#
#
# Navi Mumbai
#                       (8)
#
#
#
# Thane
#                       (7)
#
#
#
#
#
#
# Industry
#
#
#
#
#
#
#                     IT-Software
#                      (
#                     17
#                     )
#
#
#
#
#                     Financial Services/Stockbrokin..
#                      (
#                     15
#                     )
#
#
#
#
#                     IT-Hardware/Networking
#                      (
#                     12
#                     )
#
#
#
#
#                     Telecom
#                      (
#                     11
#                     )
#
#
#
#
#                     Software Services
#                      (
#                     6
#                     )
#
#
#
#
#                     Consulting Services
#                      (
#                     5
#                     )
#
#
#
#
#                     Advertising/PR/Event Managemen..
#                      (
#                     4
#                     )
#
#
#
#
#                     CRM/CallCentres/BPO/ITES/Med.T..
#                      (
#                     4
#                     )
#
#
#
#
#                     Educational/Training
#                      (
#                     4
#                     )
#
#
#
#
#                     Manufacturing/Industrial
#                      (
#                     4
#                     )
#
#
#
#
#                     Research/Surveyor/MR
#                      (
#                     4
#                     )
#
#
#
#
#                     Banking
#                      (
#                     3
#                     )
#
#
#
#
#                     Entertainment/Media
#                      (
#                     2
#                     )
#
#
#
#
#                     Internet/Dot com/ISP
#                      (
#                     2
#                     )
#
#
#
#
#                     Recruitment/Placement Agencies
#                      (
#                     1
#                     )
#
#
#
#
#                     Consumer Durables/FMCG
#                      (
#                     1
#                     )
#
#
#
#
#                     NGO/Social Services
#                      (
#                     1
#                     )
#
#
#
#
#                     Others
#                      (
#                     3
#                     )
#
#
#
#
#
#
# Salary
#
#
#
#
# 0-2 lacs
#                     (7)
#
#
#
# 2-4 lacs
#                     (63)
#
#
#
# 4-6 lacs
#                     (1)
#
#
#
# 6-10 lacs
#                     (1)
#
#
#
#
#
# Job Type
#
#
#
#
#
# Regular
# 	                    (71)
#
#
#
# Work from home
# 	                    (1)
#
#
#
#
#
#
#
#
#
#
#
#                 Morgan Stanley Pvt Ltd
#                  (12)
#
#
#
#
#
#                 Verisk Analytics India Private..
#                  (4)
#
#
#
#
#
#                 Crimson Interactive Pvt Ltd
#                  (3)
#
#
#
#
#
#                 Hiotron India Pvt Ltd
#                  (3)
#
#
#
#
#
#                 Boyen Haddin Consultants Llp
#                  (2)
#
#
#
#
#
#                 Dg7
#                  (2)
#
#
#
#
#
#                 Interactive Brokers
#                  (2)
#
#
#
#
#
#                 Larsen & Toubro Infotech L..
#                  (2)
#
#
#
#
#
#                 Pagalguy
#                  (2)
#
#
#
#
#
#                 Publicis Groupe
#                  (2)
#
#
#
#
#
#                 Rangam Infotech Pvt. Ltd.
#                  (2)
#
#
#
#
#
#                 Tac Security
#                  (2)
#
#
#
#
#
#                 World Resources Institute
#                  (2)
#
#
#
#
#
#                 Abc Consultants Pvt Ltd
#                  (1)
#
#
#
#
#
#                 Axionconnect Infosolutions Pvt..
#                  (1)
#
#
#
#
#
#                 Feedspot
#                  (1)
#
#
#
#
#
#                 Headhuntersinc Consultancy Pri..
#                  (1)
#
#
#
#
#
#                 Ingram Micro Inc.
#                  (1)
#
#
#
#
#
#                 Jai Kisan
#                  (1)
#
#
#
#
#
#                 L&t Technology Services Li..
#                  (1)
#
#
#
#
#
#                 Nec Software Solutions (india)..
#                  (1)
#
#
#
#
#
#                 Paytm
#                  (1)
#
#
#
#
#
#                 Procter & Gamble (p&g)
#                  (1)
#
#
#
#
#
#                 Propellum Infotech Private Lim..
#                  (1)
#
#
#
#
#
#                 Qs Quacquarelli Symonds India ..
#                  (1)
#
#
#
#
#
#                 Quacquarelli Symonds Pvt Ltd
#                  (1)
#
#
#
#
#
#                 Sitel
#                  (1)
#
#
#
#
#
#                 Wri India
#                  (1)
#
#
#
#
#
#
#
#  IT Software : Software Product..
#                        (63
#                       )
#
#
#
#  IT Hardware : Hardware Product..
#                        (3
#                       )
#
#
#
#  Banks/Insurance/Financial Serv..
#                        (3
#                       )
#
#
#
#  HR/PM/IR/Training
#                        (2
#                       )
#
#
#
#  Marketing/MR/Media Planning
#                        (2
#                       )
#
#
#
#
#
#
#
# Pune
#                       (8)
#
#
#
# Navi Mumbai
#                       (8)
#
#
#
# Thane
#                       (7)
#
#
#
#
#
#
#
#
#                     IT-Software
#                      (
#                     17
#                     )
#
#
#
#
#                     Financial Services/Stockbrokin..
#                      (
#                     15
#                     )
#
#
#
#
#                     IT-Hardware/Networking
#                      (
#                     12
#                     )
#
#
#
#
#                     Telecom
#                      (
#                     11
#                     )
#
#
#
#
#                     Software Services
#                      (
#                     6
#                     )
#
#
#
#
#                     Consulting Services
#                      (
#                     5
#                     )
#
#
#
#
#                     Advertising/PR/Event Managemen..
#                      (
#                     4
#                     )
#
#
#
#
#                     CRM/CallCentres/BPO/ITES/Med.T..
#                      (
#                     4
#                     )
#
#
#
#
#                     Educational/Training
#                      (
#                     4
#                     )
#
#
#
#
#                     Manufacturing/Industrial
#                      (
#                     4
#                     )
#
#
#
#
#                     Research/Surveyor/MR
#                      (
#                     4
#                     )
#
#
#
#
#                     Banking
#                      (
#                     3
#                     )
#
#
#
#
#                     Entertainment/Media
#                      (
#                     2
#                     )
#
#
#
#
#                     Internet/Dot com/ISP
#                      (
#                     2
#                     )
#
#
#
#
#                     Recruitment/Placement Agencies
#                      (
#                     1
#                     )
#
#
#
#
#                     Consumer Durables/FMCG
#                      (
#                     1
#                     )
#
#
#
#
#                     NGO/Social Services
#                      (
#                     1
#                     )
#
#
#
#
#                     Others
#                      (
#                     3
#                     )
#
#
#
#
#
#
# 0-2 lacs
#                     (7)
#
#
#
# 2-4 lacs
#                     (63)
#
#
#
# 4-6 lacs
#                     (1)
#
#
#
# 6-10 lacs
#                     (1)
#
#
#
#
#
# Regular
# 	                    (71)
#
#
#
# Work from home
# 	                    (1)
#
#
#
#
# Companies
#
#
#
#
#
#
#
#                 Morgan Stanley Pvt Ltd
#                  (12)
#
#
#
#
#
#                 Verisk Analytics India Private..
#                  (4)
#
#
#
#
#
#                 Crimson Interactive Pvt Ltd
#                  (3)
#
#
#
#
#
#                 Hiotron India Pvt Ltd
#                  (3)
#
#
#
#
#
#                 Boyen Haddin Consultants Llp
#                  (2)
#
#
#
#
#
#                 Dg7
#                  (2)
#
#
#
#
#
#                 Interactive Brokers
#                  (2)
#
#
#
#
#
#                 Larsen & Toubro Infotech L..
#                  (2)
#
#
#
#
#
#                 Pagalguy
#                  (2)
#
#
#
#
#
#                 Publicis Groupe
#                  (2)
#
#
#
#
#
#                 Rangam Infotech Pvt. Ltd.
#                  (2)
#
#
#
#
#
#                 Tac Security
#                  (2)
#
#
#
#
#
#                 World Resources Institute
#                  (2)
#
#
#
#
#
#                 Abc Consultants Pvt Ltd
#                  (1)
#
#
#
#
#
#                 Axionconnect Infosolutions Pvt..
#                  (1)
#
#
#
#
#
#                 Feedspot
#                  (1)
#
#
#
#
#
#                 Headhuntersinc Consultancy Pri..
#                  (1)
#
#
#
#
#
#                 Ingram Micro Inc.
#                  (1)
#
#
#
#
#
#                 Jai Kisan
#                  (1)
#
#
#
#
#
#                 L&t Technology Services Li..
#                  (1)
#
#
#
#
#
#                 Nec Software Solutions (india)..
#                  (1)
#
#
#
#
#
#                 Paytm
#                  (1)
#
#
#
#
#
#                 Procter & Gamble (p&g)
#                  (1)
#
#
#
#
#
#                 Propellum Infotech Private Lim..
#                  (1)
#
#
#
#
#
#                 Qs Quacquarelli Symonds India ..
#                  (1)
#
#
#
#
#
#                 Quacquarelli Symonds Pvt Ltd
#                  (1)
#
#
#
#
#
#                 Sitel
#                  (1)
#
#
#
#
#
#                 Wri India
#                  (1)
#
#
#
#
#
#
# Job Function
#
#
#
#
#
#  IT Software : Software Product..
#                        (63
#                       )
#
#
#
#  IT Hardware : Hardware Product..
#                        (3
#                       )
#
#
#
#  Banks/Insurance/Financial Serv..
#                        (3
#                       )
#
#
#
#  HR/PM/IR/Training
#                        (2
#                       )
#
#
#
#  Marketing/MR/Media Planning
#                        (2
#                       )
#
#
#
#
#
#
# Location
#
#
#
#
#
# Pune
#                       (8)
#
#
#
# Navi Mumbai
#                       (8)
#
#
#
# Thane
#                       (7)
#
#
#
#
#
#
# Industry
#
#
#
#
#
#
#                     IT-Software
#                      (
#                     17
#                     )
#
#
#
#
#                     Financial Services/Stockbrokin..
#                      (
#                     15
#                     )
#
#
#
#
#                     IT-Hardware/Networking
#                      (
#                     12
#                     )
#
#
#
#
#                     Telecom
#                      (
#                     11
#                     )
#
#
#
#
#                     Software Services
#                      (
#                     6
#                     )
#
#
#
#
#                     Consulting Services
#                      (
#                     5
#                     )
#
#
#
#
#                     Advertising/PR/Event Managemen..
#                      (
#                     4
#                     )
#
#
#
#
#                     CRM/CallCentres/BPO/ITES/Med.T..
#                      (
#                     4
#                     )
#
#
#
#
#                     Educational/Training
#                      (
#                     4
#                     )
#
#
#
#
#                     Manufacturing/Industrial
#                      (
#                     4
#                     )
#
#
#
#
#                     Research/Surveyor/MR
#                      (
#                     4
#                     )
#
#
#
#
#                     Banking
#                      (
#                     3
#                     )
#
#
#
#
#                     Entertainment/Media
#                      (
#                     2
#                     )
#
#
#
#
#                     Internet/Dot com/ISP
#                      (
#                     2
#                     )
#
#
#
#
#                     Recruitment/Placement Agencies
#                      (
#                     1
#                     )
#
#
#
#
#                     Consumer Durables/FMCG
#                      (
#                     1
#                     )
#
#
#
#
#                     NGO/Social Services
#                      (
#                     1
#                     )
#
#
#
#
#                     Others
#                      (
#                     3
#                     )
#
#
#
#
#
#
# Salary
#
#
#
#
# 0-2 lacs
#                     (7)
#
#
#
# 2-4 lacs
#                     (63)
#
#
#
# 4-6 lacs
#                     (1)
#
#
#
# 6-10 lacs
#                     (1)
#
#
#
#
#
# Job Type
#
#
#
#
#
# Regular
# 	                    (71)
#
#
#
# Work from home
# 	                    (1)
#
#
#
#
#
#
#
#
#
#
#
#                 Morgan Stanley Pvt Ltd
#                  (12)
#
#
#
#
#
#                 Verisk Analytics India Private..
#                  (4)
#
#
#
#
#
#                 Crimson Interactive Pvt Ltd
#                  (3)
#
#
#
#
#
#                 Hiotron India Pvt Ltd
#                  (3)
#
#
#
#
#
#                 Boyen Haddin Consultants Llp
#                  (2)
#
#
#
#
#
#                 Dg7
#                  (2)
#
#
#
#
#
#                 Interactive Brokers
#                  (2)
#
#
#
#
#
#                 Larsen & Toubro Infotech L..
#                  (2)
#
#
#
#
#
#                 Pagalguy
#                  (2)
#
#
#
#
#
#                 Publicis Groupe
#                  (2)
#
#
#
#
#
#                 Rangam Infotech Pvt. Ltd.
#                  (2)
#
#
#
#
#
#                 Tac Security
#                  (2)
#
#
#
#
#
#                 World Resources Institute
#                  (2)
#
#
#
#
#
#                 Abc Consultants Pvt Ltd
#                  (1)
#
#
#
#
#
#                 Axionconnect Infosolutions Pvt..
#                  (1)
#
#
#
#
#
#                 Feedspot
#                  (1)
#
#
#
#
#
#                 Headhuntersinc Consultancy Pri..
#                  (1)
#
#
#
#
#
#                 Ingram Micro Inc.
#                  (1)
#
#
#
#
#
#                 Jai Kisan
#                  (1)
#
#
#
#
#
#                 L&t Technology Services Li..
#                  (1)
#
#
#
#
#
#                 Nec Software Solutions (india)..
#                  (1)
#
#
#
#
#
#                 Paytm
#                  (1)
#
#
#
#
#
#                 Procter & Gamble (p&g)
#                  (1)
#
#
#
#
#
#                 Propellum Infotech Private Lim..
#                  (1)
#
#
#
#
#
#                 Qs Quacquarelli Symonds India ..
#                  (1)
#
#
#
#
#
#                 Quacquarelli Symonds Pvt Ltd
#                  (1)
#
#
#
#
#
#                 Sitel
#                  (1)
#
#
#
#
#
#                 Wri India
#                  (1)
#
#
#
#
#
#
#
#  IT Software : Software Product..
#                        (63
#                       )
#
#
#
#  IT Hardware : Hardware Product..
#                        (3
#                       )
#
#
#
#  Banks/Insurance/Financial Serv..
#                        (3
#                       )
#
#
#
#  HR/PM/IR/Training
#                        (2
#                       )
#
#
#
#  Marketing/MR/Media Planning
#                        (2
#                       )
#
#
#
#
#
#
#
# Pune
#                       (8)
#
#
#
# Navi Mumbai
#                       (8)
#
#
#
# Thane
#                       (7)
#
#
#
#
#
#
#
#
#                     IT-Software
#                      (
#                     17
#                     )
#
#
#
#
#                     Financial Services/Stockbrokin..
#                      (
#                     15
#                     )
#
#
#
#
#                     IT-Hardware/Networking
#                      (
#                     12
#                     )
#
#
#
#
#                     Telecom
#                      (
#                     11
#                     )
#
#
#
#
#                     Software Services
#                      (
#                     6
#                     )
#
#
#
#
#                     Consulting Services
#                      (
#                     5
#                     )
#
#
#
#
#                     Advertising/PR/Event Managemen..
#                      (
#                     4
#                     )
#
#
#
#
#                     CRM/CallCentres/BPO/ITES/Med.T..
#                      (
#                     4
#                     )
#
#
#
#
#                     Educational/Training
#                      (
#                     4
#                     )
#
#
#
#
#                     Manufacturing/Industrial
#                      (
#                     4
#                     )
#
#
#
#
#                     Research/Surveyor/MR
#                      (
#                     4
#                     )
#
#
#
#
#                     Banking
#                      (
#                     3
#                     )
#
#
#
#
#                     Entertainment/Media
#                      (
#                     2
#                     )
#
#
#
#
#                     Internet/Dot com/ISP
#                      (
#                     2
#                     )
#
#
#
#
#                     Recruitment/Placement Agencies
#                      (
#                     1
#                     )
#
#
#
#
#                     Consumer Durables/FMCG
#                      (
#                     1
#                     )
#
#
#
#
#                     NGO/Social Services
#                      (
#                     1
#                     )
#
#
#
#
#                     Others
#                      (
#                     3
#                     )
#
#
#
#
#
#
# 0-2 lacs
#                     (7)
#
#
#
# 2-4 lacs
#                     (63)
#
#
#
# 4-6 lacs
#                     (1)
#
#
#
# 6-10 lacs
#                     (1)
#
#
#
#
#
# Regular
# 	                    (71)
#
#
#
# Work from home
# 	                    (1)
#
#
#
#
#
#
#
#
#
# Python Internship in Mumbai
#
#     Maxgen Technologies
#      (More Jobs)
#
#
#
# card_travel0 - 1 yrs
#
# location_on
# Mumbai,  Dombivali,  Kalyan,  Navi Mumbai,  Thane
#
#
#
#
# Job Description:
# Maxgen technologies pvt ltd offers live project internships in Mumbai. We are offering internships in python  , django and machine learning.Reasons behind choosing us?1 - Real... More Details
#
#
# KeySkills:
#
# python  ,  new
#
#
# directions_walk
# Walk-in Details 13-Mar-2023 - 12-May-2023  09:30 AM - 05:00 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
#
#
# Show Interest
#
#
#
#
# Posted few days ago
#
#
#
#
#
#
#
#
#
#
#
# Python Internship  in Mumbai
#
#     Maxgen Technologies
#      (More Jobs)
#
#
#
# card_travel0 - 1 yrs
#
# location_on
# Mumbai,  Dombivali,  Kalyan,  Navi Mumbai,  Thane
#
#
#
#
# Job Description:
# Maxgen technologies pvt ltd is located in navi mumbai .Offering python django and machine learning internsihp.Why do you need maxgen?Long time or short time internship.Job pla... More Details
#
#
# KeySkills:
#
#
#           django  ,  internship
#
#
# directions_walk
# Walk-in Details 25-Mar-2023 - 24-May-2023  10:30 AM - 04:00 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
#
#
# Show Interest
#
#
#
#
# Posted few days ago
#
#
#
#
#
#
#
#
#
#
#
# Python Internship Hiring Mumbai
#
#     Maxgen Technologies
#      (More Jobs)
#
#
#
# card_travel0 - 1 yrs
#
# location_on
# Mumbai,  Dombivali,  Kalyan,  Navi Mumbai,  Thane
#
#
#
#
# Job Description:
# Maxgen technologies pvt ltd offers live project internships in Mumbai. We are offering internships in python  , django and machine learning.benefit to join maxgen ?College pro... More Details
#
#
# KeySkills:
#
# python  ,  hire
#
#
# directions_walk
# Walk-in Details 29-Mar-2023 - 27-May-2023  10:30 AM - 04:30 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
#
#
# Show Interest
#
#
#
#
# Posted few days ago
#
#
#
#
#
#
#
#
#
#
#
# Python Internship Hiring Mumbai
#
#     Maxgen Technologies
#      (More Jobs)
#
#
#
# card_travel0 - 1 yrs
#
# location_on
# Mumbai,  Dombivali,  Kalyan,  Navi Mumbai,  Thane
#
#
#
#
# Job Description:
# Maxgen technologies pvt ltd offers live project internships in Mumbai. We are offering internships in core Python ,  Django and machine learning.What reasons behind choosing u... More Details
#
#
# KeySkills:
#
#
#           core python  ,  django
#
#
# directions_walk
# Walk-in Details 10-Mar-2023 - 08-May-2023  09:00 AM - 05:00 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
#
#
# Show Interest
#
#
#
#
# Posted few days ago
#
#
#
#
#
#
#
#
#
#
#
# Python Internship In Mumbai
#
#     Maxgen Technologies
#      (More Jobs)
#
#
#
# card_travel0 - 1 yrs
#
# location_on
# Mumbai,  Dombivali,  Kalyan,  Navi Mumbai,  Thane
#
#
#
#
# Job Description:
# Maxgen technologies pvt ltd offering live project internship in mumbai. We are offering internships in core python  , django and machine learning.Reasons behind choosing us?1 ... More Details
#
#
# KeySkills:
#
#
#           internship  ,  python  ,  pune  ,  maharashtra
#
#
# directions_walk
# Walk-in Details 26-Feb-2023 - 24-Apr-2023  10:00 AM - 06:30 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
#
#
# Show Interest
#
#
#
#
# Posted a month ago
#
#
#
#
#
#
#
#
#
#
#
#       Manager - Java / Python Angular Developer - Technology
#
#     Morgan Stanley Pvt Ltd
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai,  Bengaluru / Bangalore
#
#
#
#
# Job Description:
# Job ProfileWe are looking for someone with technical skills in the Java / Linux environment with an understanding of mainframe environments. This individual will be part of a ... More Details
#
#
# KeySkills:
#
#
#           c    ,  information technology  ,  java  ,  software engineering  ,  c#  ,  python  ,  perl scripting  ,  sybase  ,  unix  ,  storage  ,  database  ,  linux  ,  debugging  ,  technical skills  ,  business applications  ,  c  ,  mobile  ,  team player  ,  windows  ,  infrastructure
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted a month ago
#
#
#
#
#
#
#
#
#
#
#
#       CrimsonAI - Associate Architect - Python /  Node.Js /  Golang
#
#     CRIMSON INTERACTIVE PVT LTD
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# About the role:Architect core components of the platform capable of handling 1M requests per secondBuild multi level ,  multi services components capable of supporting concurr... More Details
#
#
# KeySkills:
#
#
#           design  ,  engineering  ,  designing  ,  building
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted few days ago
#
#
#
#
#
#
#
#
#
#
#
# Python Developer , Software Engineer , Software Developer
#
#     SMASHBIG INC.
#      (More Jobs)
#
#
#
# card_travel0 - 3 yrs
# ₹Rs 8.50 - 10.50 Lacs p.a.
#
# location_on
# Bengaluru / Bangalore,  Chennai,  Delhi/NCR,  Hyderabad/Secunderabad,  Mumbai
#
#
#
#
# Job Description:
# Responsibilities: Develop complex software products that include scale ,  algorithmic complexity ,  and a huge amount of data.  Build cutting-edge scalable systems by writing ... More Details
#
#
# KeySkills:
#
# Python
#
#
#
#
#
#
# Apply
#
#
#
#
#
# Work from Home
#
# Posted 1 day ago
#
#
#
#
#
#
#
#
#
#
#
# Python Developer
#
#     New Global Technologies
#      (More Jobs)
#
#
#
# card_travel0 - 3 yrs
# ₹Rs 3.00 - 9.00 Lacs p.a.
#
# location_on
# Bengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Mumbai,  Pune
#
#
#
#
# Job Description:
# Strong Python skills along with web frameworks such as Django / FlaskHTML / CSS ,  knowledge in JS based frameworks such as JQuery / React / Angular / Bootstrap etc.Sound know... More Details
#
#
# KeySkills:
#
# python  ,  Django  ,  perl  ,  Shell  ,  Web Technologies  ,  Http  ,  html
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted a month ago
#
#
#
#
#
#
#
#
#
#
#
#       Manager - Architecture
#
#     Larsen & Toubro Infotech Ltd
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Assess automation opportunity from technical perspective and provide solution Anticipate ,  identify ,  track ,  and resolve technical issues and risks affecting deliveryPerfo... More Details
#
#
# KeySkills:
#
#
#           sql  ,  database  ,  java  ,  python
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted few days ago
#
#
#
#
#
#
#
#
#
#
#
#
#       Senior Associate /  Manager- Full Stack - Macro Strat Developer  ( Fixed Income Division )
#
#     Morgan Stanley Pvt Ltd
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# DescriptionMacro Strat DeveloperDivision: Fixed Income Division Job Title: Full Stack - Macro Strat DeveloperLocation: Mumbai Job Level: Senior ManagerCompany ProfileMorgan St... More Details
#
#
# KeySkills:
#
#
#           c    ,  fx  ,  java  ,  python
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted a month ago
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       Associate /  Senior Associate - Tokyo Structured Rates Strats  ( Fixed Income Division )
#
#     Morgan Stanley Pvt Ltd
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# DescriptionJob DescriptionFrom global institutions to hedge funds ,  investors come to Morgan Stanley for sales ,  trading ,  and market-making services in almost every type o... More Details
#
#
# KeySkills:
#
#
#           c    ,  scala  ,  fx  ,  python
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted a month ago
#
#
#
#
#
#
#
#
#
#
#
#       Vice President- Macro VA Senior Developer  ( Fixed Income Division )
#
#     Morgan Stanley Pvt Ltd
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Level: Officer - VPFront Office Risk Management System Senior Developerin Mumbai OfficeWe are recruiting a senior development lead for the Macro VA Fixed Income Trading team. ... More Details
#
#
# KeySkills:
#
# python  ,  scala  ,  fx  ,  java
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted a month ago
#
#
#
#
#
#
#
#
#
#
#
#       Data Assistant
#
#     verisk analytics india private limited
#
#
#
#
# card_travel0 - 2 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# This role will form part of theData Assetsgroup and will work closely with our Research ,  Data and Product functions. The successful candidate will help solve challenges arou... More Details
#
#
# KeySkills:
#
# python  ,  problem solving  ,  mining  ,  sql
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted 4 days ago
#
#
#
#
#
#
#
#
#
#
#
#       Data Analytics and Reporting - Manager
#
#     Interactive Brokers
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Interactive Brokers is looking to hire a technologically fluent Data Analytics and Reporting Manager at our Mumbai office. The Manager will report to the Head of Compliance Da... More Details
#
#
# KeySkills:
#
#
#           sql  ,  linux  ,  python  ,  nosql  ,  php
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted few days ago
#
#
#
#
#
#
#
#
#
#
#
#       Data Engineering Manager
#
#     verisk analytics india private limited
#
#
#
#
# card_travel0 - 2 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Job DescriptionWood Mackenzie is looking for a dynamic Data Engineering Manager with demonstrated leadership capability to actively lead the way in modern software development... More Details
#
#
# KeySkills:
#
#
#           orchestration  ,  python  ,  mining  ,  leadership skills
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted few days ago
#
#
#
#
#
#
#
#
#
#
#
#       Data Assistant
#
#     verisk analytics india private limited
#
#
#
#
# card_travel0 - 1 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Job DescriptionThis role will form part of theData Assetsgroup and will work closely with our Research ,  Data and Product functions. The successful candidate will help solve ... More Details
#
#
# KeySkills:
#
# python  ,  problem solving  ,  mining  ,  sql
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted few days ago
#
#
#
#
#
#
#
#
#
#
#
#       SDE 1 /  SDE 2 /  SDE 3
#
#     CRIMSON INTERACTIVE PVT LTD
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# About the role:Focus on writing quality codeCode end to end  ( no one is going to help you in that ) Figure out what ,  how and why you need to build what youre supposed to bu... More Details
#
#
# KeySkills:
#
# python  ,  web development  ,   keep learning
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted few days ago
#
#
#
#
#
#
#
#
#
#
#
#       Sr. Associate - QR Strats Analytics - Asia Support
#
#     Morgan Stanley Pvt Ltd
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Department ProfileFrom global institutions to hedge funds ,  investors come to Morgan Stanley for sales ,  trading ,  and market-making services in almost every type of financ... More Details
#
#
# KeySkills:
#
#
#           algorithms  ,  linux  ,  python  ,  machine learning
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted a month ago
#
#
#
#
#
#
#
#
#
#
#
#
#       Data Analytics and Reporting - Analyst
#
#     Interactive Brokers
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Interactive Brokers is looking to hire a Data Analytics and Reporting Analyst at their Mumbai office. This position comes with excellent growth potential for highly motivated ... More Details
#
#
# KeySkills:
#
#
#           bi  ,  sql  ,  linux  ,  python  ,  nosql  ,  php
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted few days ago
#
#
#
#
#
#
#
#
#
#
#
#       Senior Data Engineer
#
#     verisk analytics india private limited
#
#
#
#
# card_travel0 - 2 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Wood Mackenzie are the global research ,  analytics ,  and consultancy business powering the natural resources industry. For 50 years ,  we have been providing the quality dat... More Details
#
#
# KeySkills:
#
#
#           database  ,  security  ,  python  ,  problem solving  ,  mining  ,  nosql
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted few days ago
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       Front-end Engineer
#
#     PaGaLGuY
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Front-end EngineerAn engineer / perfectionist with a fast keyboard ,  ready to take on entire features.What Youll Do: Build the next cool thing on PaGaLGuYAnd improve the exis... More Details
#
#
# KeySkills:
#
# python  ,  github  ,  git  ,  html5  ,  mvc  ,  javascript
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted few days ago
#
#
#
#
#
#
#
#
#
#
#
#       Business Manager - Data Ops
#
#     PUBLICIS GROUPE
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Gurgaon,  Mumbai,  Pune,  Bengaluru / Bangalore
#
#
#
#
# Job Description:
# Leads a team of data scientist at various levels of seniority.Coaches team members and manages team development.Engages in knowledge transfer to team members.Partners with oth... More Details
#
#
# KeySkills:
#
#
#           sql  ,  cloud computing  ,  python  ,  machine learning
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted few days ago
#
#
#
#
#
#
#
#
#
#
#
#       Manager /  Senior Manager - Quant Dev Build Out  ( Quant Developer )   ( Fixed Income Division )
#
#     Morgan Stanley Pvt Ltd
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Job Level : ManagerDescriptionMorgan Stanley is a leading global financial services firm providing a wide range of investment banking ,  securities ,  investment management an... More Details
#
#
# KeySkills:
#
#
#           c    ,  scala  ,  fx  ,  linux  ,  python  ,  windows
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted a month ago
#
#
#
#
#
#
#
#
#
#
#
#       Manager /  Senior Manager- Quant Dev Build Out  ( Quant Developer )   ( Fixed Income Division )
#
#     Morgan Stanley Pvt Ltd
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Morgan Stanley is a leading global financial services firm providing a wide range of investment banking ,  securities ,  investment management and wealth management services. ... More Details
#
#
# KeySkills:
#
#
#           c    ,  scala  ,  fx  ,  linux  ,  python  ,  windows
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted a month ago
#
#
#
#
#
#
#
# card_travel0 - 1 yrs
#
# location_on
# Mumbai,  Dombivali,  Kalyan,  Navi Mumbai,  Thane
#
#
#
#
# Job Description:
# Maxgen technologies pvt ltd offers live project internships in Mumbai. We are offering internships in python  , django and machine learning.Reasons behind choosing us?1 - Real... More Details
#
#
# KeySkills:
#
# python  ,  new
#
#
# directions_walk
# Walk-in Details 13-Mar-2023 - 12-May-2023  09:30 AM - 05:00 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
# card_travel0 - 1 yrs
#
# location_on
# Mumbai,  Dombivali,  Kalyan,  Navi Mumbai,  Thane
#
#
#
#
# Job Description:
# Maxgen technologies pvt ltd is located in navi mumbai .Offering python django and machine learning internsihp.Why do you need maxgen?Long time or short time internship.Job pla... More Details
#
#
# KeySkills:
#
#
#           django  ,  internship
#
#
# directions_walk
# Walk-in Details 25-Mar-2023 - 24-May-2023  10:30 AM - 04:00 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
# card_travel0 - 1 yrs
#
# location_on
# Mumbai,  Dombivali,  Kalyan,  Navi Mumbai,  Thane
#
#
#
#
# Job Description:
# Maxgen technologies pvt ltd offers live project internships in Mumbai. We are offering internships in python  , django and machine learning.benefit to join maxgen ?College pro... More Details
#
#
# KeySkills:
#
# python  ,  hire
#
#
# directions_walk
# Walk-in Details 29-Mar-2023 - 27-May-2023  10:30 AM - 04:30 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
# card_travel0 - 1 yrs
#
# location_on
# Mumbai,  Dombivali,  Kalyan,  Navi Mumbai,  Thane
#
#
#
#
# Job Description:
# Maxgen technologies pvt ltd offers live project internships in Mumbai. We are offering internships in core Python ,  Django and machine learning.What reasons behind choosing u... More Details
#
#
# KeySkills:
#
#
#           core python  ,  django
#
#
# directions_walk
# Walk-in Details 10-Mar-2023 - 08-May-2023  09:00 AM - 05:00 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
# card_travel0 - 1 yrs
#
# location_on
# Mumbai,  Dombivali,  Kalyan,  Navi Mumbai,  Thane
#
#
#
#
# Job Description:
# Maxgen technologies pvt ltd offering live project internship in mumbai. We are offering internships in core python  , django and machine learning.Reasons behind choosing us?1 ... More Details
#
#
# KeySkills:
#
#
#           internship  ,  python  ,  pune  ,  maharashtra
#
#
# directions_walk
# Walk-in Details 26-Feb-2023 - 24-Apr-2023  10:00 AM - 06:30 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai,  Bengaluru / Bangalore
#
#
#
#
# Job Description:
# Job ProfileWe are looking for someone with technical skills in the Java / Linux environment with an understanding of mainframe environments. This individual will be part of a ... More Details
#
#
# KeySkills:
#
#
#           c    ,  information technology  ,  java  ,  software engineering  ,  c#  ,  python  ,  perl scripting  ,  sybase  ,  unix  ,  storage  ,  database  ,  linux  ,  debugging  ,  technical skills  ,  business applications  ,  c  ,  mobile  ,  team player  ,  windows  ,  infrastructure
#
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# About the role:Architect core components of the platform capable of handling 1M requests per secondBuild multi level ,  multi services components capable of supporting concurr... More Details
#
#
# KeySkills:
#
#
#           design  ,  engineering  ,  designing  ,  building
#
#
#
#
#
# card_travel0 - 3 yrs
# ₹Rs 8.50 - 10.50 Lacs p.a.
#
# location_on
# Bengaluru / Bangalore,  Chennai,  Delhi/NCR,  Hyderabad/Secunderabad,  Mumbai
#
#
#
#
# Job Description:
# Responsibilities: Develop complex software products that include scale ,  algorithmic complexity ,  and a huge amount of data.  Build cutting-edge scalable systems by writing ... More Details
#
#
# KeySkills:
#
# Python
#
#
#
#
# card_travel0 - 3 yrs
# ₹Rs 3.00 - 9.00 Lacs p.a.
#
# location_on
# Bengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Mumbai,  Pune
#
#
#
#
# Job Description:
# Strong Python skills along with web frameworks such as Django / FlaskHTML / CSS ,  knowledge in JS based frameworks such as JQuery / React / Angular / Bootstrap etc.Sound know... More Details
#
#
# KeySkills:
#
# python  ,  Django  ,  perl  ,  Shell  ,  Web Technologies  ,  Http  ,  html
#
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Assess automation opportunity from technical perspective and provide solution Anticipate ,  identify ,  track ,  and resolve technical issues and risks affecting deliveryPerfo... More Details
#
#
# KeySkills:
#
#
#           sql  ,  database  ,  java  ,  python
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# DescriptionMacro Strat DeveloperDivision: Fixed Income Division Job Title: Full Stack - Macro Strat DeveloperLocation: Mumbai Job Level: Senior ManagerCompany ProfileMorgan St... More Details
#
#
# KeySkills:
#
#
#           c    ,  fx  ,  java  ,  python
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# DescriptionJob DescriptionFrom global institutions to hedge funds ,  investors come to Morgan Stanley for sales ,  trading ,  and market-making services in almost every type o... More Details
#
#
# KeySkills:
#
#
#           c    ,  scala  ,  fx  ,  python
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Level: Officer - VPFront Office Risk Management System Senior Developerin Mumbai OfficeWe are recruiting a senior development lead for the Macro VA Fixed Income Trading team. ... More Details
#
#
# KeySkills:
#
# python  ,  scala  ,  fx  ,  java
#
#
#
#
#
# card_travel0 - 2 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# This role will form part of theData Assetsgroup and will work closely with our Research ,  Data and Product functions. The successful candidate will help solve challenges arou... More Details
#
#
# KeySkills:
#
# python  ,  problem solving  ,  mining  ,  sql
#
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Interactive Brokers is looking to hire a technologically fluent Data Analytics and Reporting Manager at our Mumbai office. The Manager will report to the Head of Compliance Da... More Details
#
#
# KeySkills:
#
#
#           sql  ,  linux  ,  python  ,  nosql  ,  php
#
#
#
#
#
# card_travel0 - 2 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Job DescriptionWood Mackenzie is looking for a dynamic Data Engineering Manager with demonstrated leadership capability to actively lead the way in modern software development... More Details
#
#
# KeySkills:
#
#
#           orchestration  ,  python  ,  mining  ,  leadership skills
#
#
#
#
#
# card_travel0 - 1 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Job DescriptionThis role will form part of theData Assetsgroup and will work closely with our Research ,  Data and Product functions. The successful candidate will help solve ... More Details
#
#
# KeySkills:
#
# python  ,  problem solving  ,  mining  ,  sql
#
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# About the role:Focus on writing quality codeCode end to end  ( no one is going to help you in that ) Figure out what ,  how and why you need to build what youre supposed to bu... More Details
#
#
# KeySkills:
#
# python  ,  web development  ,   keep learning
#
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Department ProfileFrom global institutions to hedge funds ,  investors come to Morgan Stanley for sales ,  trading ,  and market-making services in almost every type of financ... More Details
#
#
# KeySkills:
#
#
#           algorithms  ,  linux  ,  python  ,  machine learning
#
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Interactive Brokers is looking to hire a Data Analytics and Reporting Analyst at their Mumbai office. This position comes with excellent growth potential for highly motivated ... More Details
#
#
# KeySkills:
#
#
#           bi  ,  sql  ,  linux  ,  python  ,  nosql  ,  php
#
#
#
#
#
# card_travel0 - 2 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Wood Mackenzie are the global research ,  analytics ,  and consultancy business powering the natural resources industry. For 50 years ,  we have been providing the quality dat... More Details
#
#
# KeySkills:
#
#
#           database  ,  security  ,  python  ,  problem solving  ,  mining  ,  nosql
#
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Front-end EngineerAn engineer / perfectionist with a fast keyboard ,  ready to take on entire features.What Youll Do: Build the next cool thing on PaGaLGuYAnd improve the exis... More Details
#
#
# KeySkills:
#
# python  ,  github  ,  git  ,  html5  ,  mvc  ,  javascript
#
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Gurgaon,  Mumbai,  Pune,  Bengaluru / Bangalore
#
#
#
#
# Job Description:
# Leads a team of data scientist at various levels of seniority.Coaches team members and manages team development.Engages in knowledge transfer to team members.Partners with oth... More Details
#
#
# KeySkills:
#
#
#           sql  ,  cloud computing  ,  python  ,  machine learning
#
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Job Level : ManagerDescriptionMorgan Stanley is a leading global financial services firm providing a wide range of investment banking ,  securities ,  investment management an... More Details
#
#
# KeySkills:
#
#
#           c    ,  scala  ,  fx  ,  linux  ,  python  ,  windows
#
#
#
#
#
# card_travel0 - 3 yrs
#
# location_on
# Mumbai
#
#
#
#
# Job Description:
# Morgan Stanley is a leading global financial services firm providing a wide range of investment banking ,  securities ,  investment management and wealth management services. ... More Details
#
#
# KeySkills:
#
#
#           c    ,  scala  ,  fx  ,  linux  ,  python  ,  windows
#
#
#
#
#
# By Skill
# By Designation
#
#
#
#
#
#
#
#  Mumbai
#  Pune
#  Chennai
#  Bangalore
#  Hyderabad
#  Kolkata
#  Delhi/NCR
#  Ahmedabad
#
#
# Jobs by Function
# IT Software Jobs
# BPO Jobs
# Sales Jobs
# Fresher Jobs
# Medical Jobs
# Bank Jobs
#  All Functional Areas
#
# Jobs by Role
# Accountant Jobs
# Accountant Executive Jobs
# Assistant Manager Jobs
# Branch Manager Jobs
# Chief Marketing Officer Jobs
# Chief Executive Officer Jobs
# Chief Technology Officer Jobs
# All Roles
#
#
# IT Job Skills
# Java Jobs
# SAP Jobs
# .net Jobs
# Oracle Jobs
# Sql Server Jobs
# QA Jobs
# HTML Jobs
# ISDN Jobs
# ITIL Jobs
# JCL Jobs
# JDBC Jobs
# JIRA Jobs
# Jquery Jobs
# JSP Jobs
# All Skills
#
#
# Non-IT Job Skills
# Human resource Jobs
# Trade execution Jobs
# Taxation Jobs
# Accounts executive Jobs
# Management Jobs
# Reservation & Ticketing Executive Jobs
# Reservation & Ticketing Officer Jobs
# Reservation & Ticketing Staff Jobs
# Retail Jobs
# Safety & Security Manager Jobs
# Sales & Application Engineer Jobs
# Sales & Marketing Engineer Jobs
#
#
# Jobs by Location
#  Jobs in New Delhi
#  Jobs in Kolkata
# Jobs in Ahmedabad
#  Jobs in Noida
#  Jobs in Gurgaon
#  Jobs in Mumbai
#  Jobs in Chennai
#  Jobs in Hyderabad
# Jobs in Bangalore
# Jobs in Pune
# Jobs in Chandigarh
# All Locations
#
# Jobs by company
# Search Company
#
#
# Gulf Jobs
# Jobs in UAE
# Jobs in Bahrain
# Jobs in Dubai
# Jobs in Qatar
# Jobs in Abu Dhabi
# Jobs in Saudi Arabia
# Jobs in Kuwait
#
# Company
# About Us
# Terms of Use
# Privacy Policy
# Security Advice
# Fraud Alert
#
# Contact Us
# Sitemap
#
#
# Government Jobs
# Times of India Ascent Jobs
# Mobile Job Search
# International Jobs
# Follow Us

# %%
tag=soup.find_all('ul',class_="list-job-dtl clearfix")
for i in tag:
    print(i.text)
# Out:
# Job Description:
# Maxgen technologies pvt ltd offers live project internships in Mumbai. We are offering internships in core python  , django and machine learning.benefit to join maxgen ?Colleg... More Details
#
#
# KeySkills:
#
# python  ,  Css
#
#
# directions_walk
# Walk-in Details 10-Apr-2023 - 08-Jun-2023  09:00 AM - 04:00 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
#
# Job Description:
# Maxgen technologies pvt ltd offers live project internships in Mumbai. We are offering internships in python  , django and machine learning.Reasons behind choosing us?1 - Real... More Details
#
#
# KeySkills:
#
# python  ,  new
#
#
# directions_walk
# Walk-in Details 13-Mar-2023 - 12-May-2023  09:30 AM - 05:00 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
#
# Job Description:
# Maxgen technologies pvt ltd offers live project internships in Mumbai. We are offering internships in python  , django and machine learning.benefit to join maxgen ?College pro... More Details
#
#
# KeySkills:
#
# python  ,  hire
#
#
# directions_walk
# Walk-in Details 29-Mar-2023 - 27-May-2023  10:30 AM - 04:30 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
#
# Job Description:
# Maxgen technologies pvt ltd offers live project internships in Mumbai. We are offering internships in core Python ,  Django and machine learning.What reasons behind choosing u... More Details
#
#
# KeySkills:
#
#
#           core python  ,  django
#
#
# directions_walk
# Walk-in Details 10-Mar-2023 - 08-May-2023  09:00 AM - 05:00 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
#
# Job Description:
# Maxgen technologies pvt ltd offering live project internship in mumbai. We are offering internships in core python  , django and machine learning.Reasons behind choosing us?1 ... More Details
#
#
# KeySkills:
#
#
#           internship  ,  python  ,  pune  ,  maharashtra
#
#
# directions_walk
# Walk-in Details 26-Feb-2023 - 24-Apr-2023  10:00 AM - 06:30 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
#
# Job Description:
# Maxgen technologies pvt ltd is located in navi mumbai .Offering python django and machine learning internsihp.Why do you need maxgen?Long time or short time internship.Job pla... More Details
#
#
# KeySkills:
#
#
#           django  ,  internship
#
#
# directions_walk
# Walk-in Details 25-Mar-2023 - 24-May-2023  10:30 AM - 04:00 PM   Maxgen Technologies Pvt Ltd.
# Ambiance 1505,Sector 19 D,
# Opposite R.T.O,
# Backside Of Fortune Hotel,
# Vashi , Navi Mumbai
#
#
#
# Job Description:
# About the role:Architect core components of the platform capable of handling 1M requests per secondBuild multi level ,  multi services components capable of supporting concurr... More Details
#
#
# KeySkills:
#
#
#           design  ,  engineering  ,  designing  ,  building
#
#
#
#
#
#
# Job Description:
# Job ProfileWe are looking for someone with technical skills in the Java / Linux environment with an understanding of mainframe environments. This individual will be part of a ... More Details
#
#
# KeySkills:
#
#
#           c    ,  information technology  ,  java  ,  software engineering  ,  c#  ,  python  ,  perl scripting  ,  sybase  ,  unix  ,  storage  ,  database  ,  linux  ,  debugging  ,  technical skills  ,  business applications  ,  c  ,  mobile  ,  team player  ,  windows  ,  infrastructure
#
#
#
#
#
#
# Job Description:
# Strong Python skills along with web frameworks such as Django / FlaskHTML / CSS ,  knowledge in JS based frameworks such as JQuery / React / Angular / Bootstrap etc.Sound know... More Details
#
#
# KeySkills:
#
# python  ,  Django  ,  perl  ,  Shell  ,  Web Technologies  ,  Http  ,  html
#
#
#
#
#
#
# Job Description:
# Responsibilities: Develop complex software products that include scale ,  algorithmic complexity ,  and a huge amount of data.  Build cutting-edge scalable systems by writing ... More Details
#
#
# KeySkills:
#
# Python
#
#
#
#
#
# Job Description:
# Assess automation opportunity from technical perspective and provide solution Anticipate ,  identify ,  track ,  and resolve technical issues and risks affecting deliveryPerfo... More Details
#
#
# KeySkills:
#
#
#           sql  ,  database  ,  java  ,  python
#
#
#
#
#
# Job Description:
# DescriptionMacro Strat DeveloperDivision: Fixed Income Division Job Title: Full Stack - Macro Strat DeveloperLocation: Mumbai Job Level: Senior ManagerCompany ProfileMorgan St... More Details
#
#
# KeySkills:
#
#
#           c    ,  fx  ,  java  ,  python
#
#
#
#
#
# Job Description:
# DescriptionJob DescriptionFrom global institutions to hedge funds ,  investors come to Morgan Stanley for sales ,  trading ,  and market-making services in almost every type o... More Details
#
#
# KeySkills:
#
#
#           c    ,  scala  ,  fx  ,  python
#
#
#
#
#
# Job Description:
# Level: Officer - VPFront Office Risk Management System Senior Developerin Mumbai OfficeWe are recruiting a senior development lead for the Macro VA Fixed Income Trading team. ... More Details
#
#
# KeySkills:
#
# python  ,  scala  ,  fx  ,  java
#
#
#
#
#
#
# Job Description:
# About the role:Focus on writing quality codeCode end to end  ( no one is going to help you in that ) Figure out what ,  how and why you need to build what youre supposed to bu... More Details
#
#
# KeySkills:
#
# python  ,  web development  ,   keep learning
#
#
#
#
#
#
# Job Description:
# This role will form part of theData Assetsgroup and will work closely with our Research ,  Data and Product functions. The successful candidate will help solve challenges arou... More Details
#
#
# KeySkills:
#
# python  ,  problem solving  ,  mining  ,  sql
#
#
#
#
#
#
# Job Description:
# Job DescriptionWood Mackenzie is looking for a dynamic Data Engineering Manager with demonstrated leadership capability to actively lead the way in modern software development... More Details
#
#
# KeySkills:
#
#
#           orchestration  ,  python  ,  mining  ,  leadership skills
#
#
#
#
#
#
# Job Description:
# Interactive Brokers is looking to hire a technologically fluent Data Analytics and Reporting Manager at our Mumbai office. The Manager will report to the Head of Compliance Da... More Details
#
#
# KeySkills:
#
#
#           sql  ,  linux  ,  python  ,  nosql  ,  php
#
#
#
#
#
#
# Job Description:
# Department ProfileFrom global institutions to hedge funds ,  investors come to Morgan Stanley for sales ,  trading ,  and market-making services in almost every type of financ... More Details
#
#
# KeySkills:
#
#
#           algorithms  ,  linux  ,  python  ,  machine learning
#
#
#
#
#
#
# Job Description:
# Front-end EngineerAn engineer / perfectionist with a fast keyboard ,  ready to take on entire features.What Youll Do: Build the next cool thing on PaGaLGuYAnd improve the exis... More Details
#
#
# KeySkills:
#
# python  ,  github  ,  git  ,  html5  ,  mvc  ,  javascript
#
#
#
#
#
#
# Job Description:
# Leads a team of data scientist at various levels of seniority.Coaches team members and manages team development.Engages in knowledge transfer to team members.Partners with oth... More Details
#
#
# KeySkills:
#
#
#           sql  ,  cloud computing  ,  python  ,  machine learning
#
#
#
#
#
#
# Job Description:
# Wood Mackenzie are the global research ,  analytics ,  and consultancy business powering the natural resources industry. For 50 years ,  we have been providing the quality dat... More Details
#
#
# KeySkills:
#
#
#           database  ,  security  ,  python  ,  problem solving  ,  mining  ,  nosql
#
#
#
#
#
#
# Job Description:
# Interactive Brokers is looking to hire a Data Analytics and Reporting Analyst at their Mumbai office. This position comes with excellent growth potential for highly motivated ... More Details
#
#
# KeySkills:
#
#
#           bi  ,  sql  ,  linux  ,  python  ,  nosql  ,  php
#
#
#
#
#
#
# Job Description:
# Job Level : ManagerDescriptionMorgan Stanley is a leading global financial services firm providing a wide range of investment banking ,  securities ,  investment management an... More Details
#
#
# KeySkills:
#
#
#           c    ,  scala  ,  fx  ,  linux  ,  python  ,  windows
#
#
#
#
#
#
# Job Description:
# Morgan Stanley is a leading global financial services firm providing a wide range of investment banking ,  securities ,  investment management and wealth management services. ... More Details
#
#
# KeySkills:
#
#
#           c    ,  scala  ,  fx  ,  linux  ,  python  ,  windows

# %%
from bs4 import BeautifulSoup
import requests
#get data from html page toa file text
f=requests.get("https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=mumbai&cboWorkExp1=0").text

soup=BeautifulSoup(f,'lxml')
print(soup)
job=soup.find('h3',class_="joblist-comp-name")
#company=job.find('h3')
print(company.text.strip())
# Out:
# <!DOCTYPE html>
# <html><head>
# <link href="https://fonts.googleapis.com/css?family=Poppins:400,500,600,700" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/jquery.tokeninput.js" type="text/javascript"></script>
# <!-- <script type="text/javascript" src="https://code.angularjs.org/1.7.0/angular.min.js"></script> -->
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/angular1.7.0.min.js" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/materialize.min.js" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/groupJs/dwrGroup.js?v=7.1.7" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/mustache.js" type="text/javascript"></script>
# <link href="https://www.timesjobs.com/candidate/job-search.html" rel="canonical"/>
# <link href="https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&amp;from=submit&amp;txtKeywords=python&amp;txtLocation=mumbai&amp;cboWorkExp1=0/&amp;sequence=2&amp;startPage=1" rel="next"/>
# <title>python Jobs in mumbai  with Entry Level experience - TimesJobs</title>
# <meta content="Jobs in python in mumbai  with Entry Level experience. Search and apply jobs online at Timesjobs.com" name="description"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-59SJDG4');</script>
# <!-- End Google Tag Manager -->
# <script src="https://www.gstatic.com/charts/loader.js" type="text/javascript"></script>
# <script>
#           //google.charts.load('current', {'packages':['bar']});
#           google.charts.load('current', {packages: ['corechart', 'bar']});
#         </script>
# <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="C4P83-FLD8C-N9VTA-RP2SP-ZADRK",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"C4P83-FLD8C-N9VTA-RP2SP-ZADRK";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="ejimmzdiotztazbsmjva-f-b4ffc8221-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"34","ak.cp":"1277284","ak.ai":parseInt("765140",10),"ak.ol":"0","ak.cr":9,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"1eebf696","ak.r":44822,"ak.a2":n,"ak.m":"j","ak.n":"essl","ak.bpcip":"34.80.198.0","ak.cport":41262,"ak.gh":"104.116.243.44","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1681023594","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"9","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head>
# <body>
# <div id="site">
# <!-- Header Starts -->
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-59SJDG4" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script src="https://wchat.freshchat.com/js/widget.js" type="text/javascript"></script>
# <script>
# window.fcWidget.init({
# token: "d7130618-a917-400b-804c-bdf44d8d178b",
# host: "https://wchat.freshchat.com",
# config: {
# headerProperty: {
# hideChatButton: true
# }
#         }
# });
#
# </script>
# <!--[if IE]>
# <script src="scripts/html5shiv.js"></script>
# <![endif]-->
# <script src="https://static.timesjobs.com/newtj_js/scripts/ajax-upload.js" type="text/javascript"></script>
# <div class="msg notify" id="fb_connect_suggest" style="display: none;">
# 		Dear Jobseeker, Find millions of jobs on single click.
# 		<span id="fb_auto_connect"><a href="javascript:fconnect_auto();"><img alt="fconnect" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/top-facebook-notify.png"/></a></span>
# <span class="big-cls cls-icn" onclick="javascript:ack_fbconnect_cancel();" title="Click to Hide"><i class="material-icons">close</i></span>
# <span id="fb_connect_status"></span>
# </div>
# <div class="msg success" id="fb_connect_success" style="display: none;">
# 			Congratulations! You have been logged in via Facebook
# 		</div>
# <header class="main-header">
# <div class="top-header">
# <div class="ubility-wrap clearfix">
# <ul class="top-link">
# <li><a class="link-active" href="https://www.timesjobs.com">TimesJobs</a></li>
# <li><a href="http://jobbuzz.timesjobs.com" target="_blank">JobBuzz</a></li>
# <!--<li><a href="http://stepahead.timesjobs.com" target="_blank">Career Services</a></li>
#      <li><a href="http://www.techgig.com" target="_blank">TechGig</a></li> -->
# <li><a href="https://ae.timesjobs.com" target="_blank">Gulf Jobs</a></li>
# <li><a href="http://content.timesjobs.com/recruitex?fromsite=tjcand" target="_blank">Career Insight</a></li>
# </ul>
# <ul class="top-contact">
# <li><i class="material-icons">call</i>0120 6358222</li>
# <li>
# <span class="live-chat" id="chat-widget" onclick="window.fcWidget.open();window.fcWidget.show();">Live Chat (10am to 6pm IST)</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="ubility-wrap logo-section clearfix">
# <a class="top-tj-logo" href="https://www.timesjobs.com" itemprop="url" title="TIMESJOBS">
# <img alt="TimesJobs" height="23" itemprop="logo" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/tj-logo-new.png" title="TimesJobs" width="140"/>
# </a>
# <script type="text/javascript">
# 				jQuery(document).ready(function() {
# 					jQuery("#career-affection").show();
# 					jQuery("#career-affection-rhs").show();
# 				})
# 			</script>
# <ul class="main-tj-nav clearfix">
# <script type="text/javascript">
# var notification_timeout = 10000;
# var notification_cache = true;
# if (!window.console) console = {log: function() {}};
#
# if(typeof String.prototype.trim !== 'function') {
#   String.prototype.trim = function() {
#     return this.replace(/^\s+|\s+$/g, '');
#   }
# }
#
#
# /* This function is used to set cookies */
# function setCookie(name,value,expires,path,domain,secure) {
#   document.cookie = name + "=" + escape (value) +
#     ((expires) ? "; expires=" + expires.toGMTString() : "") +
#     ((path) ? "; path=" + path : "") +
#     ((domain) ? "; domain=" + domain : "") + ((secure) ? "; secure" : "");
# }
#
# /* This function is used to get cookies */
# function getCookie(name) {
# 	var prefix = name + "=" ;
# 	var start = document.cookie.indexOf(prefix);
#
# 	if (start==-1) {
# 		return null;
# 	}
#
# 	var end = document.cookie.indexOf(";", start+prefix.length);
# 	if (end==-1) {
# 		end=document.cookie.length;
# 	}
#
# 	var value=document.cookie.substring(start+prefix.length, end) ;
# 	return unescape(value);
# }
#
#
# function deleteCookie(name,path,domain) {
#   if (getCookie(name)) {
#     document.cookie = name + "=" +
#       ((path) ? "; path=" + path : "") +
#       ((domain) ? "; domain=" + domain : "") +
#       "; expires=Thu, 01-Jan-70 00:00:01 GMT";
#   }
# }
#
# var authenticated = 'false';
#
# jQuery(document).ready(function(){
# var alreadyCalled = false;
#
# //alert("logged-in:"+authenticated);
# //alert("comparison to true, for"+authenticated +", "+ ('true' == authenticated));
#
# if('true' == authenticated){
# 	//jQuery(".viewnoteTab").mouseout(function(){
# //	  jQuery(".showdiv").hide();
# //	});
# //	jQuery(".viewnoteTab").mouseenter(function(){
# //	  jQuery(".showdiv").show();
# //	});
# 	//alert("logged in ");
# }else{
# 	//alert("not logged in ");
# 	jQuery(".notif-cls").on("click",function(){
# 		//alert('hi');
# 	  jQuery("#inline_login").hide();
# 	  //jQuery(".notification .nav-drop").hide();
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# 	updateNonLoggedInUsersTime();
# }
# function updateNonLoggedInUsersTime(){
# 	//alert("non_loggedin_time:"+getCookie('non_loggedin_time'));
# 	var setCookieForTime = getCookie('non_loggedin_time');
# 	if(null!=setCookieForTime){
# 		//alert("cookie found to be set to : "+setCookieForTime+" where time since is:"+timeSince(setCookieForTime));
# 		jQuery("#non_loggedin_time").html(timeSince(setCookieForTime));
# 	}else{
# 		var currentTime = new Date().getTime();
# 		setCookie('non_loggedin_time',currentTime);
# 	}
# }
#
# jQuery(".viewnote").on("click",function(){
# 	var loggedInClicked = getCookie('loggedin_click');
# 	if(null!=loggedInClicked){
# 		jQuery("#notification_count").css("background-color","#075DC1");
# 	}else{
# 		if('true' == authenticated){
# 			setCookie('loggedin_click',1);
# 			//alert("setting loggedInClicked");
# 		}
# 	}
# });
#
# });
#
# </script>
# <!--- view notification section begin --->
# <li class="notification viewnote">
# <a class="dropdown-button" data-activates="notifyDropdown" href="#">
# <i class="material-icons left">notifications_none</i>
# <span class="notif-count-new" id="notification_count">1</span>
# 	</a>
# <div class="nav-drop viewnoteTab dropdown-content" id="notifyDropdown">
# <div class="showdiv">
# <div class="notif-not-logedin" id="non_loggedin" style="display:none;">
# <div class="notif-welcm-msg clearfix">To see all recommended jobs, profile views, recruiter's contacted information, updates and more...</div>
# <div class="notif-act clearfix">
# <button class="waves-effect waves-light btn red-bdr-btn" onclick="javascript:openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');" type="button">Login</button>
# <strong class="or">or</strong>
# <a class="waves-effect waves-light btn red-bdr-btn" href="/candidate/register.html">Register</a>
# </div>
# </div>
# <!-- INLINE LOGIN PAGE -->
# <div class="notif-login-frm" id="inline_login" style="display:none;">
# <span class="notif-cls" title="Click to Hide"></span>
# <strong>Login to View Notifications!</strong>
# <form action="/candidate/times_login?BeforeLoginUrl=notification&amp;tab=1" method="post" name="loginFormNotification">
# <input class="txt2 defaultValue inpt-typ" id="txtUseNameNotification" name="j_username" onblur="javascript:settextNotification('txtUseNameNotification');" onclick="filltxtNotification(txtUseNameNotification)" size="42" type="text" value="Enter Email id / Login id"/>
# <input class="password_input_notification" name="j_password" size="42" style="display:none" type="password" value=""/>
# <input class="clearNotification" size="42" type="text" value="Enter Password"/>
# <div class="frgt-pass"><a class="fp" href="javascript:forgotPasswordNotification();">Forgot Password?</a></div>
# <input class="" onclick="javascript:return validateLoginFormNotification();" type="submit" value="Login"/>
# <div class="error-msg dflt-msg" id="loginErrNotification" style="display:none;">
# <!--<img class="errTip" title="Error" alt="Error" src="https://static.timesjobs.com/images_cand/tj_images/home/errTipL.gif">-->
# <!--<a class="errCls" href="#"><img border="0" title="Close" alt="Close" src="/images_cand/tj_images/home/logginErrClse.gif"></a>-->
#        	      Login-ID/Password cannot be left blank. Enter the full email ID (like: ram@gmail.com), if you are using registered email-id for login.
# 	      </div>
# <input name="notlogin" type="hidden" value="mytj"/>
# <input name="_acegi_security_remember_me" type="hidden" value="yes"/>
# </form>
# </div>
# <!-- INLINE LOGIN PAGE -->
# <div class="notif-main" id="base" style="display: none;">
# <ul>
# <li class="heading clearfix" id="heading">
# <a href="#" id="heading-link"><span>Job Alerts(10)</span></a>
# </li>
# <li id="base-li" style="display: none;"><a href="#" id="base-li-anchor">5 Matching Jobs <span id="base-li-time">3 hrs ago</span></a>
# </li>
# <span class="base_li" id="base-li-data" style="display: none;"></span>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <!--- view notification section ends here --->
# <script type="text/javascript">
#
# function forgotPasswordNotification(){
# 		GB_showCenter('Forgot Password','/candidate/ForgetPassword.html',180,420);
# 	}
# var race = 0;
# function showNotificationLoginThickBox(){
#
# race = 1;
#
# 			//jQuery("#inline_login").addClass('notifyshow');
# 			//jQuery('.viewnoteTab').addClass('notifyshow');
# 			//jQuery('.showdiv').addClass('notifyshow');
# 			//jQuery(".notif-not-logedin").hide();
# 			//jQuery(".notification .nav-drop").css('display','block');
# 			//jQuery(".notification").addClass("notifi");
# 			jQuery('.clearNotification').css({color:"#b3b3b3"});
# 					jQuery('.clearNotification').focus(function(){
# 						//alert('check');
# 						jQuery(this).hide();
# 						jQuery(' .password_input_notification').show();
# 						jQuery('.password_input_notification').focus();
# 					});
# 					jQuery('.password_input_notification').blur(function(){
# 						if(this.value==''){
# 						jQuery(this).hide();
# 							jQuery('.clearNotification').show();
# 						}
# 					});
#
#
#
# }
# jQuery(".notif-cls").on("click",function(){
# 	  //jQuery("#inline_login").removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.viewnoteTab').removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.showdiv').removeClass('notifyshow');
#
# 	 // jQuery(".notif-not-logedin").show();
# 	 jQuery(".notif-not-logedin").css('display','');
# 	  //jQuery(".notification .nav-drop").css('display','none');
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# jQuery(".viewnote").mouseenter(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").show();
#   //jQuery(".notification .nav-drop").show();
#
#   if('false' == authenticated){
#     var hideCountCookie = getCookie('hide_nologgedin_count');
#     if(null == hideCountCookie){
#   		setCookie('hide_nologgedin_count',1);
#   		//alert("setting hide_nologgedin_count");
#   	}else{
#   		jQuery("#notification_count").hide();
#   	}
#   }else{
#    jQuery("#inline_login").hide();
#    jQuery("#non_loggedin").hide();
#
#    	updateNotificationComponentWithIECheck();
#   }
#
# });
# jQuery(".viewnote").mouseleave(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").hide();
#   //jQuery(".notification .nav-drop").hide();
# });
# jQuery(".notif-login-frm").mouseleave(function(){
# //alert("mouseenter called..");
#   event.stopPropagation()
# });
# function settextNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value !=''){
# 			document.getElementById(id).checked=true;
# 		}else{
# 			document.getElementById(id).checked=false;
# 			document.getElementById('txtUseNameNotification').value='Enter Email id / Login id';
# 			document.getElementById('txtUseNameNotification').style.color='#999'
# 		}
# 	}
# function filltxtNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id')
# 			document.getElementById('txtUseNameNotification').value=''
# 		document.getElementById('txtUseNameNotification').style.color='#333'
# 	}
# function validateLoginFormNotification(){
# var status = true;
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id'){
# 			document.getElementById('txtUseNameNotification').value='';
# 			status =  false;
# 		}
#
# 		if(checkBlankNotification(document.loginFormNotification.j_username,"Login ID")){
# 			status =  false;
# 		}
# 		if(checkBlankNotification(document.loginFormNotification.j_password,"Password")){
# 			status =  false;
# 		}
# 		//update_notification_cookie
# 		if(status){
# 			deleteCookie('update_notification_cookie');
# 		}
# 		return status;
# 	}
# function checkBlankNotification(field,name){
# 		if(field.value.trim() == ""){
# 			field.value = "";
# 			field.focus();
# 			document.getElementById("loginErrNotification").style.display="";
# 			return true;
# 		}
# 		return false;
# 	}
#
# var diff = 1681023594-((new Date().getTime())/1000);
#
#
# function ellipsize(str, len) {
# 	if(str.length > len) {
#  		return str.substr(0,len) + "...";
# 	} else {
# 		return str;
# 	}
# }
#
# function timeSince(previous){
#
# 	current =  new Date().getTime()+diff;
# 	var milleSecondsPerMinute = 60 * 1000;
#     var milleSecondsPerHour = milleSecondsPerMinute * 60;
#     var milleSecondsPerDay = milleSecondsPerHour * 24;
#     var milleSecondsPerMonth = milleSecondsPerDay * 30;
#     var milleSecondsPerYear = milleSecondsPerDay * 365;
#
#     var elapsed = current - previous;
#
#     if (elapsed < milleSecondsPerMinute) {
#          value = Math.round(elapsed/1000) + ' seconds ago';
#     }
#
#     else if (elapsed < milleSecondsPerHour) {
#     	value = Math.round(elapsed/milleSecondsPerMinute) + ' minutes ago';
#     }
#
#     else if (elapsed < milleSecondsPerDay ) {
#     	value = Math.round(elapsed/milleSecondsPerHour ) + ' hours ago';
#     }
#
#     else if (elapsed < milleSecondsPerMonth) {
#     	value =  Math.round(elapsed/milleSecondsPerDay) + ' days ago';
#     }
#
#     else if (elapsed < milleSecondsPerYear) {
#     	value = Math.round(elapsed/milleSecondsPerMonth) + ' months ago';
#     }
#
#     else {
#     	value = Math.round(elapsed/milleSecondsPerYear ) + ' years ago';
#     }
#     //return (value);
#     return (value);
# }
#
#
# function updateNotificationComponent(){
#  alreadyCalled  =true;
# 	var context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  context="/candidate/";
# 		  //alert("bingo");
# 	}
#
#
# 	ajaxController.getLoginId(function(response){
# 	//alert("updateNotificationComponent,response:"+response)
# 		if (response != null && response.trim().length > 0) {
# 			jQuery.ajax({
# 							cache:notification_cache,
# 							timeout:notification_timeout,
# 							url:context+"inbox-notifications.html?from=submit",
# 							success:function(data){
# 							var trimLength = 30;
# 									jQuery("#base_ja").remove();
# 									jQuery("#base_j").remove();
# 									jQuery("#base_rv").remove();
# 									//alert(data);
# 									var parsedData = JSON.parse(data);
# 									var theCount = parsedData["count"];
#
# 									var jaCount = parsedData["jaCount"];
# 									var jCount = parsedData["jCount"];
# 									var rvCount = parsedData["rvCount"];
#
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
# 									//theCount = theCount - jCount;
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
#
# 									if(theCount >= 0){
# 										if(theCount >= 0){
# 											if(theCount <99){
# 												jQuery("#notification_count").html(theCount);
# 												setCookie('notification_cookie_count',theCount);
# 											}else{
# 												jQuery("#notification_count").html("99+");
# 												setCookie('notification_cookie_count',"99+");
# 											}
# 										}
#
# 										var isNew = parsedData["new"];
# 										//alert("new:"+(isNew == true));
# 										if(isNew == true){
# 											jQuery("#notification_count").css("background-color","red");
# 											setCookie('notification_cookie_color','red');
# 											deleteCookie('loggedin_click');
# 										}else{
# 											var loggedInClicked = getCookie('loggedin_click');
# 											//alert("loggedInClicked:"+loggedInClicked);
# 											if(null!=loggedInClicked){
# 												jQuery("#notification_count").css("background-color","#075DC1");
# 												setCookie('notification_cookie_color','#075DC1');
# 											}else{
# 												jQuery("#notification_count").css("background-color","red");
# 												setCookie('notification_cookie_color','red');
# 											}
#
# 										}
# 									}
# 									jQuery("#notification_count").show();
#
# 									/* alert("count:"+parsedData["count"]);
# 									alert("jaCount:"+parsedData["jaCount"]);
# 									alert("jCount:"+parsedData["jCount"]);
# 									alert("rvCount:"+parsedData["rvCount"]); */
#
# 									/**
# 									start-JA
# 									*/
# 									if(jaCount){
# 										if(jaCount <25){
# 											jQuery("#base .heading span").html("Job alerts ("+jaCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Job alerts (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Job alerts");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jaData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jaData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jaData"])[i].subject;
# 										var since = timeSince(JSON.parse(parsedData["jaData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=1&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_ja_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_ja");
# 									//alert("jaData[0]:"+ (JSON.parse(parsedData["jaData"]).length));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-JA
# 									*/
#
# 									/**
# 									start-J
# 									*/
# 								   if(jCount){
# 									 	if(jCount <25){
# 											jQuery("#base .heading span").html("Mails from recruiters ("+jCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Mails from recruiters (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Mails from recruiters");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jData"])[i].EmployerName + " contacted you.";
# 										var since = timeSince(JSON.parse(parsedData["jData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=2&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_j_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_j");
# 									//alert("jData[0]:"+timeSince(JSON.parse(parsedData["jData"])[0].creationTime));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-J
# 									*/
#
# 									/**
# 									start-RV
# 									*/
# 									if(rvCount > 0){
# 										if(rvCount <25){
# 											jQuery("#base .heading span").html("Who's viewed your profile ("+rvCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Who's viewed your profile (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Who's viewed your profile");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["rvData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["rvData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["rvData"])[i].subject;
# 										var employerName = JSON.parse(parsedData["rvData"])[i].EmployerName + " viewed your resume.";
# 										var since = timeSince(JSON.parse(parsedData["rvData"])[i].creationTime);
# 										if(null!=employerName && employerName.length > 0){
# 											jQuery("#base-li-anchor").html(ellipsize(employerName,trimLength));
# 											jQuery("#base-li-anchor").attr("title",employerName);
# 										}else{
# 											jQuery("#base-li-anchor").html("Resume Viewed");
# 										}
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=5&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_rv_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_rv");
# 									//alert("rvData[0]:"+timeSince(JSON.parse(parsedData["rvData"])[0].employerName));
# 									jQuery("#base > ul span.base_li").html("");
# 									/**
# 									end-RV
# 									*/
#
# 									jQuery("#base").hide();
# 									jQuery("li#base-li").hide();
# 								},
# 							complete:function(){
# 								console.log("complete... inbox-notifications");
# 								jQuery("#inline_login").hide();
#    								jQuery("#non_loggedin").hide();
#    								alreadyCalled  = false;
# 							},
# 							error: function(x, t, m) {
# 								console.log("Error message"+m);
# 								 var randomnumber=Math.floor(Math.random()*100000001);
# 								 var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+context+"inbox-notifications.html?from=submit"+'&op=respTracking#'+randomnumber;
# 								 ping(nlpurl);
# 						        jQuery("#error").show();
# 							}
# 						});
#
# 		}else{
# 					jQuery("#base_ja").remove();
# 					jQuery("#base_j").remove();
# 					jQuery("#base_rv").remove();
# 					if(0 == race){
# 						jQuery("#non_loggedin").show();
# 					}
#
#
# 					var hideCountCookie = getCookie('hide_nologgedin_count');
# 					if(null != hideCountCookie){
# 						/*This is commented because for non logged in user default count 1 is being hidden.*/
# 						//jQuery("#notification_count").hide();
# 					}else{
# 						jQuery("#notification_count").css("background-color","red");
# 						jQuery("#notification_count").show();
# 					}
# 					alreadyCalled  = false;
# 		}
# 	});
# }
#
# var updateNotificationCookie = getCookie('update_notification_cookie');
# //alert("updateNotificationCookie: "+updateNotificationCookie);
# if(null == updateNotificationCookie || updateNotificationCookie==''){
# 	updateNotificationComponentWithIECheck();
# 	setCookie('update_notification_cookie',1);
# 	//alert("cookie set");
# 	scheduleNotificationCookieToDie();
# }else{
# 	if('true' == authenticated){
# 		//alert("updating from cookie!!!");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		if(null==notificationCookieCount){
# 			updateNotificationComponent();
# 		}
# 		updateNotificationFromCookie();
# 	}else{
# 		//alert("not updating from cookie!!!");
# 		updateNotificationComponentWithIECheck();
# 	}
# }
#
# function scheduleNotificationCookieToDie(){
# 	setTimeout(function() {
# 	      deleteCookie('update_notification_cookie');
# 	      deleteCookie('notification_cookie_count');
# 	      deleteCookie('notification_cookie_color');
# 	},5*60*1000);
# }
#
# function updateNotificationFromCookie(){
# console.log("cookie set for updateNotificationCookie, not making server call.");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		//alert("not setting cookie"+updateNotificationCookie);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").html(""+notificationCookieCount);
# 		}else{
# 			jQuery("#notification_count").html("1");
# 		}
# 		var notificationCookieColor = getCookie('notification_cookie_color');
# 		//alert("cookie color"+notificationCookieColor);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").css("background-color",notificationCookieColor);
# 		}else{
# 			jQuery("#notification_count").css("background-color","red");
# 		}
# 		jQuery("#notification_count").show();
# }
#
# function updateNotificationComponentWithIECheck(){
# <!--[if gte IE 9]>
# 		updateNotificationComponent();
# 	<!--<![endif]-->
# 	<!--[if lt IE 9]>
#    		jQuery(document).ready(function() {
# 			updateNotificationComponent();
# 		});
# 	<!--<![endif]-->
# }
#
# </script>
# <li class="login-reg">
# <a href="javascript:void(0);" onclick="openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');">Login</a>
# </li>
# <li class="login-reg">
# <a href="/candidate/register.html?pageFlow=TJ_SEARCH">Register</a>
# </li>
# </ul>
# </div>
# </header>
# <!--bottom banner starts-->
# <!--bottom banner ends-->
# <div class="open-search">
# <div class="usability-srch clearfix">
# <div class="main-srch-form clearfix">
# <div class="msg error" id="errorMsgDiv" style="display:none">Please provide inputs for at least one field</div>
# <form action="https://www.timesjobs.com/candidate/job-search.html" id="quickSearchBean" method="get" name="quickSearchBean" onsubmit="return searchEngine.validateSearchForm(this);">
# <input name="searchType" type="hidden" value="personalizedSearch"/>
# <input name="from" type="hidden" value="submit"/>
# <div class="auto-suggest-blk">
# <input class="browser-default" id="txtKeywords" name="txtKeywords" type="text" value="python"/>
# <div id="autoSuggestList" style="display:none;"><ul></ul></div><iframe frameborder="0" id="FrameautoSuggestList" style="display:none;"></iframe>
# <div class="suggestionList srch-suggest" id="autoSuggestList2ndKeywordsListSFB" style="display:none;">
# <h5>Suggested Keywords</h5>
# <ul></ul></div>
# </div>
# <div class="auto-suggest-blk location-srch">
# <input class="location-srch browser-default" id="txtLocation" name="txtLocation" type="text" value="mumbai"/><div id="autoSuggestLocation" style="display:none;"><ul></ul></div><iframe frameborder="0" id="FrameautoSuggestLocation" style="display:none"></iframe></div>
# <div class="srch-select">
# <select class="browser-default" id="cboWorkExp1" name="cboWorkExp1">
# <option value="-1">Experience</option>
# <option selected="selected" value="0">Entry Level</option>
# <option value="1">1 year</option>
# <option value="2">2 years</option>
# <option value="3">3 years</option>
# <option value="4">4 years</option>
# <option value="5">5 years</option>
# <option value="6">6 years</option>
# <option value="7">7 years</option>
# <option value="8">8 years</option>
# <option value="9">9 years</option>
# <option value="10">10 years</option>
# <option value="11">11 years</option>
# <option value="12">12 years</option>
# <option value="13">13 years</option>
# <option value="14">14 years</option>
# <option value="15">15 years</option>
# <option value="16">16 years</option>
# <option value="17">17 years</option>
# <option value="18">18 years</option>
# <option value="19">19 years</option>
# <option value="20">20 years</option>
# <option value="21">20+ years</option>
# </select>
# </div>
# <button class="waves-effect waves-light btn" onclick="javascript:setAClickOnSearch();" value="Search">Find Jobs</button>
# </form>
# </div>
# <div class="recent-srchs home-srchptext srch-top-right" id="recentSearchId" style="display: none;"></div>
# <div class="upload-res-uni srch-top-right clearfix" id="resNewUpload" style="display:none;">
# <div class="upload-res-txt clearfix">
# <span class="upload-icon"></span>
# <div class="upload-res-input">
# <h5>New to Timesjobs?</h5>
# <label class="upload-res-btn" id="uploadResume_basic">
#           upload your resume
#           <input id="resumeFile_basic" name="resumeFile_basic" size="25" type="file"/>
# </label>
# <span id="uploadingResume_basic" style="display:none"><img alt="Uploading Resume" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/loader.gif"/></span>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#   var ssCounterSFB=0;
# 	function openSecondSuggestionSFB(theSelectedSuggestionText){
# 		if(ssCounterSFB < 5){
# 			ajaxController.getSuggestedSkillList(theSelectedSuggestionText,"","SKILL",8,true,cb_openSecondSuggestionSFB);
# 		}else{
# 			console.log("CAND-131 Not showing 2nd suggestion.");
# 		}
# 	}
#
# 	function cb_openSecondSuggestionSFB(result){
# 		//alert("cb_openSecondSuggestion:"+result);
# 		var splitData = (""+result).split(",");
# 		var li_data = "";
# 		var dataLength = splitData.length;
# 	    var text = jQuery("#txtKeywords").val();
# 	    text =text.toLowerCase();
# 	    if(dataLength >1){
# 			for(i=0;i<dataLength;i++){
# 	            if(text.indexOf(splitData[i].toLowerCase()) < 0){
# 	                var hyperlink =  "javascript:secondSelectionClickedSFB('"+encodeURI(splitData[i])+"');";
# 					li_data+="<li><a href="+hyperlink+">"+splitData[i]+"</a></li>";
# 				}
# 			}
# 			jQuery("#autoSuggestList2ndKeywordsListSFB ul").html(li_data);
# 			jQuery("#autoSuggestList2ndKeywordsListSFB").slideDown(300);
# 			//ssCounterSFB = ssCounterSFB  + 1;
# 		}
# 	}
#
# 	function secondSelectionClickedSFB(that){
# 		//alert("that:"+that);
# 		_gaq.push(['_trackEvent','Click2Ad','tj_skillsuggestion']);
# 		jQuery("#autoSuggestList2ndKeywordsListSFB").hide();
# 		var text = jQuery("#txtKeywords").val();
# 		var text2 = text.toLowerCase() + ",";
# 		var that2 = that.toLowerCase();
# 		var res = text2.split(",");
# 		var exists = false;
# 		for(i in res){
# 			if(null!=res[i] && res[i].length > 0 && res[i]+"".trim() === that2){
# 				exists = true;
# 				break;
# 			}
# 		}
# 		//var index = text2.search(new RegExp(that2, "i"));
# 		//console.log("exists:"+exists);
# 		if(!exists){
# 			jQuery("#txtKeywords").val(text +","+ that);
# 			jQuery("#txtKeywords").focus();
# 		}
# 		openSecondSuggestionSFB(that);
# 	}
# jQuery(document).ready(function(){
# 	jQuery('#quickSearchBean input[type="text"]').DefaultInputValue();
# })
#
# function BasicResFileUpload(){
# 		//alert('uploaded re loaded');
# 		new AjaxUpload('resumeFile_basic', {
# 			action:'/candidate/servlet/FileUploadServlet',
# 			//responseType: 'json',
# 			responseType: 'true',
# 			name: 'resumeFile_basic',
# 			onSubmit : function() {
# 				//alert('11');
# 				document.getElementById("uploadResume_basic").style.display="none";
# 				document.getElementById("uploadingResume_basic").style.display="block";
# 			},
# 			onComplete : function(file,response){
# 				var displayFilename=file;
# 				if(file.length >18){
# 					displayFilename=file.substring(0,18)+"..";
# 				}
# 				response = response.replace(/'/g , '"');
# 				var jsonObj = jQuery.parseJSON(response);
# 				jsonObj["filename"] = displayFilename;
# 				ajaxController.setSessionAttribute('tjindexResumeUploadMsg', jsonObj["MESSAGE"]);
# 				response = JSON.stringify(jsonObj);
# 				ajaxController.setSessionAttribute('tjindexResumeUpload', response);
# 				//window.open('/candidate/register.html', '_blank');
# 				window.location ='/candidate/register.html';
# 			}
# 		});
# 	}
# 	BasicResFileUpload();
#   </script>
# </div>
# <script>
# var name='null';
# var phone='null';
# var email='null';
# //alert("name"+name);
# //alert("phone Num"+phone);
# if((phone!=null && $.trim(phone).length>0)&& phone.indexOf("+91-")!=-1){
#    phone = phone.replace("+91-",'');
# }
#
# FRESHCHAT_VISITORINFO={"name":name,"email":email,"phone":phone};
# </script>
# <script type="text/javascript">
#
# //	alert("Hello");
# 	    var fc_CSS = document.createElement('link');
# 	    fc_CSS.setAttribute('rel', 'stylesheet');
# 	    var fc_isSecured = (window.location && window.location.protocol == 'https:');
# 	    var fc_lang = document.getElementsByTagName('html')[0].getAttribute('lang');
# 	    var fc_rtlLanguages = ['ar', 'he'];
# 	    var fc_rtlSuffix = (fc_rtlLanguages.indexOf(fc_lang) >= 0) ? '-rtl' : '';
# 	    fc_CSS.setAttribute('type', 'text/css');
# 	    fc_CSS.setAttribute('href', ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets1.chat.freshdesk.com') + '/css/visitor' + fc_rtlSuffix + '.css');
# 	    document.getElementsByTagName('head')[0].appendChild(fc_CSS);
# 	    var fc_JS = document.createElement('script');
# 	    fc_JS.type = 'text/javascript';
# 	    fc_JS.defer = true;
# 	    fc_JS.src = ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets.chat.freshdesk.com') + '/js/visitor.js';
# 	    (document.body ? document.body : document.getElementsByTagName('head')[0]).appendChild(fc_JS);
# 	    window.freshchat_setting = '...';
#
# </script>
# <script type="text/javascript">
#
# if(document.getElementById("chat-widget") != undefined){
# document.getElementById("chat-widget").addEventListener("click", function(event){
#     event.preventDefault()
# });
# }
# </script>
# <script type="text/javascript">
# 		$(function(){
# 			$('.nav-search').click(function(e){
# 				$('.common-search').slideToggle();
# 			});
# 			 $('.dropdown-button').dropdown({
# 				  inDuration: 300,
# 				  outDuration: 225,
# 				  constrainWidth: false,
# 				  hover: true,
# 				  gutter: 0,
# 				  belowOrigin: false,
# 				  alignment: 'left',
# 				  stopPropagation: false
# 			}
# 		  );
# 		});
# 	</script>
# <script>
# 	jQuery(function() {
# 		//bottom banner starts
# 		jQuery('.bot-bnr').append('<span class="up-dwn-arrow"></span><span class="bot-bnr-cls"></span>');
# 		jQuery('.bot-bnr').addClass('bot-bnr-expnd',1000);
# 		setTimeout(function(){
# 		jQuery('.bot-bnr').removeClass('bot-bnr-expnd',1000);}, 5000);
# 		jQuery('.bot-bnr-cls').on("click", function() {
# 		  jQuery(this).parent("div").addClass('bot-bnr-csl',1000);
# 		});
# 		jQuery('.up-dwn-arrow').on("click", function() {
# 		  jQuery(this).parent("div").toggleClass('bot-bnr-expnd',1000);
# 		});
# 		//bottom banner ends
# 	});
# </script>
# <!-- Header Ends -->
# <!-- Content Starts   -->
# <div class="ubility-wrap clearfix">
# <!--Cluster related page inclusion start here-->
# <!--Cluster related page inclusion end here-->
# <section class="ubility-lhs clearfix">
# <div class="inside-lhs" id="search-result-cluster">
# <div class="wht-bdr-bx tj-cluster">
# <h4><i class="material-icons">sort</i>Refined By</h4>
# <!--  <div id="clusterRefineHistoryId"></div>-->
# <!--
#   <ul class="tab-filter clearfix">
#
#       <li class="tab-tc" id="tab-tc"><a href="#tabtc">Top Companies</a></li>
#
#
#     <li class="tab-jf" id="tab-jf"><a href="#tabjf">Job Function</a></li>
#
#       <li class="tab-loc" id="tab-loc"><a href="#tabloc">Location</a></li>
#
#
#
#
#       <li class="tab-ind" id="tab-ind"><a href="#tabind">Industry</a></li>
#
#
#
#
#       <li class="tab-sal" id="tab-sal"><a href="#tabsal">Salary</a></li>
#
#   </ul>
# -->
# <div id="tj-tab-container-clusterId">
# <div id="clusterDataInitial">
# <ul class="collapsible" data-collapsible="expandable">
# <li id="tabtc">
# <div class="collapsible-header active"><h6>Companies</h6></div>
# <div class="cluster-scroll collapsible-body">
# <ul>
# <div id="comp_show">
# <li>
# <input id="com_0" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=morgan+stanley+pvt+ltd&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=morgan+stanley+pvt+ltd&amp;gadLink=View Jobs By This Company','Morgan Stanley Pvt Ltd');" type="checkbox"/>
# <label for="com_0">
# <span title="Morgan Stanley Pvt Ltd">
#                 Morgan Stanley Pvt Ltd
#                 </span> <span class="grey-text">(12)</span></label>
# </li>
# <li>
# <input id="com_1" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=verisk+analytics+india+private+limited&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=verisk+analytics+india+private+limited&amp;gadLink=View Jobs By This Company','Verisk Analytics India Private Limited');" type="checkbox"/>
# <label for="com_1">
# <span title="Verisk Analytics India Private Limited">
#                 Verisk Analytics India Private..
#                 </span> <span class="grey-text">(4)</span></label>
# </li>
# <li>
# <input id="com_2" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=crimson+interactive+pvt+ltd&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=crimson+interactive+pvt+ltd&amp;gadLink=View Jobs By This Company','Crimson Interactive Pvt Ltd');" type="checkbox"/>
# <label for="com_2">
# <span title="Crimson Interactive Pvt Ltd">
#                 Crimson Interactive Pvt Ltd
#                 </span> <span class="grey-text">(3)</span></label>
# </li>
# <li>
# <input id="com_3" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=hiotron+india+pvt+ltd&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=hiotron+india+pvt+ltd&amp;gadLink=View Jobs By This Company','Hiotron India Pvt Ltd');" type="checkbox"/>
# <label for="com_3">
# <span title="Hiotron India Pvt Ltd">
#                 Hiotron India Pvt Ltd
#                 </span> <span class="grey-text">(3)</span></label>
# </li>
# <li>
# <input id="com_4" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=boyen+haddin+consultants+llp&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;searchType=personalizedSearch&amp;txtLocation=mumbai&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=0&amp;undokey=compCluster&amp;compCluster=boyen+haddin+consultants+llp&amp;gadLink=View Jobs By This Company','Boyen Haddin Consultants Llp');" type="checkbox"/>
# <label for="com_4">
# <span title="Boyen Haddin Consultants Llp">
#                 Boyen Haddin Consultants Llp
#                 </span> <span class="grey-text">(2)</span></label>
# </li>
# <li>
# ...
# 	background-position: center;
# 	background-repeat: no-repeat;
# 	width: 510px;
# 	height: 310px;
# 	border-radius: 8px;
# 	margin: auto;
# 	font-size: 14px;
# 	padding: 20px;
# 	display: none;
# }
#
# .registration-message p {
# 	margin: 0px;
# 	padding: 0 30px 0px 30px;
# 	text-align: center;
# 	line-height: 21px;
# 	font-size: 14px;
# }
#
# .registration-message .registration-close {
# 	color: #ccc;
# 	font-size: 16px;
# 	font-weight: bold;
# 	top: 10px;
# 	right: 15px;
# 	position: absolute;
# 	cursor: pointer;
# }
#
# .registration-message .registration-btn-close {
# 	text-decoration: none;
# 	color: #fff;
# 	font-size: 12px;
# 	background-color: #EE2525;
# 	text-align: center;
# 	-webkit-transition: .2s ease-out;
# 	transition: .2s ease-out;
# 	cursor: pointer;
# 	padding: 10px 20px;
# 	font-weight: bold;
# 	border:none;
# }
#
# .registration-message .heading {
# 	color: #01439F;
# 	font-size: 18px;
# 	font-weight: bold;
# 	text-align: center;
# 	padding: 24px 0;
# 	margin: 0px;
# }
# </style>
# <div class="registration-overlay"></div>
# <div class="registration-message">
# <span class="registration-close" oncli="">X</span>
# <h2 class="heading">We care for you!</h2>
# <p>
# <strong>Please note:</strong> TimesJobs or its recruiting partners do
# 		not charge money or fee from candidates for recruitment or anything
# 		else. If anyone calls you asking for money or payment for
# 		registration, application process, resume service, etc, then please
# 		report it immediately to <a href="mailto:corporatecare@timesinternet.in">corporatecare@timesinternet.in</a>
# <br/>
# <br/>
# <button class="registration-btn-close">OK</button>
# </p>
# </div>
# <script>
# 	let isFDivClosed = false;
#
# 	$(document).ready(function(){
# 		getFraudBannerShowStatus();
# 	})
#
# 	function registerFraudBannerEvents(){
# 		$(".registration-overlay, .registration-message").css("display", "block");
# 		/* $(".registration-close, .registration-btn-close").on(
# 			"click",
# 			function() {
# 				$(".registration-overlay, .registration-message").css("display", "none");
# 				updateStatus();
# 			}); */
# 	}
# 	/*
# 	$(window).on(
# 			'load',
# 			function() {
# 				$(".registration-overlay, .registration-message").css("display", "block");
# 			});
# 	*/
# 	$(".registration-close, .registration-btn-close").on("click", function() {
# 				$(".registration-overlay, .registration-message").css("display", "none");
# 				updateStatus();
# 			});
#
#
#  	function updateStatus(){
# 		if(isFDivClosed === false){
# 			updateFraudBannerStatus();
# 		}
# 	}
#
# 	setTimeout(autoFDivClose, 30000);
#
# 	function autoFDivClose(){
# 		if(isFDivClosed === false){
# 			//updateFraudBannerStatus();
# 			isFDivClosed = true;
# 			$(".registration-overlay, .registration-message").css("display", "none");
# 		}
# 	}
#
# 	function updateFraudBannerStatus(){
# 		var context="/candidate/";
# 		jQuery.ajax({
#  					url:context + 'updateFraudBannerStatus.json?&source=TJWEB',
#  					beforeSend:function(){
# 						console.log("beforeSend... updateFraudBannerStatus");
# 						},
# 					success:function(jsonResp){
#    	 					 console.log('updateFraudBannerStatus loaded successfully : ',jsonResp)
# 						},
# 					complete:function(){
# 						console.log("complete... updateFraudBannerStatus");
# 						isFDivClosed = true;
# 						$(".registration-overlay, .registration-message").css("display", "none");
# 					}
#  				});
# 	}
#
# 	function getFraudBannerShowStatus(){
# 		var context="/candidate/";
# 		jQuery.ajax({
#  					url:context + 'getFraudBannerShowStatus.json?&source=TJWEB',
#  					beforeSend:function(){
# 						console.log("beforeSend... updateFraudBannerStatus");
# 						},
# 					success:function(jsonResp){
#    	 					 console.log('updateFraudBannerStatus loaded successfully : ',jsonResp)
#    	 					 console.log('jsonResp : ',jsonResp)
#    	 					 if(jsonResp != null && jsonResp['showfraudbanner'] != null && jsonResp['showfraudbanner'] === true){
#    	 					 	isFDivClosed = false;
#    	 					 	registerFraudBannerEvents();
#    	 					 }
# 						},
# 					complete:function(){
#
# 					}
#  				});
# 	}
#
#
#
# </script>
# <!-- Footer Ends   -->
# <script type="text/javascript">
#         var GB_ROOT_DIR = "/candidate/greybox/";
#     </script>
# <link href="https://static.timesjobs.com/newtj_css/css/tj_css/personlisation/gb_styles.css" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://static.timesjobs.com/newtj_js/scripts/groupJs/searchResultTempGroup.js?v=7.1.7" type="text/javascript"></script>
# <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
# <!--[if IE]><script src="https://static.timesjobs.com/newtj_js/scripts/html5.js"></script><![endif]-->
# <script type="text/javascript">
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6036484" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#
#   function trackAjaxSRPresult(url, type) {
# 		var title = document.getElementsByTagName("title")[0].innerHTML;
# 		title = title.replace("TimesJobs.com", type + " Jobs");
# 		title = title.concat(" | TimesJobs.com");
#
# 		var t = "2", n = "6036484", r = "", i = encodeURIComponent(url), s = "", o = "", u = encodeURIComponent(title), a = "", f = "2.0", l = "1";
# 		var c = document.createElement("img");
# 		c.src = "https://sb.scorecardresearch.com/p?c1=" + t + "&c2=" + n +"&c3=" + r + "&c4=" + i + "&c5=" + s + "&c6=" + o + "&c8=" + u + "&c15=" + a + "&cv=" + f + "&cj=" + l + "&ns__t=" + (new Date).getTime();
# 		document.body.appendChild(c);
# 	}
#
#
# </script>
# <noscript>
# <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6036484&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <script type="text/javascript">
# /*!
# * jQuery Cookie Plugin v1.3.1
# * https://github.com/carhartl/jquery-cookie
# *
# * Copyright 2013 Klaus Hartl
# * Released under the MIT license
# */
# (function (factory) {
# if (typeof define === 'function' && define.amd && define.amd.jQuery) {
# // AMD. Register as anonymous module.
# define(['jquery'], factory);
# } else {
# // Browser globals.
# factory(jQuery);
# }
# }(function ($) {
#
# var pluses = /\+/g;
#
# function raw(s) {
# return s;
# }
#
# function decoded(s) {
# return decodeURIComponent(s.replace(pluses, ' '));
# }
#
# function converted(s) {
# if (s.indexOf('"') === 0) {
# // This is a quoted cookie as according to RFC2068, unescape
# s = s.slice(1, -1).replace(/\\"/g, '"').replace(/\\\\/g, '\\');
# }
# try {
# return config.json ? JSON.parse(s) : s;
# } catch(er) {}
# }
#
# var config = $.cookie = function (key, value, options) {
#
# // write
# if (value !== undefined) {
# options = $.extend({}, config.defaults, options);
#
# if (typeof options.expires === 'number') {
# var days = options.expires, t = options.expires = new Date();
# t.setDate(t.getDate() + days);
# }
#
# value = config.json ? JSON.stringify(value) : String(value);
#
# return (document.cookie = [
# encodeURIComponent(key), '=', config.raw ? value : encodeURIComponent(value),
# options.expires ? '; expires=' + options.expires.toUTCString() : '', // use expires attribute, max-age is not supported by IE
# options.path ? '; path=' + options.path : '',
# options.domain ? '; domain=' + options.domain : '',
# options.secure ? '; secure' : ''
# ].join(''));
# }
#
# // read
# var decode = config.raw ? raw : decoded;
# var cookies = document.cookie.split('; ');
# var result = key ? undefined : {};
# for (var i = 0, l = cookies.length; i < l; i++) {
# var parts = cookies[i].split('=');
# var name = decode(parts.shift());
# var cookie = decode(parts.join('='));
#
# if (key && key === name) {
# result = converted(cookie);
# break;
# }
#
# if (!key) {
# result[name] = converted(cookie);
# }
# }
#
# return result;
# };
#
# config.defaults = {};
#
# $.removeCookie = function (key, options) {
# if ($.cookie(key) !== undefined) {
# $.cookie(key, '', $.extend(options, { expires: -1 }));
# return true;
# }
# return false;
# };
#
# }));
# </script>
# <script type="text/javascript">
# 	jQuery.cookie('previous_browser_url', $.cookie('current_browser_url'));
# 	jQuery.cookie('current_browser_url', window.location.href);
# 	//setCookie('previous_browser_url',getCookie('current_browser_url'));
# 	//setCookie('current_browser_url', window.location.href);
# </script>
# <script type="text/javascript">
# 	function getPredefinedActionName(url){
# 		var returnActionName = "";
# 		var from = url.lastIndexOf("/");
# 		var to = url.indexOf("?",from);
# 		if(-1!=to){
# 			returnActionName = url.substring(from,to);
# 		}else{
# 			returnActionName = url.substring(from);
# 		}
# 		return returnActionName;
# 	}
# 	</script>
# <script type="text/javascript">
#
# var notification_timeout = 10000;
# var notification_cache = true;
# function ping(url){
#  var ImageObject = new Image();
#  ImageObject.src = url; //e.g. logo
# }
# var cand_context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  cand_context="/candidate/";
# 		  //alert("bingo");
# 	}
#
# 		function getMailInBoxUnreadCount(){
# 			var rurl=cand_context+"inbox-message-get-unread-count.html";
# 			jQuery.ajax({
# 				cache:notification_cache,
# 				url:rurl,
# 				success:function(data){
# 					console.log("success... inbox-message-get-unread-count.html"+'');
# 				},
# 				error: function(x, textStatus, m) {
# 					console.log("Failed"+m);
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            //do something. Try again perhaps?
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    	}
# 			});
# 		}
#
# 		function getDistinctEmployerCounts(){
# 		 var rurl=cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_RE";
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:rurl,
# 			success:function(data){
# 				//alert("RE-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_re").html(data);
# 				jQuery("#mytj_header_re").html(data);
# 				jQuery("#homeindex_inbox_re").html(data);
# 				jQuery("#headerhome_inbox_re").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			            console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			            //do something. Try again perhaps?
# 			        }
# 		    }
#
# 		});
# 	//alert("call in progress...");
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV",
# 			success:function(data){
# 				//alert("PV-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_pv").html(data);
# 				jQuery("#mytj_header_pv").html(data);
# 				jQuery("#homeindex_inbox_pv").html(data);
# 				jQuery("#headerhome_inbox_pv").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV"+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    }
# 		});
# 	 }
# 	function displayLoading(div){
# 	if(1 == tab || 2 == tab || 4 == tab || 5 == tab  ){
# 			jQuery(div).append("<div class='loading'>&nbsp;</div>");
# 	}
# }
# </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "location": {
#     "@type": "Place",
#     "address": "TimesJobs.com, Times Business Solutions (A Division of Times Internet Ltd.), Times Center (Digital Content Production Facility), FC - 6, (Ground Floor), Sector 16 A, Film City, NOIDA - 201 301, Uttar Pradesh, India"
#   },
#   "name": "TimesJobs.com",
#   "description": "TimesJobs: India's Leading Job Portal",
#   "logo": "https://static.timesjobs.com/images_cand/tj_images/logos/tj_logo_300x300.jpg",
#   "url": "https://www.timesjobs.com",
#   "email": "timesjobs@timesgroup.com"
# }
# </script>
# <script type="application/ld+json">
# {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "https://www.timesjobs.com",
#     "potentialAction": {
#       "@type": "SearchAction",
#       "target": "https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords={search_term_string}",
#       "query-input": "required name=search_term_string"
#     }
# }
# </script>
# <!--Common Template Included in all files end here  -->
# <!--google analytics start-->
# <script type="text/javascript">
# 	var _gaq = _gaq || [];
#
#
#
#
#
#
#
#
# 			_gaq.push(['_setAccount', 'UA-1688637-1']);
#
#
#   _gaq.push(['_trackPageview']);
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
#   function trackClickEvent(category,action){
# 		_gaq.push(['_trackEvent',category,action]);
# 	}
# </script>
# <!--google analytics ends-->
# <img alt="" border="0" height="1" src="https://tracking.sokrati.com/site?client_id=60&amp;product_category=Site_Search" width="1"/>
# <script type="text/javascript">
#
# 	function removeSpecificRefineNew(urltoHit){
#  	getSRPResultByDwrNew(urltoHit);
#  	return false;
#  }
#
#  function getSRPResultByDwrNew(urlToHit) {
# 		jQuery( "#refine-opt-search-datewise a" ).removeClass( "refinejobsopt" );
# 		jQuery("#defualtSelectedDate").addClass( "refinejobsopt" );
# 		jQuery("#searchResultData").remove();
# 		jQuery("#searchResultContents").html(dataImageLoader);
# 		var matchStr=urlToHit.match("&undo=(.*)&undoValue");//For Selecting tab on Cluster
#
# 		ajaxController.getDWRBasedWebResponse(urlToHit,function(data) {
# 							if (data != null && data != 'undefined') {
# 								jQuery("#searchResultContents").html(data);
#
# 								console.info("matchStr=="+matchStr);
# 								if(chkNull(matchStr)){
# 									console.info("matched text at posotion 1="+matchStr[1]);
# 									showSelectedTabData(matchStr[1]);
# 								}
# 								if(matchStr==null && urlToHit.indexOf("undo=")!=-1){
# 									//jQuery( ".refined-bx" ).tabs("refresh");
#
# 								}
# 								//For making initial tab selected
# 								if(urlToHit.indexOf("&reset")!=-1){
# 									console.info("inside reset all tab");
# 									//jQuery( ".refined-bx" ).tabs("refresh");
# 								}
# 							} else {
# 								jQuery("#searchResultContents").html("Oops! There seems to be a technical problem. Please try again");
# 							}
# 						});
# 						return false;
# 	}
#
#
#
# 	if (top != self){
# 		window.open(self.location.href,"_top");
# 	}
# 	var siteId='1040';
# 	var stype = 'timesjobs.com';
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://ceoconnect.in/feedback/scripts/feedbackInc.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
# </div>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/lightBox.js" type="text/javascript"></script>
# <div class="modal" id="light-box-popup">
# <span class="material-icons close-modal modal-action modal-close">close</span>
# <div class="modal-content" id="light-box-popup-content"></div>
# </div>
# <!-- <script type="text/javascript">
#   $(document).ready(function(){
# 	    // the "href" attribute of the modal trigger must specify the modal ID that wants to be triggered
# 	    $('.modal').modal();
# 	  });
#
#   </script> -->
# <!--  ##########################  JobBuzz Ads  ################## -->
# </body>
# </html>
#
# Maxgen Technologies
#      (More Jobs)
