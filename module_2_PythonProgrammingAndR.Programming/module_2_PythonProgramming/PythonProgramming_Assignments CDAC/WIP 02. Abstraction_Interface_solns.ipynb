# %% [markdown]
# 1. Create an abstract class Shape that has abstract methods area() and perimeter(). Create subclasses Rectangle and Circle that inherit from Shape and implement the area() and perimeter() methods as appropriate.

# %% [markdown]
# 2. Create an abstract class Animal that has an abstract method speak(). Create subclasses Dog, Cat, and Cow that inherit from Animal and implement the speak() method to print out the appropriate sound for each animal.

# %% [markdown]
# 3. Create an abstract class BankAccount that has abstract methods deposit() and withdraw(). Create subclasses CheckingAccount and SavingsAccount that inherit from BankAccount and implement the deposit() and withdraw() methods as appropriate.

# %% [markdown]
# 4. Create an abstract class Person that has abstract methods greet() and introduce(). Create subclasses Student and Teacher that inherit from Person and implement the greet() and introduce() methods as appropriate.

# %% [markdown]
# 5. Create an abstract class Transportation that has abstract methods start() and stop(). Create subclasses Car and Motorcycle that inherit from Transportation and implement the start() and stop() methods as appropriate.

# %% [markdown]
# 6. Create an abstract class Employee that has abstract methods calculate_salary() and get_department(). Create subclasses Manager, Developer, and Designer that inherit from Employee and implement the calculate_salary() and get_department() methods as appropriate.

# %% [markdown]
# 7. Create an abstract class Shape that has abstract methods area() and perimeter(). Create subclasses Rectangle, Square, and Circle that inherit from Shape and implement the area() and perimeter() methods as appropriate.

# %% [markdown]
# 8. Create an abstract class Animal that has an abstract method eat(). Create subclasses Herbivore and Carnivore that inherit from Animal and implement the eat() method as appropriate.

# %% [markdown]
# 9. Create an abstract class BankAccount that has abstract methods deposit() and withdraw(). Create subclasses CheckingAccount and SavingsAccount that inherit from BankAccount and implement the deposit() and withdraw() methods as appropriate.

# %% [markdown]
# 10. Create an abstract class Person that has abstract methods greet() and introduce(). Create subclasses Student, Teacher, and Administrator that inherit from Person and implement the greet() and introduce() methods as appropriate.

# %%
class Person:
    def greet(self):
        pass
    def introduce(self):
        pass
class Student(Person):
    def __init__(self, naam):
        self.__name=naam
        self.greet()
        self.introduce()
    def greet(self):
        print("Hello from student")
    def introduce(self):
        print("My name is", self.__name, "and I'm student")
class Teacher(Person):
    def __init__(self, naam):
        self.__name=naam
        self.greet()
        self.introduce()
    def greet(self):
        print("Hello from Teacher")
    def introduce(self):
        print("My name is", self.__name, "and I'm Teacher")
class Administrator(Person):
    def __init__(self, naam):
        self.__name=naam
        self.greet()
        self.introduce()
    def greet(self):
        print("Hello from Administrator")
    def introduce(self):
        print("My name is", self.__name, "and I'm administrator")
adm=Administrator("Davinder")
tchr=Teacher("Surinder")
stud=Student("Sahil")
# Out:
# Hello from Administrator
# My name is Davinder and I'm administrator
# Hello from Teacher
# My name is Surinder and I'm Teacher
# Hello from student
# My name is Sahil and I'm student
