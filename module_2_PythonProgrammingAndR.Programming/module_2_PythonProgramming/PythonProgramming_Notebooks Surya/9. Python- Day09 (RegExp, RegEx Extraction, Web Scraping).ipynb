# %% [markdown]
# Regular Expression

# %%
import re
string = "The quick brown fox jumps over the lazy dog."
pattern="brown"
match=re.search(pattern, string) # returns True/False, used for validation
if match:
    print("Match found:", match.group())
else:
    print("Match not found")
# Out:
# Match found: brown

# %%
import re
string = "The quick brown fox jumps over the lazy dog."
pattern="The"
match=re.match(pattern, string)
if match:
    print("Match found:", match.group())
else:
    print("Match not found")
# Out:
# Match found: The

# %%
import re
string = "The quick brown fox jumps over the lazy dog."
pattern="[aeiou]"
matches=re.findall(pattern, string)
if matches:
    print("Match found:", matches)
else:
    print("Match not found")
# Out:
# Match found: ['e', 'u', 'i', 'o', 'o', 'u', 'o', 'e', 'e', 'a', 'o']

# %%
import re
string = "The quick brown fox jumps over the lazy dog."
pattern="brown"
new_str=re.sub(pattern, "red", string)
print(new_str)
print(string) # actual string
# Out:
# The quick red fox jumps over the lazy dog.
# The quick brown fox jumps over the lazy dog.

# %%
import re
string = "The quick brown fox jumps over the lazy dog."
pattern="\s+"
split_str=re.split(pattern, string)
print(split_str)
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog.']

# %% [markdown]
# Match any character: . (dot)
# Example: a.b matches "a b", "a1b", "a!b", etc.
#
# Match the start of a string: ^
# Example: ^hello matches "hello world", but not "world hello"
#
# Match the end of a string: $
# Example: world$ matches "hello world", but not "world hello"
#
# Match any single digit: \d
# Example: \d matches any digit from 0 to 9
#
# Match any non-digit character: \D
# Example: \D matches any character that is not a digit
#
# Match any whitespace character: \s
# Example: \s matches spaces, tabs, and newlines
#
# Match any non-whitespace character: \S
# Example: \S matches any character that is not whitespace
#
# Match any word character (letters, digits, or underscore): \w
# Example: \w+ matches one or more word characters (letters, digits, or underscore)
#
# Match any non-word character: \W
# Example: \W matches any character that is not a word character
#
# Match zero or one occurrence of the previous character: ?
# Example: colou?r matches "color" and "colour"
#
# Match zero or more occurrences of the previous character: *
# Example: ab*c matches "ac", "abc", "abbc", etc.
#
# Match one or more occurrences of the previous character: +
# Example: ab+c matches "abc", "abbc", "abbbc", etc.
#
# Match a specific number of occurrences of the previous character: {m}
# Example: a{3} matches "aaa"
#
# Match a range of occurrences of the previous character: {m,n}
# Example: a{2,4} matches "aa", "aaa", and "aaaa"
#
# Match any one of a set of characters: []
# Example: [abc] matches "a", "b", or "c"
#
# Match any character except those in a set: [^]
# Example: [^abc] matches any character except "a", "b", or "c"
#
# Match the same characters as a previously captured group: \1, \2, etc.
# Example: (\w) is \1 matches "a is a", "b is b", etc.
#
# These are just some of the most common regular expressions used in Python. There are many more advanced regular expressions available as well.

# %% [markdown]
# ##validation through Regular Expression (RE)
# 1. re.search(pattern, string)  ----  to check if pattern is present or net
# 2. re.findall(pattern, string)  ----  to find all occurences of pattern in string
# 3. re.sub(pattern, newpattern, inp)        to replace string
# 4.

# %%
import re
p='[a-z]'
string=input("Enter data to check: ")
if re.search(p, string):
    print("yes")
else:
    print("No")

p2='\d'
string=input("Enter data to check: ")
if re.search(p2, string):
    print("yes")
else:
    print("No")
# Out:
# Enter data to check: amar123
# yes
# Enter data to check: amar123panchal
# yes

# %%
import re
p='[a-zA-Z0-9]'
string=input("Enter data to check: ")
if re.search(p, string):
    print("yes")
else:
    print("No")
# Out:
# Enter data to check: Amar123panchal
# yes

# %%
import re
p='(.com|.co.in|.in|man)'
i=input("Enter data to check: ")
if re.search(p, i):
    print("yes")
else:
    print("No")
# Out:
# Enter data to check: google.com
# yes

# %%
import re
p='[a-zA-Z0-9]+\.' # seaches for dot at end
string=input("Enter data to check: ")
if re.search(p, string):
    print("yes")
else:
    print("No")
# Out:
# Enter data to check: asds121cs.
# yes

# %%
import re
p='[0-9]+\.+[0-9]+\.+[0-9]+\.+[0-9]' # IP validation
string=input("Enter data to check: ")
if re.search(p, string):
    print("yes")
else:
    print("No")
# Out:
# Enter data to check: 123amar.hehe.gone
# No

# %%
import re
p='[a-zA-Z0-9]+\@+[a-zA-Z]+\.+[a-zA-Z]' # email validation
string=input("Enter data to check: ")
if re.search(p, string):
    print("yes")
else:
    print("No")
# Out:
# Enter data to check: sachin@iyla.com
# yes

# %%
import re
p='\d{10}' # mobile validation
i=input("Enter data to check: ")
if re.search(p, i):
    print("yes")
else:
    print("No")
# Out:
# Enter data to check: 8787878787
# yes

# %%
import re
p='^\d{2}' # starts with 2
i=input("Enter data to check: ")
if re.search(p, i):
    print("yes")
else:
    print("No")
# Out:
# Enter data to check: 2656
# yes

# %%
import re
p='\d{2}$' # ends with 2
i=input("Enter data to check: ")
if re.search(p, i):
    print("yes")
else:
    print("No")
# Out:
# Enter data to check: 5662
# yes

# %%
import re
p='\d{2}$' # 
i=input("Enter data to check: ")
if re.search(p, i):
    print("yes")
else:
    print("No")

# %% [markdown]
# ##Extraction

# %%
pattern="[\W]+" #word separated
inp=input("Enter data to check: ")
data=re.findall(pattern, inp)
print("Final result: ", data)
# Out:
# Enter data to check: ajkda 789 jnk** k*(
# Final result:  [' ', ' ', '** ', '*(']

# %%
pattern="\+(\d{2})-(\d{4})-(\d{6})" # pattern for telephone number
newpattern=r"Country:\1 Area:\2 Number\3" # r"" is raw string, will replace the matching pattern
inp=input("Enter data to check: ")
newstr=re.sub(pattern, newpattern, inp)
print("Final result: ", newstr)
# Out:
# Enter data to check: +91-1923-220007
# Final result:  Country:91 Area:1923 Number220007

# %%
import re
log='''192.168.198.92 - - [22/Dec/2002:23:08:37 -0400] "GET 
   / HTTP/1.1" 200 6394 www.yahoo.com 
   "-" "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1...)" "-"
192.168.198.92 - - [22/Dec/2002:23:08:38 -0400] "GET 
   /images/logo.gif HTTP/1.1" 200 807 www.yahoo.com 
   "http://www.some.com/" "Mozilla/4.0 (compatible; MSIE 6...)" "-"
192.168.72.177 - - [22/Dec/2002:23:32:14 -0400] "GET 
   /news/sports.html HTTP/1.1" 200 3500 www.yahoo.com 
   "http://www.some.com/" "Mozilla/4.0 (compatible; MSIE ...)" "-"
192.168.72.177 - - [22/Dec/2002:23:32:14 -0400] "GET 
   /favicon.ico HTTP/1.1" 404 1997 www.yahoo.com 
   "-" "Mozilla/5.0 (Windows; U; Windows NT 5.1; rv:1.7.3)..." "-"
192.168.72.177 - - [22/Dec/2002:23:32:15 -0400] "GET 
   /style.css HTTP/1.1" 200 4138 www.yahoo.com 
   "http://www.yahoo.com/index.html" "Mozilla/5.0 (Windows..." "-"
192.168.72.177 - - [22/Dec/2002:23:32:16 -0400] "GET 
   /js/ads.js HTTP/1.1" 200 10229 www.yahoo.com 
   "http://www.search.com/index.html" "Mozilla/5.0 (Windows..." "-"
192.168.72.177 - - [22/Dec/2002:23:32:19 -0400] "GET 
   /search.php HTTP/1.1" 400 1997 www.yahoo.com 
   "-" "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; ...)" "-"'''

# %%
pattern="[0-9]+\.[0-9]+\.[0-9]+\.[0-9]"
iplist=re.findall(pattern, log)
print(iplist)
# Out:
# ['192.168.198.9', '192.168.198.9', '192.168.72.1', '192.168.72.1', '192.168.72.1', '192.168.72.1', '192.168.72.1']

# %%
pattern="[0-9]{2}/[a-zA-Z]{3}/[0-9]{4}"
datelist=re.findall(pattern, log)
print(datelist)
# Out:
# ['22/Dec/2002', '22/Dec/2002', '22/Dec/2002', '22/Dec/2002', '22/Dec/2002', '22/Dec/2002', '22/Dec/2002']

# %%
pattern="\d+/\w{3}/\d+"
datelist=re.findall(pattern, log)
print(datelist)
# Out:
# ['22/Dec/2002', '22/Dec/2002', '22/Dec/2002', '22/Dec/2002', '22/Dec/2002', '22/Dec/2002', '22/Dec/2002']

# %% [markdown]
# ##Web-Scraping

# %%
from bs4 import BeautifulSoup
import requests
f=requests.get("https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=mumbai&cboWorkExp1=0").text

soup=BeautifulSoup(f, 'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html><head>
# <link href="https://fonts.googleapis.com/css?family=Poppins:400,500,600,700" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/jquery.tokeninput.js" type="text/javascript"></script>
# ...

# %%
from bs4 import BeautifulSoup
import requests
f=requests.get("https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=mumbai&cboWorkExp1=0").text

soup=BeautifulSoup(f, 'lxml')
soup.prettify()
#print(soup)
# Out:
# '<!DOCTYPE html>\n<html>\n <head>\n  <link href="https://fonts.googleapis.com/css?family=Poppins:400,500,600,700" rel="stylesheet"/>\n  <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>\n  <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>\n  <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>\n  <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>\n  <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js" type="text/javascript">\n  </script>\n  <script src="https://static.timesjobs.com/newtj_js/scripts/jquery.tokeninput.js" type="text/javascript">\n  </script>\n  <!-- <script type="text/javascript" src="https://code.angu
# ...

# %%
from bs4 import BeautifulSoup
import requests
f=requests.get("https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=mumbai&cboWorkExp1=0").text

soup=BeautifulSoup(f, 'lxml')
soup.prettify().split()

#print(soup)
# Out:
# ['<!DOCTYPE',
#  'html>',
#  '<html>',
#  '<head>',
#  '<link',
#  'href="https://fonts.googleapis.com/css?family=Poppins:400,500,600,700"',
#  'rel="stylesheet"/>',
#  '<link',
#  'href="https://fonts.googleapis.com/icon?family=Material+Icons"',
#  'rel="stylesheet"/>',
#  '<link',
#  'href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.7"',
#  'media="all"',
#  'rel="stylesheet"',
#  'type="text/css"/>',
#  '<link',
#  'href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.7"',
#  'media="all"',
#  'rel="stylesheet"',
#  'type="text/css"/>',
#  '<link',
#  'href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.7"',
#  'media="all"',
#  'rel="stylesheet"',
#  'type="text/css"/>',
#  '<script',
#  'src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js"',
#  'type="text/javascript">',
#  '</script>',
#  '<script',
# ...

# %%
from bs4 import BeautifulSoup

html_doc = """
<html>
<head>
<title>My Website</title>
</head>
<body>
<div id="content">
<h1>Welcome to my website!</h1>
<p>This is a paragraph of text.</p>
<a href="http://www.google.com">Google</a>
</div>
</body>
</html>
"""
soup=BeautifulSoup(html_doc, 'html.parser')
div_tag=soup.find('div', {'id':'content'})
print(div_tag)
# Out:
# <div id="content">
# <h1>Welcome to my website!</h1>
# <p>This is a paragraph of text.</p>
# <a href="http://www.google.com">Google</a>
# </div>

# %%
from bs4 import BeautifulSoup
html_doc = """
<html>
<head>
<title>My Website</title>
</head>
<body>
<div class="article">
<h2>Article Title</h2>
<p>This is the first paragraph.</p>
<p>This is the second paragraph.</p>
</div>
<div class="article">
<h2>Another Article Title</h2>
<p>This is another paragraph.</p>
</div>
</body>
</html>
"""
soup=BeautifulSoup(html_doc, 'html.parser')
h2tags=soup.find_all('h2')
for h2tag in h2tags:
    print(h2tag)
# Out:
# <h2>Article Title</h2>
# <h2>Another Article Title</h2>
